# %% [markdown]
# # Experiment 9
# Description :
# * n_fft = 4096
# * Silent parts removed ( threshold based )
# * Vocal separated
# * Ten classes ( Abhogi , Basant , Ahir Bhairav , Alhaiya Bilawal , Bairagi , Puriya Dhanashree , Bhoopali , Kedar , Rageshri , Bilaskhani Todi)
# * Spectrograms of window length 10 seconds and hop length 5 seconds.

# %% [markdown]
# # Install libraries

# %%
# !cp -r "/gdrive/My Drive/Major Project/Images/Experiment 2/Data" "/content"
# Out:
# cp: cannot stat '/gdrive/My Drive/Major Project/Images/Experiment 2/Data': No such file or directory

# %%
# !pip install flashtorch --quiet
# Out:
#   Building wheel for flashtorch (setup.py) ... done

# %%
# !pip install livelossplot --quiet

# %%
# !pip install InaSpeechSegmenter --quiet
# Out:
#      |████████████████████████████████| 13.9MB 235kB/s
#      |████████████████████████████████| 61kB 10.4MB/s
#      |████████████████████████████████| 92kB 10.2MB/s
#      |████████████████████████████████| 174kB 64.4MB/s
#      |████████████████████████████████| 81kB 12.6MB/s
#      |████████████████████████████████| 133kB 65.8MB/s
#      |████████████████████████████████| 163kB 59.3MB/s
#      |████████████████████████████████| 1.1MB 54.3MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#   Building wheel for pyroomacoustics (PEP 517) ... done
#   Building wheel for sidekit (setup.py) ... done

# %%
# !pip install librosa==0.8.0 --quiet
# Out:
#      |████████████████████████████████| 184kB 8.5MB/s
#      |████████████████████████████████| 51kB 4.8MB/s
#   Building wheel for librosa (setup.py) ... done

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# # Image generation code / commands

# %%
import os
# from inaSpeechSegmenter.segmenter import Segmenter
import librosa
import librosa.display
import scipy.io.wavfile
import matplotlib.pyplot as plt
import numpy as np
import gc
from librosa.effects import split

# %%
def separate_speech_silence(audio , fs , intermediate_path , index):
	"""
	Removes slient parts of the audio and saves resulting wavefile to intermediate path
	"""
	intervals = split(audio)
	result = np.array([])
	for interval in intervals:
		result = np.append(result , audio[interval[0]:interval[1]])
	scipy.io.wavfile.write(os.path.join(intermediate_path , str(index)+".wav") , fs , result)
	return result

# %%
def make_spec(audio , fs , output_path , index):
    """
    Makes spectrogram images from audio present at intermediate path and saves images at output path
    """
    window_length_in_sec = 10
    window_hop_in_sec = 5

    # audio , fs = librosa.load(intermediate_path)

    start = 0
    end = window_length_in_sec * fs
    idx = 0
    while end < len(audio):
        D_block = librosa.stft(audio[start:end] , center=False , n_fft = 4096 , hop_length=64)
        fig , ax = plt.subplots()
        librosa.display.specshow(D_block , y_axis="linear" , ax=ax)
        ax.set_ylim([0,1024])
        ax.set_ylabel("")
        plt.tick_params(axis="both" ,bottom=False , left=False)
        plt.yticks()
        ax.get_yaxis().set_visible(False)

        plt.savefig(os.path.join(output_path , str(index) + "_" + str(idx) + ".png" ) , bbox_inches="tight" , format="png" , pad_inches=0)
        fig.clf()
        plt.close()
        gc.collect()

        idx += 1
        start += window_hop_in_sec * fs
        end += window_hop_in_sec * fs

# %%
def generate_images(input_path , audio_path, output_path , index):
    audio , fs = librosa.load(input_path)
    audio = separate_speech_silence(audio , fs , audio_path , index)
    make_spec(audio , fs , output_path , index)

# %%
class_name = "Basant"
temp = df.loc[df['Raga']==class_name]
base_s = "/gdrive/My Drive/Major Project/Vocals/"
output_path = "/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/" + class_name + "/"
audio_path = "/gdrive/My Drive/Major Project/Images/Experiment 9/Silent Split/" + class_name + "/"
for i in range(5, len(temp)):
    input_path = base_s + class_name + "/"+ str(temp.iloc[i][1]) + "/vocals.wav"
    print(str(i) + " : " + input_path)
    generate_images(input_path , audio_path , output_path , i)
# Out:
# 5 : /gdrive/My Drive/Major Project/Vocals/Basant/Raga_Basant_Khyal_bb6a5ac4-9e42-49b2-bec4-58e1aff53230/vocals.wav
# /usr/local/lib/python3.6/dist-packages/librosa/display.py:696: UserWarning: Trying to display complex-valued input. Showing magnitude instead.
#   warnings.warn('Trying to display complex-valued input. '
# 6 : /gdrive/My Drive/Major Project/Vocals/Basant/Raga_Basant_-_Drut_Ektaal_9ff5e2dd-7c77-492d-9aa1-09508fe595b9/vocals.wav
# /usr/local/lib/python3.6/dist-packages/librosa/display.py:696: UserWarning: Trying to display complex-valued input. Showing magnitude instead.
#   warnings.warn('Trying to display complex-valued input. '
# 7 : /gdrive/My Drive/Major Project/Vocals/Basant/Raga_Basant_Piya_Sang_Kheloon_3d6dc834-550d-4eb5-87f9-6e57747f3cb1/vocals.wav
# /usr/local/lib/python3.6/dist-packages/librosa/display.py:696: UserWarning: Trying to display complex-valued input. Showing magnitude instead.
#   warnings.warn('Trying to display complex-valued input. '
# 8 : /gdrive/My Drive/Major Project/Vocals/Basant/Madhukar_Aaj_Basant_88b004be-6280-402b-a178-07efd6285326/vocals.wav
# /usr/local/lib/python3.6/dist-packages/librosa/display.py:696: UserWarning: Trying to display complex-valued input. Showing magnitude instead.
#   warnings.warn('Trying to display complex-valued input. '
# 9 : /gdrive/My Drive/Major Project/Vocals/Basant/Raga_Basant_10224082-7d00-4839-b430-c8110686ec64/vocals.wav
# /usr/local/lib/python3.6/dist-packages/librosa/display.py:696: UserWarning: Trying to display complex-valued input. Showing magnitude instead.
#   warnings.warn('Trying to display complex-valued input. '

# %% [markdown]
# Import dataset from google sheets

# %%
from google.colab import auth
auth.authenticate_user()
import gspread
from oauth2client.client import GoogleCredentials
gc_ = gspread.authorize(GoogleCredentials.get_application_default())

# %%
import pandas as pd

# %%
wb = gc_.open_by_url('https://docs.google.com/spreadsheets/d/1gysr1UIh8sgLvT7JJEeYHbR-EUQ95TjYE8JT7xowkOs/edit#gid=1882594633')
sheet = wb.worksheet('silent split')
data = sheet.get_all_values()
df = pd.DataFrame(data)
df.columns = df.iloc[0]
df = df.iloc[1:]
df.shape
# Out:
# (299, 2)

# %%
# trial code
class_name = "Basant"
temp = df.loc[df['Raga']==class_name]
base_s = "/gdrive/My Drive/Major Project/Vocals/"
raga_class = []
for i in range(len(temp)):
    raga_class.append(base_s + class_name + "/"+ str(temp.iloc[i][1]) + "/vocals.wav")
for song in raga_class:
    print(song)
print(len(raga_class))
# Out:
# /gdrive/My Drive/Major Project/Vocals/Basant/Mora_Saajan_Chhabila_Ree_dbfa7e22-4432-4db5-8ec6-8482b97bcea9/vocals.wav
# /gdrive/My Drive/Major Project/Vocals/Basant/Raga_Basant_4519091e-9eaa-4f03-911e-348727ee3c90/vocals.wav
# /gdrive/My Drive/Major Project/Vocals/Basant/Raga_Basant_5b640af5-26f6-4a02-81e5-d28cd01e9149/vocals.wav
# /gdrive/My Drive/Major Project/Vocals/Basant/Raga_Vasant_-_Khyal_d9a79389-f4b4-4d66-920c-494525b3417e/vocals.wav
# /gdrive/My Drive/Major Project/Vocals/Basant/Raga_Basant_c853d66a-7f61-42ef-8373-94798bde90a6/vocals.wav
# /gdrive/My Drive/Major Project/Vocals/Basant/Raga_Basant_Khyal_bb6a5ac4-9e42-49b2-bec4-58e1aff53230/vocals.wav
# /gdrive/My Drive/Major Project/Vocals/Basant/Raga_Basant_-_Drut_Ektaal_9ff5e2dd-7c77-492d-9aa1-09508fe595b9/vocals.wav
# /gdrive/My Drive/Major Project/Vocals/Basant/Raga_Basant_Piya_Sang_Kheloon_3d6dc834-550d-4eb5-87f9-6e57747f3cb1/vocals.wav
# /gdrive/My Drive/Major Project/Vocals/Basant/Madhukar_Aaj_Basant_88b004be-6280-402b-a178-07efd6285326/vocals.wav
# /gdrive/My Drive/Major Project/Vocals/Basant/Raga_Basant_10224082-7d00-4839-b430-c8110686ec64/vocals.wav
# 10

# %%
# !pip install pydub
# Out:
# Collecting pydub
#   Downloading https://files.pythonhosted.org/packages/7b/d1/fbfa79371a8cd9bb15c2e3c480d7e6e340ed5cc55005174e16f48418333a/pydub-0.24.1-py2.py3-none-any.whl
# Installing collected packages: pydub
# Successfully installed pydub-0.24.1

# %%
from os import path
from pydub import AudioSegment

# files
base = "/gdrive/My Drive/Major Project/Vocals/Ahir Bhairav/Raga_Ahir_Bhairav_cbcba04b-023b-40e0-a5e8-04260ad3efdd" + "/"
src_a = base + "accompaniment.mp3"
dst_a = base + "accompaniment.wav"
src_v = base + "vocals.mp3"
dst_v = base + "vocals.wav"

# convert wav to mp3                                                            
sound_a = AudioSegment.from_mp3(src_a)
sound_a.export(dst_a, format="wav")
sound_v = AudioSegment.from_mp3(src_v)
sound_v.export(dst_v, format="wav")
# Out:
# <_io.BufferedRandom name='/gdrive/My Drive/Major Project/Vocals/Ahir Bhairav/Raga_Ahir_Bhairav_cbcba04b-023b-40e0-a5e8-04260ad3efdd/vocals.wav'>

# %%
# append the list of classes in the below list
classes = ['Jog']

# %%
for raag in classes:
    seperate_class_raga(raag)

# %%
def seperate_class_raga(class_name):
    # class_name = "Darbari"
    print("\033[1m" + class_name + "\033[0m")

    temp = df.loc[df['Raga']==class_name]
    base_s = "/gdrive/My Drive/Major Project/Vocals/"
    raga_class = []
    for i in range(len(temp)):
        raga_class.append(base_s + class_name + "/"+ str(temp.iloc[i][1]) + "/vocals.wav")

    output_loc = "/gdrive/My Drive/Major Project/Images/Experiment 2/Silent split Ragas/" + class_name
    os.makedirs(output_loc)
    for idx in range(len(raga_class)):
        print("\033[1m" + str(temp.iloc[idx][1]) + "\033[0m")
        separate_speech_silence(raga_class[idx] , output_loc, idx )
        print()

# %%
for idx in range(len(bairagi)):
    generate_images(bairagi[idx] , "/gdrive/My Drive/Major Project/Images/Experiment 2/Bairagi" ,"/gdrive/My Drive/Major Project/Images/Experiment 2/Spectrograms/Bairagi" , idx )

# %% [markdown]
# # Data Splitting

# %%
# !pip install split-folders
# Out:
# Collecting split-folders
#   Downloading https://files.pythonhosted.org/packages/d1/4b/7b282b0f9319189d71e803220748929b37d019b67b1782d14c59cb1bd940/split_folders-0.4.2-py3-none-any.whl
# Installing collected packages: split-folders
# Successfully installed split-folders-0.4.2

# %%
import splitfolders
input_folder = "/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms"
output_folder = "/gdrive/My Drive/Major Project/Images/Experiment 9/Data"
splitfolders.ratio(input_folder , output=output_folder, seed=42, ratio=(.8, .1, .1), group_prefix=None)
# Out:
# Copying files: 19161 files [1:34:03,  3.39 files/s]

# %% [markdown]
# # Imports

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms as transforms
import torch.optim as optim
from torchvision import datasets
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
from livelossplot import PlotLosses

# %% [markdown]
# # Data Loading

# %%
# Data transforms : Resizing , Converting to Pytorch tensor , Nomralizing the image
# data_transforms = {
#     'train' : transforms.Compose([transforms.Resize(size=(324,216)),
#                                  transforms.ToTensor(),
#                                  transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])]),
#     'valid': transforms.Compose([transforms.Resize(size=(324,216)),
#                                transforms.ToTensor(),
#                                transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])]),
#     'test': transforms.Compose([transforms.Resize(size=(324,216)),
#                                transforms.ToTensor(),
#                                transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])]) 
# }

data_transforms = {
    'train' : transforms.Compose([transforms.Resize(size=(324,216)),
                                 transforms.ToTensor(),
                                 ]),
    'valid': transforms.Compose([transforms.Resize(size=(324,216)),
                               transforms.ToTensor(),
                               ]),
    'test': transforms.Compose([transforms.Resize(size=(324,216)),
                               transforms.ToTensor(),
                               ]) 
}

main_dir = "/gdrive/My Drive/Major Project/Images/Experiment 9/Data"
# main_dir = "/content/Data"
train_dir = os.path.join(main_dir, "train")
test_dir = os.path.join(main_dir, "val")
valid_dir = os.path.join(main_dir, "test")

# Making dataset objects
train_data = datasets.ImageFolder(train_dir, transform=data_transforms['train'])
valid_data = datasets.ImageFolder(valid_dir, transform=data_transforms['valid'])
test_data = datasets.ImageFolder(test_dir, transform=data_transforms['test'])

batch_size = 8
num_workers = 0

# Making dataloader objects
train_loader = torch.utils.data.DataLoader(train_data,
                                           batch_size=batch_size, 
                                           num_workers=num_workers,
                                           shuffle=True,
                                           drop_last = True,)
valid_loader = torch.utils.data.DataLoader(valid_data,
                                           batch_size=batch_size, 
                                           num_workers=num_workers,
                                           shuffle=True,
                                           drop_last=True)
test_loader = torch.utils.data.DataLoader(test_data,
                                           batch_size=1, 
                                           num_workers=num_workers,
                                           shuffle=True)
loaders = {
    'train': train_loader,
    'valid': valid_loader,
    'test': test_loader
}

# %%
print(test_data.class_to_idx)
# Out:
# {'Abhogi': 0, 'Ahir Bhairav': 1, 'Alhaiya Bilawal': 2, 'Bairagi': 3, 'Basant': 4, 'Bhoopali': 5, 'Bilaskhani Todi': 6, 'Kedar': 7, 'Puriya Dhanashree': 8, 'Rageshri': 9}

# %% [markdown]
# # Modeling

# %%
"""
This method returns Sequential Conv2d with/without batch normalisation of given size, same size by default
"""
def conv(in_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False, batch_norm=False):
    layers = []
    layers.append(nn.Conv2d(in_channels, out_channels, kernel_size, stride=stride, padding=padding, bias=bias))
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
    return nn.Sequential(*layers)

"""
Returns Maxpool2D, shrinks in half by default
"""
def pool(kernel_size=2, stride=2, padding=0):
    layers = []
    layers.append(nn.MaxPool2d(kernel_size, stride=stride, padding=padding))
    return nn.Sequential(*layers)

"""
Modify this to experiment on CNN architecture
Basic flow => Conv => BatchNorm => Activation => Dropout => Pooling
"""
class CNN(nn.Module):

    """
    Change in architecture must change forward function
    """
    def __init__(self, output_size=10):
        super(CNN, self).__init__()
        self.conv1 = conv(3, 32, 3, stride=1, padding=1, batch_norm=True)
        self.pool1 = pool(3, stride=3, padding=0)
        self.conv2 = conv(32, 64, 3, stride=1, padding=1, batch_norm=True)
        self.pool2 = pool(2, stride=2, padding=0)
        self.conv3 = conv(64, 64, 3, stride=1, padding=1, batch_norm=True)
        self.pool3 = pool(2, stride=2, padding=0)
        self.conv4 = conv(64, 64, 3, stride=1, padding=1, batch_norm=True)
        self.pool4 = pool(2, stride=2, padding=0)
        # TODO: write input size of FC1
        self.fc1 = nn.Linear(13*9*64, 512)
        self.fc2 = nn.Linear(512, output_size)
        self.softmax = nn.LogSoftmax(dim=1)
        self.dropout = nn.Dropout(0.2)

    def forward(self, x):
        x = self.conv1(x)                              # (324,216,3) => (324 , 216 , 32)
        x = F.relu(x)
        x = self.dropout(x)                           
        x = self.pool1(x)                              # (324 , 216 , 32) => (108 , 72 , 32)
        
        # print("Shape after 1st pooling layer " , x.shape)
        # One liner for all
        x = self.pool2(self.dropout(F.relu(self.conv2(x))))   # (107 , 71 , 32) => (107 , 71 , 64) => (54 , 36 , 64)
        # print("Shape after 2nd pooling layer " , x.shape)
        
        x = self.pool3(self.dropout(F.relu(self.conv3(x))))   #(54 , 36 , 64) => (54 , 36 , 128) => (27 , 18 , 64)
        # print("Shape after 3rd pooling layer " , x.shape)
        
        x = self.pool4(self.dropout(F.relu(self.conv4(x))))   # (13 , 9 , 64) 
        # print("Shape after 4th pooling layer " , x.shape)
        
        # Flatten                                             
        x = x.view(-1, x.shape[3]*x.shape[1]*x.shape[2])
        # print("Shape after flattening " , x.shape)
        
        x = F.relu(self.fc1(x))
        # print("Shape after FC 1 " , x.shape)

        x = self.dropout(x)
        x = self.fc2(x)
        x = self.softmax(x)
        return x

# %% [markdown]
# # Training

# %%
def train(model, loaders, n_epochs, optimizer, criterion, device, save_path, print_every=100 , stop_after=3):
    valid_loss_min = np.Inf
    stop = stop_after
    liveloss = PlotLosses()

    for epoch in range(1, n_epochs+1):
        logs = {}
        
        train_loss = 0.0
        valid_loss = 0.0
        running_loss_t = 0.0
        running_correct_t = 0
        running_loss_v = 0.0
        running_correct_v = 0.0
        print("Epoch number start " ,str(epoch) )
        # training
        model.train()
        for batch_index, (data, target) in enumerate(loaders['train']):
            if device == 'cuda':
                data, target = data.cuda(), target.cuda()

            # print("Data size " , data.shape)
            # print("Target " , target)
            optimizer.zero_grad()         
            pred = model(data)
            # print("Pred " , pred)
            loss = criterion(pred, target)
            # running_loss_t += loss.detach()*data.size(0)
            loss.backward()
            optimizer.step()

            running_loss_t += loss.detach()*data.size(0)
            running_correct_t += torch.sum( torch.argmax(torch.exp(pred) , dim=1) == target)

            train_loss += ((1 / (batch_index + 1)) * (loss.data - train_loss))

            if batch_index%print_every == 0:
                print(f"Epoch {epoch} Batch {batch_index} loss {train_loss}")
        
        epoch_loss_t = running_loss_t / len(loaders["train"].dataset)
        epoch_acc_t = running_correct_t.item() / len(loaders['train'].dataset)
        logs["log loss"] = epoch_loss_t.item()
        logs["accuracy"] = epoch_acc_t
        
        # validation
        model.eval()
        for batch_index, (data, target) in enumerate(loaders['valid']):
            if device == 'cuda':
                data, target = data.cuda(), target.cuda()
            # print("VAlid data shape " , data.shape)
            pred = model(data)
            loss = criterion(pred, target)
            running_loss_v += loss.detach()*data.size(0)
            running_correct_v += torch.sum( torch.argmax(torch.exp(pred) , dim=1) == target)

            valid_loss += ((1 / (batch_index + 1)) * (loss.data - valid_loss))

        epoch_loss_v = running_loss_v / len(loaders["valid"].dataset)
        epoch_acc_v = running_correct_v.item() / len(loaders['valid'].dataset)
        logs["val_log loss"] = epoch_loss_v.item()
        logs["val_accuracy"] = epoch_acc_v

        liveloss.update(logs)
        liveloss.send()

        print(f"Epoch: {epoch} Training Loss: {train_loss} Validation Loss: {valid_loss}")

        if valid_loss < valid_loss_min:
            torch.save(model.state_dict(), save_path)
            print(f"Validation Loss decreased from {valid_loss_min} to {valid_loss}. Saving model...")
            valid_loss_min = valid_loss
            stop_after = stop
        else:
            stop_after -= 1

        if stop_after == 0:
            return model
        print("Epoch end ",str(epoch))
    return model

# %% [markdown]
# # Main

# %%
if torch.cuda.is_available():
    device = 'cuda'
else:
    device = 'cpu'
model = CNN(output_size=10)

# if device == 'cuda':
#     model = model.cuda()

model = model.cuda()
# Loss class
criterion = torch.nn.NLLLoss()
# Optimizer class
optimizer = optim.Adam(params=model.parameters() , lr=0.0001)

model = train(model, loaders, 100, optimizer, criterion, device, os.path.join("/gdrive/My Drive/Major Project/Images/Experiment 9","model_5classes_d.pt"), print_every=100 , stop_after=300)
# test(model, loaders, criterion, device)
# Out:
# accuracy
# 	training         	 (min:    0.425, max:    0.998, cur:    0.998)
# 	validation       	 (min:    0.623, max:    0.953, cur:    0.948)
# log loss
# 	training         	 (min:    0.004, max:    1.679, cur:    0.005)
# 	validation       	 (min:    0.150, max:    1.376, cur:    0.188)
# Epoch: 100 Training Loss: 0.004824172705411911 Validation Loss: 0.18803957104682922
# Epoch end  100

# %% [markdown]
# # Testing

# %%
def test(model, loaders, criterion, device):
    test_loss = 0.0
    correct = 0.0
    total = 0.0

    model.eval()
    for batch_index, (data, target) in enumerate(loaders['test']):
        if device == 'cuda':
            data, target = data.cuda(), target.cuda()
        pred = model(data)
        loss = criterion(pred, target)
        test_loss += ((1 / (batch_index + 1)) * (loss.data - test_loss))
        pred = pred.data.max(1, keepdim=True)[1]
        correct += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
        total += data.size(0)
        
    print("Correct : " , correct , " Total : " , len(loaders["test"]))
    print(f"Test loss {test_loss}")
    print(f"Testing accuracy {correct/total}")

# %%
print(len(loaders["test"].dataset))
# Out:
# 320

# %%
# model = torch.load(os.path.join("/gdrive/My Drive/Major Project/Images/Experiment 9","model_10classes_d.pt"))
model = CNN(output_size = 10)
model.load_state_dict(torch.load(os.path.join("/gdrive/My Drive/Major Project/Images/Experiment 9","model_10classes_D.pt")))
model = model.cuda()
test(model, loaders, criterion, device)
# Out:
# Correct :  1795.0  Total :  1912
# Test loss 0.21675840020179749
# Testing accuracy 0.9388075313807531

# %%
model = CNN(output_size = 10)
model.load_state_dict(torch.load(os.path.join("/gdrive/My Drive/Major Project/Images/Experiment 9","model_10classes_d.pt")))
model = model.cuda()
test(model, loaders, criterion, device)
# Out:
# Correct :  1808.0  Total :  1912
# Test loss 0.19144736230373383
# Testing accuracy 0.9456066945606695

# %%
print(len(loaders["test"]))
# Out:
# 1581

# %%
torch.save(model.state_dict() , os.path.join("/gdrive/My Drive/Major Project/Images/Experiment 6","model.pt"))

# %% [markdown]
# # LSTM data preparation

# %%
"""
Making a dataframe of all spectrogram files' path and their class
"""
import pandas as pd

path_df = pd.DataFrame(columns=["Path" , "Name" , "Raga"])
paths = []
names = []
ragas = []

dataset_path = "/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms"

raga_classes = ["Abhogi", "Ahir Bhairav", "Alhaiya Bilawal", "Basant", "Bairagi" , "Bhoopali" , "Bilaskhani Todi" , "Kedar" , "Puriya Dhanashree" , "Rageshri"]

# for file_name in os.listdir(os.path.join(dataset_path , "Abhogi")):
#     paths.append(os.path.join(dataset_path , "Abhogi" , file_name))
#     names.append(file_name.split("_")[0])
#     ragas.append("Abhogi")

# for file_name in os.listdir(os.path.join(dataset_path , "Basant")):
#     paths.append(os.path.join(dataset_path , "Basant" , file_name))
#     names.append(file_name.split("_")[0])
#     ragas.append("Basant")

for raga_class in raga_classes:
  for file_name in os.listdir(os.path.join(dataset_path , raga_class)):
    paths.append(os.path.join(dataset_path , raga_class , file_name))
    names.append(file_name.split("_")[0])
    ragas.append(raga_class)

path_df.Path = paths
path_df.Name = names
path_df.Raga = ragas

path_df.to_csv(dataset_path + str("/file.csv"))

raga_name_groupby = path_df.groupby(by=["Raga" , "Name"])
# print(raga_name_groupby.count())

# %%
print(raga_name_groupby.count())
# Out:
#                Path
# Raga     Name
# Abhogi   0      258
#          1      320
#          2       53
#          3      166
#          4       72
# ...             ...
# Rageshri 5      302
#          6      211
#          7      237
#          8      183
#          9       50
#
# [100 rows x 1 columns]

# %%
"""
Making sequences from the input 
"""
def batch_data(words, sequence_length, batch_size , raga_name , features , target):    
    n_targets = len(words) - sequence_length
    
    if n_targets < 1:
        return 
    
    for i in range(n_targets):
        end_idx = i + sequence_length
        
        batch = words[i : end_idx]
        features.append(batch)
        target.append(raga_name)
        
    return features , target

# %%
"""
Saving pickle files of sequences of paths
"""
import pickle

sequence_length = 5
raga_names = ["Abhogi", "Ahir Bhairav", "Alhaiya Bilawal", "Bairagi", "Basant" , "Bhoopali" , "Bilaskhani Todi" , "Kedar" , "Puriya Dhanashree" , "Rageshri"]
# min_count = {"Abhogi":1, "Ahir Bhairav":0, "Alhaiya Bilawal":0, "Bairagi":0, "Basant":1}
# max_count = {"Abhogi":11, "Ahir Bhairav":10, "Alhaiya Bilawal":10, "Bairagi":10, "Basant":11}

for raga_name in raga_names:
    features = []
    target = []
    for i in range(10):
        # print("Starting " , i)
        features , target = batch_data(list(raga_name_groupby.get_group((raga_name,str(i))).Path) , sequence_length , 1 , raga_name , features , target)
        # print("Ending " , i)
    
    # print(len(target))
    with open(os.path.join("/gdrive/My Drive/Major Project/Images/Experiment 10/Paths" , raga_name + "_feature") , "wb") as f:
        pickle.dump(features , f)
    with open(os.path.join("/gdrive/My Drive/Major Project/Images/Experiment 10/Paths" , raga_name + "_target") , "wb") as f:
        pickle.dump(target , f)
print(features)
# Out:
# [['/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_0.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_1.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_2.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_3.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_4.png'], ['/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_1.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_2.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_3.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_4.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_5.png'], ['/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_2.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_3.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_4.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_5.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_6.png'], ['/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_3.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_4.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_5.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_6.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_7.png'], ['/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_4.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_5.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_6.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_7.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_8.png'], ['/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_5.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_6.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_7.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_8.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_9.png'], ['/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_6.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_7.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_8.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_9.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_10.png'], ['/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_7.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_8.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_9.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_10.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_11.png'], ['/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_8.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_9.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_10.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_11.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_12.png'], ['/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_9.png', '/gdrive/My Drive/Major Project/Images/Experiment 9/Spectrograms/Rageshri/0_10.png', '/gdrive/My Drive/Major P ...

# %%
"""
Loading pickle files
"""
import pickle
abhogi_fv = pickle.load(open("/gdrive/My Drive/Major Project/Images/Experiment 9/Paths/Abhogi_feature" , "rb"))
abhogi_t = pickle.load(open("/gdrive/My Drive/Major Project/Images/Experiment 9/Paths/Abhogi_target" , "rb"))

ahir_bhairav_fv = pickle.load(open("/gdrive/My Drive/Major Project/Images/Experiment 9/Paths/Ahir Bhairav_feature" , "rb"))
ahir_bhairav_t = pickle.load(open("/gdrive/My Drive/Major Project/Images/Experiment 9/Paths/Ahir Bhairav_target" , "rb"))

alhaiya_bilwal_fv = pickle.load(open("/gdrive/My Drive/Major Project/Images/Experiment 9/Paths/Alhaiya Bilawal_feature" , "rb"))
alhaiya_bilwal_t = pickle.load(open("/gdrive/My Drive/Major Project/Images/Experiment 9/Paths/Alhaiya Bilawal_target" , "rb"))

bairagi_fv = pickle.load(open("/gdrive/My Drive/Major Project/Images/Experiment 9/Paths/Bairagi_feature" , "rb"))
bairagi_t = pickle.load(open("/gdrive/My Drive/Major Project/Images/Experiment 9/Paths/Bairagi_target" , "rb"))

basant_fv = pickle.load(open("/gdrive/My Drive/Major Project/Images/Experiment 9/Paths/Basant_feature" , "rb"))
basant_t = pickle.load(open("/gdrive/My Drive/Major Project/Images/Experiment 9/Paths/Basant_target" , "rb"))

bhoopali_fv = pickle.load(open("/gdrive/My Drive/Major Project/Images/Experiment 9/Paths/Bhoopali_feature" , "rb"))
bhoopali_t = pickle.load(open("/gdrive/My Drive/Major Project/Images/Experiment 9/Paths/Bhoopali_target" , "rb"))

bilaskhani_fv = pickle.load(open("/gdrive/My Drive/Major Project/Images/Experiment 9/Paths/Bilaskhani Todi_feature" , "rb"))
bilaskhani_t = pickle.load(open("/gdrive/My Drive/Major Project/Images/Experiment 9/Paths/Bilaskhani Todi_target" , "rb"))

kedar_fv = pickle.load(open("/gdrive/My Drive/Major Project/Images/Experiment 9/Paths/Kedar_feature" , "rb"))
kedar_t = pickle.load(open("/gdrive/My Drive/Major Project/Images/Experiment 9/Paths/Kedar_target" , "rb"))

puriya_dhanashree_fv = pickle.load(open("/gdrive/My Drive/Major Project/Images/Experiment 9/Paths/Puriya Dhanashree_feature" , "rb"))
puriya_dhanashree_t = pickle.load(open("/gdrive/My Drive/Major Project/Images/Experiment 9/Paths/Puriya Dhanashree_target" , "rb"))

rageshri_fv = pickle.load(open("/gdrive/My Drive/Major Project/Images/Experiment 9/Paths/Rageshri_feature" , "rb"))
rageshri_t = pickle.load(open("/gdrive/My Drive/Major Project/Images/Experiment 9/Paths/Rageshri_target" , "rb"))

# %%
"""
Train test split
"""
from sklearn.model_selection import train_test_split

full_fv = abhogi_fv + ahir_bhairav_fv + alhaiya_bilwal_fv + bairagi_fv + basant_fv + bhoopali_fv + bilaskhani_fv + kedar_fv + puriya_dhanashree_fv + rageshri_fv
full_t = abhogi_t + ahir_bhairav_t + alhaiya_bilwal_t + bairagi_t + basant_t + bhoopali_t + bilaskhani_t + kedar_t + puriya_dhanashree_t + rageshri_t

X_train ,  X_test , y_train ,y_test = train_test_split(full_fv , full_t , test_size = 0.2)
X_valid ,  X_test , y_valid ,y_test = train_test_split(X_test ,y_test, test_size = 0.5)

print(len(X_train))
# print(X_train)
print(len(X_valid))
print(len(X_test))
# Out:
# 14928
# 1866
# 1867

# %%
"""
Custom Dataset class inheriting abstract Dataset class
"""
class SequenceDataset(torch.utils.data.Dataset):
    def __init__(self , x , y , cnn_model , test_transforms):
        self.x = x
        self.y = y
        self.cnn_model = cnn_model
        self.cnn_model.eval()
        self.test_transforms = test_transforms
        self.raga_encode = {"Abhogi":0, "Ahir Bhairav":1, "Alhaiya Bilawal":2, "Bairagi":3, "Basant":4 , "Bhoopali":5 , "Bilaskhani Todi":6 , "Kedar":7 , "Puriya Dhanashree":8 , "Rageshri":9}

    def __len__(self):
        return(len(self.x))

    def __getitem__(self , idx):
        """
        Returns sequence of feature vectors by getting output from cnn model
        """
        arr = self.x[idx]
        out = []
        with torch.no_grad():
            for path in arr:
                with open(path, 'rb') as f:
                    img = Image.open(f)
                    img = img.convert('RGB')
                img = self.test_transforms(img)
                img = img.cuda()
                output = self.cnn_model(img.unsqueeze(0))
                output = output.reshape(-1,13*9*64)
                out.append(output)

        t = torch.Tensor([self.raga_encode[self.y[idx]]]).long()
        return torch.stack(out) , t


# Transforms
test_transforms = transforms.Compose([transforms.Resize(size=(324,216)),
                                 transforms.ToTensor()])

# Loading the CNN model and removing the fully connected layers
model = CNN(output_size = 10)
model.load_state_dict(torch.load(os.path.join("/gdrive/My Drive/Major Project/Images/Experiment 9","model_10classes_d.pt") ,  map_location=torch.device('cpu')))
model = model.cuda()
cnn_model = nn.Sequential(*list(model.children())[:8])

# Making dataset objects
train_dataset = SequenceDataset(X_train , y_train , cnn_model , test_transforms)
valid_dataset = SequenceDataset(X_valid , y_valid , cnn_model , test_transforms)
test_dataset = SequenceDataset(X_test , y_test , cnn_model , test_transforms)

# %%
# Making Dataloader objects
loaders = {
    "train" : torch.utils.data.DataLoader(train_dataset,
                                           batch_size=16, 
                                           num_workers=0,
                                           shuffle=True,
                                           drop_last = True) ,
    "valid" : torch.utils.data.DataLoader(valid_dataset,
                                           batch_size=16, 
                                           num_workers=0,
                                           shuffle=True,
                                           drop_last = True) ,
    "test" : torch.utils.data.DataLoader(test_dataset,
                                           batch_size=16, 
                                           num_workers=0,
                                           shuffle=True,
                                           drop_last = True)
}

# %% [markdown]
# # LSTM Modeling

# %%
seq_length = 5
class LSTMModel(nn.Module):
    def __init__(self , input_size = 1 , hidden_layer_size = 256 , output_size = 2, num_layers=1):
        super(LSTMModel, self).__init__()
        self.hidden_layer_size = hidden_layer_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size , hidden_layer_size, num_layers=self.num_layers)
        self.fc = nn.Linear(hidden_layer_size , output_size)
        self.softmax = nn.LogSoftmax(dim=1)
        self.hidden = self.init_hidden()
    
    def init_hidden(self):
        return (torch.zeros(self.num_layers, 16, self.hidden_layer_size).cuda(),
                torch.zeros(self.num_layers, 16, self.hidden_layer_size).cuda())
        

    def forward(self , input_seq):
        self.hidden = self.init_hidden()
        self.lstm.flatten_parameters()
        # print("Input sequence shape " , input_seq.shape)
        lstm_out , self.hidden = self.lstm(input_seq, self.hidden)
        # print("LSTM layer output shape " , lstm_out.shape)
        lstm_output = lstm_out.view(-1, self.hidden_layer_size)
        # print("Reshaping lstm output to " , lstm_output.shape)
        lstm_output = lstm_output[seq_length-1::seq_length]
        # print("Input to fc layer " , lstm_output.shape)
        model_output = self.fc(lstm_output)
        # print("Output of fc layer " , model_output.shape)
        probabilities = self.softmax(model_output)
        # print("Output of softmax " , probabilities.shape)
        return probabilities
        # return model_output

# %% [markdown]
# # LSTM training

# %%
def train_lstm(model , loader , n_epochs , optimizer , criterion , device , save_path , print_every=100 , stop_after = 3):
    valid_loss_min = np.Inf
    stop = stop_after
    liveloss = PlotLosses()
    
    for epoch in range(1, n_epochs+1):
        logs = {}
        running_loss_t = 0.0
        running_correct_t = 0
        running_loss_v = 0.0
        running_correct_v = 0.0
        train_loss = 0.0
        valid_loss = 0.0
        print("Epoch number start " ,str(epoch) )
        # training
        model.train()
        if device == 'cuda':
          model = model.cuda()
        else:
          model = model.cpu()
        for batch_index, (data, target) in enumerate(loader["train"]):    # for sequence in sequences
            if device == 'cuda':
                data, target = data.cuda(), target.cuda()

            # print("Original data size " , data.shape)
            # print("Original target size " , target.shape)
            data = torch.squeeze(data , dim=0)
            data = data.reshape(seq_length, -1, 7488)
            # print("Data size " , data.shape)
            target = torch.squeeze(target , dim=1)
            # print("Target size " , target.shape)
            # print("Target " , target)
            model.zero_grad()
            
            # print("Forward pass beginning -----------")   
            pred = model(data)
            # pred = torch.unsqueeze(pred , 0)
            # print("Pred " , pred.shape)
            # print("Prediction" , pred)
            
            model.hidden[0].detach_()
            model.hidden[1].detach_()

            # print("Predicted " , torch.exp(pred) , " Target " , target)
            # print("Predicted shape " , pred.shape)
            # print("Target shape " , target.shape)
            loss = criterion(pred, target)
            # model.train()
            # optimizer.zero_grad()      
            loss.backward()
            optimizer.step()
            # print(model.lstm.weight_ih)
            running_loss_t += loss.detach()*data.size(1)
            running_correct_t += torch.sum( torch.argmax(torch.exp(pred) , dim=1) == target)

            train_loss += ((1 / (batch_index + 1)) * (loss.data - train_loss))

            if batch_index%print_every == 0:
                print(f"Epoch {epoch} Batch {batch_index} loss {train_loss}")
            
        epoch_loss_t = running_loss_t / len(loaders["train"].dataset)
        epoch_acc_t = running_correct_t.item() / len(loaders["train"].dataset)
        logs["log loss"] = epoch_loss_t.item()
        logs["accuracy"] = epoch_acc_t

        print("VALIDATION")
        # validation
        model.eval()
        with torch.no_grad():
            for batch_index, (data, target) in enumerate(loader['valid']):
                if device == 'cuda':
                    data, target = data.cuda(), target.cuda()
                # print("Valid data shape " , data.shape)
                
                data = torch.squeeze(data , dim=0)
                data = data.reshape(seq_length, -1, 7488)
                target = torch.squeeze(target , dim=1)
                # print("Valid Target " , target)
                # print("Valid target size " , target.shape)
                pred = model(data)
                # print("Vaild prediction " , torch.exp(pred))
                # pred = torch.unsqueeze(pred , 0)

                loss = criterion(pred , target)
                running_loss_v += loss.detach()*data.size(1)
                running_correct_v += torch.sum( torch.argmax(torch.exp(pred) , dim=1) == target)
                valid_loss += ((1 / (batch_index + 1)) * (loss.data - valid_loss))
        
        epoch_loss_v = running_loss_v / len(loaders["valid"].dataset)
        epoch_acc_v = running_correct_v.item() / len(loaders['valid'].dataset)
        logs["val_log loss"] = epoch_loss_v.item()
        logs["val_accuracy"] = epoch_acc_v

        liveloss.update(logs)
        liveloss.send()
        
        print(f"Epoch: {epoch} Training Loss: {train_loss} Validation Loss: {valid_loss}")

        if valid_loss < valid_loss_min:
            torch.save(model.state_dict(), save_path)
            print(f"Validation Loss decreased from {valid_loss_min} to {valid_loss}. Saving model...")
            valid_loss_min = valid_loss
            stop_after = stop
        else:
            stop_after -= 1

        if stop_after == 0:
            return model
        print("Epoch end ",str(epoch))
    return model

# %%
model_seq = LSTMModel(input_size = 7488, output_size=10)

# criterion = torch.nn.CrossEntropyLoss()
criterion = torch.nn.NLLLoss()
optimizer = optim.Adam(params=model_seq.parameters(), lr=0.0001)

model_seq = model_seq.cuda()
model_seq = train_lstm(model_seq  , loaders , 20 , optimizer , criterion , "cuda" , os.path.join("/gdrive/My Drive/Major Project/Images/Experiment 9","lstm_model.pt") , print_every = 10)
# Out:
# accuracy
# 	training         	 (min:    0.503, max:    1.000, cur:    0.999)
# 	validation       	 (min:    0.659, max:    0.914, cur:    0.874)
# log loss
# 	training         	 (min:    0.003, max:    1.667, cur:    0.013)
# 	validation       	 (min:    0.259, max:    1.218, cur:    0.341)
# Epoch: 20 Training Loss: 0.013086298480629921 Validation Loss: 0.3426004648208618

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
import gc
gc.collect()
# Out:
# 899

# %%
def test(model, loaders, criterion, device):
    test_loss = 0.0
    correct = 0.0
    total = 0.0
    
    
    model.eval()
    with torch.no_grad():
        for batch_index, (data, target) in enumerate(loaders['test']):
            if device == 'cuda':
                data, target = data.cuda(), target.cuda()
            data = torch.squeeze(data , dim=0)
            data = data.reshape(5, -1, 7488)
            target = torch.squeeze(target , dim=1)
            
            
            # hidden_cell = (torch.zeros(1,1,256).cuda(),
            #             torch.zeros(1,1,256).cuda())
            # model.init_hidden()
            pred = model(data)
            # pred = torch.unsqueeze(pred , 0)

            print("Prediction " , torch.exp(pred) , " Target " , target)
            loss = criterion(pred, target)
            test_loss += ((1 / (batch_index + 1)) * (loss.data - test_loss))
            pred = pred.data.max(1, keepdim=True)[1]
            correct += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
            total += data.size(1)

    print(f"Test loss {test_loss}")
    print(f"Testing accuracy {correct/total}")

# %%
# model_path = "/gdrive/My Drive/Major Project/Images/Experiment 1/lstm_model.pt"

# model = LSTMModel(input_size=7488)
# model.load_state_dict(torch.load(os.path.join("/gdrive/My Drive/Major Project/Images/Experiment 1","lstm_model.pt")))
# model = model.cuda()
# criterion = torch.nn.CrossEntropyLoss()
test(model_seq, loaders, criterion, "cuda")
# Out:
# Prediction  tensor([[3.1824e-06, 9.5923e-04, 2.3621e-04, 9.8315e-01, 9.7765e-03, 2.4106e-03,
#          2.7185e-03, 1.6860e-05, 6.7032e-04, 5.6954e-05],
#         [1.8661e-05, 1.2423e-04, 1.4323e-04, 7.1556e-04, 8.6592e-06, 6.7057e-05,
#          9.9662e-01, 3.2015e-06, 2.3001e-03, 2.5939e-06],
#         [1.2575e-02, 2.6482e-01, 6.1326e-04, 1.5470e-03, 1.8850e-04, 1.5592e-04,
#          7.1803e-01, 1.7683e-03, 1.4159e-04, 1.6112e-04],
#         [6.7033e-03, 5.5857e-01, 8.4790e-05, 5.4500e-02, 3.6015e-04, 2.2819e-01,
#          9.0150e-02, 2.0443e-03, 1.4291e-02, 4.5107e-02],
#         [3.7615e-02, 1.1353e-02, 4.6540e-02, 3.2715e-01, 1.1219e-01, 2.7900e-01,
#          1.0481e-01, 4.9276e-03, 7.6301e-02, 1.1334e-04],
#         [1.7826e-03, 1.2935e-01, 2.1158e-06, 1.2500e-05, 8.5627e-05, 1.5164e-06,
#          9.2944e-05, 8.6824e-01, 2.1249e-06, 4.3060e-04],
#         [2.2772e-02, 1.0227e-05, 7.9576e-01, 4.0443e-04, 4.2881e-05, 2.4370e-05,
#          1.8178e-02, 1.3789e-01, 2.4858e-02, 5.9219e-05],
#         [2.7564e-04, 2.8054e-03, 8.4739e-03, 1.5032e-05, 1.9284e-06, 1.8907e-04,
#          4.3454e-05, 9.8799e-01, 2.3065e-06, 2.0071e-04],
#         [9.9999e-01, 1.4029e-06, 1.0574e-06, 1.2601e-07, 3.2194e-09, 2.6180e-07,
#          1.6033e-06, 4.7816e-08, 4.4590e-08, 3.6427e-06],
#         [6.7672e-05, 3.5452e-05, 1.6237e-04, 9.9762e-01, 1.7410e-04, 1.0093e-06,
#          1.1531e-03, 1.2785e-06, 7.8782e-04, 5.1907e-07],
#         [1.3686e-03, 2.9015e-04, 4.7932e-01, 2.6792e-04, 4.4640e-03, 1.6739e-02,
#          2.1528e-04, 4.9719e-01, 3.4661e-05, 1.1513e-04],
#         [7.6116e-06, 4.3048e-06, 5.5846e-07, 1.3098e-06, 8.3087e-07, 9.9998e-01,
#          2.7431e-06, 1.0859e-06, 3.6408e-07, 3.2223e-07],
#         [6.7838e-04, 1.0194e-02, 1.2727e-02, 1.5698e-02, 4.0066e-02, 5.9296e-04,
#          8.7297e-01, 2.9091e-04, 4.6778e-02, 9.4489e-07],
#         [9.9822e-01, 3.7240e-04, 7.0319e-04, 2.4220e-05, 1.5655e-05, 5.5392e-06,
#          6.2072e-06, 3.3804e-05, 4.9508e-05, 5.7059e-04],
#         [7.7405e-05, 2.0888e-03, 3.8306e-07, 1.0562e-05, 4.2760e-05, 2.6504e-06,
#          4.9465e-04, 6.2682e-07, 9.9728e-01, 3.1396e-07],
#         [1.2866e-04, 1.8171e-02, 9.3648e-03, 4.8916e-04, 3.2423e-03, 4.4228e-04,
#          1.7169e-03, 5.7942e-02, 9.0828e-01, 2.2608e-04]], device='cuda:0')  Target  tensor([3, 6, 6, 0, 3, 7, 2, 7, 0, 3, 2, 5, 8, 0, 8, 8], device='cuda:0')
# Prediction  tensor([[2.8262e-02, 6.0119e-01, 2.5160e-01, 1.7959e-02, 5.7210e-03, 2.6392e-02,
#          3.8103e-03, 1.9715e-02, 5.5626e-04, 4.4797e-02],
#         [2.9979e-04, 3.1315e-01, 4.0045e-03, 2.5120e-02, 6.0362e-04, 4.1466e-02,
#          2.9710e-01, 2.0438e-03, 3.1592e-01, 3.0303e-04],
#         [1.1777e-03, 1.7305e-03, 1.2455e-06, 8.0197e-01, 2.4955e-04, 1.5764e-04,
#          1.9436e-01, 6.3603e-05, 2.6212e-04, 2.3075e-05],
#         [2.3807e-06, 3.2079e-05, 4.3576e-04, 1.4781e-06, 2.5907e-03, 1.1790e-05,
#          5.0624e-05, 1.7751e-04, 9.9669e-01, 4.8038e-06],
#         [2.2423e-01, 7.3764e-02, 1.9153e-01, 3.9983e-03, 1.2445e-03, 4.3886e-01,
#          9.9255e-03, 4.0484e-02, 1.3043e-02, 2.9197e-03],
#         [4.1970e-02, 3.5983e-02, 3.6160e-05, 2.7782e-03, 1.8074e-03, 3.9753e-02,
#          2.1574e-03, 2.3054e-01, 1.2884e-04, 6.4485e-01],
#         [1.8681e-04, 1.9041e-03, 1.6057e-03, 7.3494e-01, 2.5110e-01, 8.5349e-04,
#          8.4224e-03, 6.2057e-06, 6.4127e-04, 3.3343e-04],
#         [9.4095e-03, 1.7236e-03, 9.8060e-01, 2.5316e-04, 5.7553e-05, 2.6343e-06,
#          2.5027e-04, 4.9451e-03, 2.7015e-03, 5.6747e-05],
#         [8.0056e-03, 2.2368e-01, 2.6686e-03, 2.2785e-05, 6.4382e-05, 3.4842e-05,
#          7.4025e-03, 7.5793e-01, 7.5782e-05, 1.1785e-04],
#         [2.5618e-03, 9.8091e-03, 1.5764e-03, 9.5305e-01, 6.7654e-03, 1.2156e-02,
#          8.5658e-03, 4.0542e-03, 3.9335e-04, 1.0651e-03],
#         [1.4376e-06, 6.7186e-06, 1.5482e-03, 2.6225e-05, 3.1493e-03, 1.2230e-06,
#          4.3396e-05, 3.8924e-05, 9.9487e-01, 3.1197e-04],
#         [5.9676e-04, 1.3555e-03, 1.9934e-04, 8.2988e-04, 2.0468e-05, 9.9413e-01,
#          9.3526e-05, 2.7112e-03, 3.4453e-05, 3.1556e-05],
#         [1.8438e-03, 9.9093e-01, 6.3642e-03, 2.6443e-06, 6.0959e-05, 3.4321e-05,
#          2.1679e-04, 4.2912e-04, 1.8344e-05, 1.0448e-04],
#         [4.3391e-05, 1.9980e-02, 2.9137e-03, 3.2053e-04, 5.5059e-04, 8.1986e-05,
#          2.2180e-03, 5.3139e-06, 9.7369e-01, 1.9776e-04],
#         [2.1477e-06, 3.5118e-05, 1.5743e-03, 5.2227e-07, 1.1727e-06, 8.2944e-06,
#          1.1706e-06, 9.9837e-01, 6.4286e-07, 7.3336e-06],
#         [3.8345e-01, 1.7948e-02, 8.0695e-03, 3.9626e-01, 5.7902e-04, 6.2244e-02,
#          6.6113e-03, 3.5105e-04, 5.0573e-04, 1.2398e-01]], device='cuda:0')  Target  tensor([2, 8, 3, 8, 2, 1, 3, 2, 0, 3, 8, 5, 1, 8, 7, 6], device='cuda:0')
# Prediction  tensor([[3.2851e-04, 2.2667e-01, 5.7438e-03, 1.6827e-03, 3.5162e-03, 2.6872e-02,
#          2.8184e-01, 3.6248e-02, 4.1655e-01, 5.4701e-04],
#         [2.5039e-06, 1.6931e-05, 6.0909e-05, 9.9951e-01, 2.1748e-04, 1.1759e-06,
#          3.8135e-05, 3.4508e-06, 1.4595e-04, 1.1098e-07],
#         [4.5104e-04, 1.5126e-01, 4.2220e-04, 7.8936e-01, 1.0023e-05, 4.6244e-04,
#          5.6739e-02, 7.8456e-05, 9.3787e-04, 2.8427e-04],
#         [4.4336e-07, 1.8698e-05, 6.5293e-05, 3.5291e-04, 5.2377e-06, 1.6888e-05,
#          1.8232e-04, 5.8179e-06, 9.9935e-01, 3.0785e-07],
#         [4.2646e-05, 1.5630e-05, 9.9756e-01, 2.1509e-05, 1.4349e-05, 3.6883e-06,
#          4.3993e-07, 4.7995e-04, 2.0638e-05, 1.8448e-03],
#         [3.3186e-05, 1.1988e-04, 4.7051e-04, 3.3606e-06, 1.3139e-05, 6.1199e-05,
#          7.5704e-07, 9.9923e-01, 2.3741e-07, 6.4262e-05],
#         [7.9525e-05, 9.4350e-05, 8.9077e-04, 2.1375e-03, 2.5764e-01, 1.4693e-05,
#          2.6248e-03, 2.0146e-05, 7.3650e-01, 1.1117e-06],
#         [9.9289e-02, 4.8944e-02, 2.3042e-03, 2.0541e-04, 5.2659e-04, 1.2643e-01,
#          7.1193e-01, 4.6435e-05, 4.3181e-03, 6.0112e-03],
#         [1.0004e-04, 5.2837e-01, 2.7796e-04, 4.6964e-01, 2.9368e-06, 3.1125e-04,
#          3.7292e-04, 7.9339e-04, 9.1785e-06, 1.1963e-04],
#         [3.5496e-02, 1.7723e-01, 1.1660e-04, 4.2483e-03, 1.7396e-04, 1.0676e-02,
#          7.6616e-01, 5.5247e-03, 6.8971e-05, 3.0182e-04],
#         [1.9353e-03, 2.1908e-03, 4.3634e-04, 9.2800e-06, 1.1295e-04, 1.1275e-05,
#          3.7992e-05, 1.7402e-05, 1.2021e-06, 9.9525e-01],
#         [2.4987e-04, 1.9228e-03, 1.5222e-02, 4.5955e-03, 4.4072e-01, 6.9324e-03,
#          1.2481e-01, 5.1738e-03, 4.0037e-01, 4.3211e-06],
#         [2.7083e-03, 1.9055e-03, 3.0741e-02, 7.9532e-03, 8.7197e-01, 9.9979e-03,
#          4.8923e-02, 2.1596e-05, 2.5774e-02, 9.7562e-06],
#         [6.3893e-07, 1.1183e-05, 3.6859e-06, 2.9340e-06, 2.1392e-06, 9.9987e-01,
#          2.0107e-05, 1.8196e-06, 8.3743e-05, 4.3294e-06],
#         [7.0846e-01, 2.7066e-01, 2.5668e-04, 2.9690e-04, 3.7847e-04, 7.9327e-03,
#          8.8733e-04, 3.0544e-03, 8.7774e-04, 7.1963e-03],
#         [3.8033e-03, 3.5404e-04, 5.8584e-04, 7.8843e-05, 7.1770e-06, 4.3117e-07,
#          3.7222e-05, 2.3609e-03, 1.5144e-04, 9.9262e-01]], device='cuda:0')  Target  tensor([8, 3, 3, 8, 2, 7, 8, 6, 1, 6, 9, 8, 4, 5, 0, 9], device='cuda:0')
# Prediction  tensor([[1.3628e-05, 2.0478e-05, 2.9203e-04, 9.3830e-05, 9.9931e-01, 1.0023e-06,
#          2.5622e-05, 1.1214e-04, 6.0746e-05, 7.4090e-05],
#         [3.4580e-04, 4.2216e-03, 2.0624e-06, 9.9195e-01, 4.2993e-05, 2.5460e-03,
#          6.1590e-04, 1.0519e-04, 2.1732e-05, 1.4391e-04],
#         [7.2301e-03, 4.9200e-05, 8.1485e-04, 1.5186e-06, 9.8828e-01, 2.6004e-04,
#          4.0348e-04, 9.2567e-05, 2.8608e-03, 3.9321e-06],
#         [6.1217e-03, 2.6011e-02, 6.3471e-04, 9.1218e-01, 3.0637e-04, 2.3925e-05,
#          1.2611e-02, 1.2701e-05, 5.3028e-04, 4.1566e-02],
#         [4.3146e-01, 1.9300e-02, 4.5560e-05, 2.5703e-03, 3.5984e-04, 1.0752e-03,
#          8.9613e-03, 2.3931e-01, 1.0781e-02, 2.8614e-01],
#         [4.9982e-05, 1.3387e-04, 2.3474e-03, 9.2769e-05, 9.9567e-01, 8.2955e-06,
#          2.3495e-04, 7.5996e-04, 6.4302e-04, 6.1156e-05],
#         [2.8330e-03, 3.5309e-03, 8.1555e-07, 6.5208e-04, 1.5878e-06, 2.7733e-06,
#          9.7854e-01, 6.8220e-05, 1.4364e-02, 6.2686e-06],
#         [3.8418e-06, 3.2375e-06, 4.4078e-05, 2.5320e-07, 9.9992e-01, 1.5893e-07,
#          6.7803e-06, 1.0733e-07, 2.6365e-05, 7.3247e-08],
#         [8.4196e-01, 6.4552e-03, 7.4656e-02, 4.7477e-03, 1.3843e-03, 1.9874e-02,
#          8.5113e-03, 1.1284e-02, 6.3031e-04, 3.0501e-02],
#         [8.7042e-01, 3.8397e-02, 2.3013e-03, 2.8119e-05, 2.8681e-04, 6.4047e-02,
#          2.3174e-02, 8.6383e-06, 1.3269e-03, 1.0467e-05],
#         [5.7536e-07, 1.4997e-05, 6.4962e-05, 1.2445e-05, 6.1646e-06, 1.2421e-04,
#          9.9976e-01, 1.7052e-06, 1.2894e-05, 1.9645e-06],
#         [1.1197e-04, 1.5802e-02, 2.8678e-04, 2.7837e-03, 5.1367e-06, 1.5331e-03,
#          9.4631e-01, 1.2211e-05, 3.4938e-04, 3.2809e-02],
#         [5.4725e-04, 8.1249e-04, 9.9695e-01, 3.1661e-05, 2.1196e-06, 4.8527e-04,
#          1.7943e-06, 5.9079e-07, 1.5645e-06, 1.1653e-03],
#         [1.5533e-05, 3.8837e-05, 1.4294e-05, 7.7259e-07, 3.4465e-06, 9.9982e-01,
#          7.1365e-05, 1.3271e-05, 6.0755e-06, 1.8347e-05],
#         [1.0304e-04, 9.8999e-01, 1.4032e-03, 9.3727e-07, 4.8363e-03, 3.1498e-03,
#          1.7173e-04, 1.4437e-04, 1.0432e-04, 9.5260e-05],
#         [1.3121e-04, 8.8430e-01, 9.7187e-04, 2.7569e-03, 1.3933e-05, 3.6311e-04,
#          1.0884e-01, 6.7539e-06, 2.4684e-03, 1.5125e-04]], device='cuda:0')  Target  tensor([4, 3, 4, 3, 9, 4, 6, 4, 0, 0, 6, 9, 2, 5, 1, 1], device='cuda:0')
# Prediction  tensor([[9.2097e-03, 7.1160e-02, 8.0734e-04, 2.7315e-04, 2.3686e-04, 9.8443e-03,
#          6.9717e-01, 8.1454e-03, 1.4466e-02, 1.8869e-01],
#         [4.4908e-03, 1.4926e-03, 2.5157e-05, 7.3733e-03, 3.6980e-04, 7.0841e-04,
#          1.0353e-01, 4.2597e-04, 3.2716e-05, 8.8155e-01],
#         [5.4791e-05, 3.2891e-03, 1.4407e-02, 3.3293e-04, 9.1220e-01, 1.1751e-03,
#          3.0587e-04, 1.3922e-03, 6.6780e-02, 6.2289e-05],
#         [2.5965e-04, 1.3911e-06, 1.5066e-06, 3.0989e-07, 2.4465e-07, 3.9330e-06,
#          2.4198e-05, 1.5962e-06, 3.5650e-08, 9.9971e-01],
#         [9.9634e-01, 2.8729e-04, 1.1967e-04, 1.8531e-04, 3.0125e-04, 4.0216e-04,
#          3.6685e-04, 2.3594e-06, 1.9930e-03, 1.2009e-06],
#         [8.6607e-06, 1.0684e-06, 9.9670e-01, 5.7696e-05, 3.1003e-03, 8.6906e-06,
#          2.8434e-05, 8.6717e-07, 4.9383e-05, 4.8802e-05],
#         [1.0742e-02, 1.7400e-03, 2.4187e-04, 6.2164e-04, 2.2514e-06, 4.1399e-07,
#          9.5473e-01, 3.1840e-02, 7.4852e-05, 3.7157e-06],
#         [4.5587e-04, 4.9766e-05, 8.8451e-06, 3.4558e-04, 1.5990e-03, 1.6810e-06,
#          9.9701e-01, 1.2413e-04, 3.9456e-04, 1.0425e-05],
#         [4.2270e-05, 1.8846e-02, 1.8885e-05, 1.7276e-03, 1.3264e-06, 2.5966e-04,
#          1.4226e-03, 4.4259e-06, 1.0167e-05, 9.7767e-01],
#         [2.1995e-03, 4.8228e-01, 1.8654e-05, 3.9235e-01, 1.7509e-04, 2.5559e-04,
#          7.3782e-02, 4.6762e-05, 4.2992e-02, 5.8939e-03],
#         [1.9014e-05, 5.6236e-05, 2.3367e-06, 4.0689e-05, 4.0689e-06, 9.8482e-07,
#          9.9930e-01, 4.3121e-07, 5.7999e-04, 5.3078e-08],
#         [8.9567e-06, 2.8434e-06, 7.6132e-07, 4.1454e-06, 1.6326e-07, 1.2188e-07,
#          9.9905e-01, 1.4331e-07, 9.2815e-04, 4.3316e-08],
#         [2.0058e-05, 1.3470e-03, 6.1279e-04, 3.3467e-04, 1.8280e-03, 1.6416e-03,
#          1.2386e-02, 3.0035e-07, 9.8183e-01, 2.7162e-06],
#         [1.3255e-03, 9.2203e-03, 6.2439e-03, 1.4368e-03, 9.6708e-01, 7.4108e-04,
#          4.1914e-03, 6.2558e-03, 1.0780e-03, 2.4281e-03],
#         [9.9972e-01, 6.7189e-05, 4.7148e-07, 1.6590e-04, 6.0747e-07, 7.9631e-07,
#          2.7943e-05, 5.4453e-06, 1.3743e-06, 8.0775e-06],
#         [1.9879e-03, 7.2569e-02, 7.2864e-03, 4.6358e-03, 7.5817e-04, 4.0110e-01,
#          3.0337e-04, 3.8021e-04, 5.0759e-01, 3.3859e-03]], device='cuda:0')  Target  tensor([1, 9, 8, 9, 0, 2, 6, 6, 9, 3, 6, 6, 8, 4, 0, 8], device='cuda:0')
# Prediction  tensor([[2.2201e-02, 8.3319e-03, 9.3001e-01, 4.2976e-05, 2.3557e-04, 3.4312e-04,
#          3.8480e-03, 2.3359e-02, 1.1308e-04, 1.1515e-02],
#         [8.8052e-01, 6.6896e-04, 1.2604e-02, 5.2012e-05, 1.1351e-06, 2.1374e-04,
#          3.0264e-04, 1.0267e-01, 2.7205e-05, 2.9356e-03],
#         [5.1732e-03, 3.8721e-03, 7.4490e-01, 9.0659e-05, 3.9367e-04, 9.4741e-05,
#          2.0572e-06, 2.4513e-01, 5.6471e-06, 3.3574e-04],
#         [5.7018e-04, 7.7259e-03, 2.9430e-05, 2.8718e-01, 2.5030e-05, 1.3305e-05,
#          7.0355e-01, 2.8375e-04, 7.9426e-06, 6.1089e-04],
#         [1.4581e-04, 8.8973e-01, 1.1295e-03, 1.8465e-03, 1.8866e-03, 2.0920e-03,
#          2.3531e-03, 8.3776e-02, 2.3233e-04, 1.6812e-02],
#         [2.3730e-03, 5.5288e-02, 4.0218e-03, 7.5855e-03, 2.1889e-04, 9.2748e-01,
#          1.5685e-04, 1.7995e-03, 8.8897e-04, 1.9047e-04],
#         [1.0600e-05, 3.0532e-01, 5.0259e-03, 5.5522e-01, 2.2424e-03, 1.0966e-01,
#          2.2306e-03, 1.2613e-02, 6.3476e-03, 1.3331e-03],
#         [5.4177e-03, 1.3400e-03, 1.3645e-02, 1.3274e-03, 1.3326e-02, 6.9017e-03,
#          1.1514e-03, 9.4556e-01, 1.1233e-02, 9.4338e-05],
#         [1.7905e-03, 7.2495e-05, 1.2104e-04, 2.3542e-06, 9.9618e-01, 1.0631e-05,
#          1.3681e-05, 1.7205e-03, 1.3050e-05, 7.7278e-05],
#         [1.0441e-04, 2.0980e-03, 7.7920e-04, 4.5985e-05, 2.0138e-04, 2.7936e-06,
#          2.1262e-06, 9.9212e-01, 3.0439e-06, 4.6399e-03],
#         [1.1932e-01, 5.2513e-03, 1.0752e-04, 9.4872e-03, 2.5410e-02, 5.5658e-06,
#          8.3825e-01, 1.2489e-03, 8.4404e-04, 7.7745e-05],
#         [5.3434e-06, 4.2721e-06, 1.0259e-03, 4.7591e-07, 9.9844e-01, 2.5964e-06,
#          9.7489e-07, 8.3386e-05, 4.2833e-04, 1.0726e-05],
#         [7.5605e-01, 1.3717e-02, 1.7784e-04, 6.6222e-03, 2.0690e-01, 5.2147e-04,
#          1.6146e-03, 5.7764e-03, 8.5041e-03, 1.1564e-04],
#         [5.7163e-06, 8.4861e-07, 2.1611e-04, 5.6580e-05, 1.4760e-05, 4.0803e-07,
#          9.9968e-01, 1.8180e-07, 2.1926e-05, 9.5910e-08],
#         [6.9890e-05, 3.6658e-03, 8.9847e-04, 9.2344e-01, 2.1434e-03, 5.9419e-02,
#          5.5604e-03, 9.0842e-05, 4.4909e-03, 2.2263e-04],
#         [1.5606e-04, 1.1148e-03, 4.5451e-04, 2.0565e-04, 3.0755e-04, 9.2566e-06,
#          8.7263e-03, 9.7179e-01, 1.7130e-02, 1.1028e-04]], device='cuda:0')  Target  tensor([2, 0, 2, 6, 1, 5, 3, 7, 4, 7, 6, 4, 0, 6, 3, 7], device='cuda:0')
# Prediction  tensor([[1.6595e-03, 9.9060e-01, 7.9055e-06, 3.4630e-03, 2.0301e-05, 7.8912e-04,
#          6.0288e-04, 2.6743e-03, 8.6536e-05, 9.8466e-05],
#         [3.6329e-04, 7.6111e-03, 9.7739e-04, 8.8567e-01, 5.7888e-03, 1.1836e-02,
#          5.0279e-02, 2.6364e-03, 3.1388e-02, 3.4534e-03],
#         [6.5987e-04, 3.5350e-04, 9.9300e-01, 1.6512e-05, 2.2983e-05, 6.0738e-06,
#          5.6410e-05, 4.2155e-03, 1.2876e-04, 1.5449e-03],
#         [5.1139e-05, 8.8547e-06, 3.3935e-06, 1.3860e-05, 3.6309e-04, 2.0742e-07,
#          9.9953e-01, 2.1481e-06, 2.2409e-05, 1.2171e-07],
#         [2.6889e-05, 1.9747e-05, 5.8570e-04, 2.4765e-07, 9.9903e-01, 8.9477e-06,
#          1.3880e-04, 3.5124e-06, 1.3766e-04, 4.7755e-05],
#         [5.9809e-03, 4.8618e-04, 6.1277e-03, 3.8384e-02, 3.6959e-05, 9.7917e-05,
#          9.0798e-01, 3.0974e-05, 4.0724e-02, 1.5052e-04],
#         [3.2861e-06, 5.3077e-05, 3.6221e-06, 6.4568e-05, 2.5359e-07, 9.9948e-01,
#          1.8906e-04, 6.0973e-06, 1.7725e-04, 2.1279e-05],
#         [5.3455e-05, 8.3888e-02, 1.2252e-02, 2.0814e-05, 2.4490e-04, 9.1020e-05,
#          9.6992e-05, 9.0252e-01, 7.1996e-04, 1.1353e-04],
#         [1.5058e-06, 1.0869e-03, 4.6969e-07, 3.2178e-04, 4.8521e-07, 4.7608e-05,
#          9.3180e-04, 1.5758e-06, 9.9761e-01, 3.5946e-07],
#         [3.3912e-02, 1.0543e-02, 1.3330e-02, 7.7884e-02, 4.8417e-02, 2.6581e-03,
#          7.8879e-01, 5.8856e-05, 2.4158e-02, 2.4830e-04],
#         [3.3909e-04, 4.6322e-04, 9.3639e-05, 8.5613e-01, 3.0619e-05, 1.1730e-07,
#          1.3926e-01, 2.6249e-05, 3.6500e-03, 3.9361e-06],
#         [9.3341e-06, 1.0950e-04, 4.6613e-06, 1.5984e-04, 3.4715e-05, 1.7482e-06,
#          9.9921e-01, 8.1169e-06, 4.4402e-04, 1.7281e-05],
#         [4.3379e-07, 3.6929e-06, 1.9398e-06, 3.6282e-07, 1.8824e-08, 9.9996e-01,
#          3.0330e-05, 2.2089e-08, 2.2722e-07, 4.0011e-06],
#         [8.2497e-06, 5.3723e-04, 2.4443e-07, 9.9918e-01, 6.6663e-07, 8.4238e-06,
#          2.1653e-04, 8.1666e-06, 1.0367e-05, 2.7512e-05],
#         [7.8469e-03, 5.5067e-04, 8.0671e-01, 1.0745e-02, 1.8338e-04, 5.3451e-04,
#          5.4852e-03, 3.3782e-03, 5.1658e-02, 1.1291e-01],
#         [1.2211e-05, 1.5381e-04, 2.2844e-04, 5.3043e-04, 1.7620e-05, 2.5490e-04,
#          4.1821e-06, 3.4799e-04, 3.9627e-06, 9.9845e-01]], device='cuda:0')  Target  tensor([1, 3, 2, 6, 4, 6, 5, 7, 8, 0, 3, 6, 5, 3, 2, 9], device='cuda:0')
# Prediction  tensor([[2.2317e-05, 9.6681e-01, 1.4451e-04, 5.7238e-04, 8.5228e-04, 6.1221e-05,
#          1.8031e-02, 6.9476e-06, 1.3417e-02, 8.1549e-05],
#         [1.3706e-05, 2.8339e-05, 4.2000e-04, 4.1355e-07, 2.1255e-05, 8.7751e-05,
#          1.6279e-05, 9.9940e-01, 2.8178e-07, 1.4778e-05],
#         [1.1501e-05, 2.8067e-03, 7.5410e-04, 9.5663e-01, 1.0952e-03, 1.8241e-05,
#          2.7117e-02, 2.0753e-04, 1.1266e-02, 9.0007e-05],
#         [2.1019e-05, 7.9203e-04, 1.0899e-04, 9.7617e-05, 3.1588e-05, 5.2415e-04,
#          5.0789e-05, 1.9150e-03, 9.4555e-07, 9.9646e-01],
#         [3.1991e-03, 9.4038e-01, 4.8813e-05, 1.2537e-03, 1.2553e-04, 1.5165e-05,
#          1.5879e-02, 5.6556e-05, 3.3132e-03, 3.5728e-02],
#         [2.9536e-07, 1.1281e-06, 1.1848e-04, 2.0851e-05, 9.9965e-01, 2.9166e-07,
#          1.4453e-05, 4.7801e-05, 1.4435e-04, 2.4644e-06],
#         [3.4737e-04, 8.5170e-04, 1.2075e-02, 2.8366e-05, 9.6388e-01, 2.0746e-02,
#          1.0193e-03, 6.9497e-06, 8.1207e-04, 2.3347e-04],
#         [1.5502e-03, 1.0078e-04, 2.9129e-04, 2.1556e-03, 4.3620e-06, 1.0797e-06,
#          3.6530e-03, 9.9209e-01, 9.7699e-05, 6.0493e-05],
#         [5.8131e-04, 8.1686e-05, 3.0312e-03, 5.8280e-06, 9.9597e-01, 6.5717e-05,
#          2.3652e-04, 1.8572e-06, 2.5181e-05, 2.9477e-06],
#         [1.6245e-03, 8.5450e-06, 7.9538e-03, 1.7166e-05, 1.0121e-03, 2.2440e-02,
#          1.4701e-03, 2.4753e-05, 3.5849e-06, 9.6545e-01],
#         [7.5525e-05, 1.0161e-02, 8.1550e-04, 2.4927e-04, 5.8697e-05, 9.7846e-01,
#          3.1752e-03, 4.3992e-03, 2.0254e-03, 5.8014e-04],
#         [1.4608e-05, 1.0286e-04, 2.0378e-03, 6.4393e-05, 2.4647e-04, 4.7576e-05,
#          3.5451e-04, 2.7467e-05, 9.9708e-01, 2.4904e-05],
#         [6.7198e-01, 9.3014e-06, 2.0822e-02, 1.5762e-02, 1.1684e-01, 2.3505e-02,
#          1.9381e-02, 1.2722e-01, 1.8716e-04, 4.2994e-03],
#         [2.5858e-05, 1.1469e-04, 2.4384e-03, 1.5407e-05, 1.3806e-05, 4.9879e-03,
#          9.8158e-01, 2.1438e-05, 1.0794e-02, 7.0417e-06],
#         [9.9080e-04, 9.3853e-01, 2.4727e-05, 3.7959e-02, 6.2227e-05, 2.1669e-03,
#          1.3204e-02, 6.9282e-03, 1.0203e-04, 3.0849e-05],
#         [6.2735e-05, 2.1013e-04, 2.9272e-08, 9.9925e-01, 7.3923e-07, 2.8569e-05,
#          2.2318e-04, 9.9365e-06, 3.4141e-06, 2.1026e-04]], device='cuda:0')  Target  tensor([6, 7, 3, 9, 1, 4, 4, 7, 4, 9, 5, 8, 0, 6, 6, 3], device='cuda:0')
# Prediction  tensor([[1.9410e-04, 1.9437e-02, 9.2667e-01, 1.4348e-03, 5.0861e-02, 1.2119e-03,
#          4.2937e-05, 8.2179e-06, 8.6670e-05, 5.1906e-05],
#         [2.5332e-04, 1.5278e-02, 5.9331e-07, 5.2180e-04, 5.2116e-07, 1.2582e-05,
#          9.8366e-01, 3.7292e-05, 2.0182e-04, 3.4015e-05],
#         [4.5071e-03, 7.4066e-01, 6.6163e-04, 2.1615e-04, 1.4694e-04, 2.2311e-01,
#          3.5655e-04, 7.3438e-03, 7.5508e-04, 2.2247e-02],
#         [1.9137e-03, 2.3522e-03, 2.7106e-03, 1.3791e-02, 6.9635e-03, 8.3564e-01,
#          1.3502e-01, 2.6561e-04, 1.2552e-03, 8.6963e-05],
#         [1.0183e-05, 1.0910e-04, 1.0810e-07, 9.9958e-01, 4.5975e-06, 1.1294e-04,
#          1.2851e-04, 1.2678e-06, 4.5815e-05, 7.8321e-06],
#         [2.1963e-04, 1.2038e-05, 8.0877e-06, 1.1186e-04, 5.2680e-05, 7.4984e-05,
#          9.6282e-01, 1.2907e-06, 3.6684e-02, 1.5197e-05],
#         [3.9297e-04, 1.2510e-03, 1.2825e-06, 2.2968e-04, 4.5200e-05, 9.8975e-01,
#          2.0814e-03, 3.7020e-03, 1.2054e-04, 2.4231e-03],
#         [1.3688e-04, 3.7912e-02, 1.7766e-04, 5.6577e-05, 4.6642e-05, 1.2286e-04,
#          2.1703e-03, 9.4916e-01, 4.0674e-07, 1.0219e-02],
#         [4.3011e-04, 6.2437e-02, 1.2518e-03, 8.2366e-01, 1.0604e-04, 1.9148e-04,
#          1.3218e-02, 4.1728e-03, 3.5736e-04, 9.4179e-02],
#         [2.1924e-06, 7.1641e-06, 6.1455e-05, 2.5312e-04, 7.6048e-05, 8.6542e-06,
#          1.7414e-04, 1.6935e-05, 9.9940e-01, 2.1997e-07],
#         [8.4363e-07, 2.3833e-04, 4.4936e-07, 9.9968e-01, 3.8536e-08, 1.0815e-05,
#          2.9655e-05, 1.6130e-05, 9.6912e-06, 1.6760e-05],
#         [3.1151e-02, 2.1801e-01, 5.2121e-02, 4.7900e-01, 5.3799e-03, 4.1074e-02,
#          7.6842e-02, 2.7853e-02, 6.5958e-02, 2.6168e-03],
#         [1.2288e-05, 2.8292e-04, 9.0296e-05, 8.9647e-05, 2.8645e-04, 3.1951e-06,
#          1.2703e-02, 2.1283e-05, 9.8637e-01, 1.4178e-04],
#         [9.9248e-01, 7.0214e-04, 6.0645e-03, 1.4889e-05, 3.7713e-05, 1.0936e-04,
#          4.3480e-04, 8.6517e-05, 2.5238e-05, 4.6540e-05],
#         [8.8627e-03, 8.9043e-01, 7.3819e-02, 8.7174e-05, 1.5423e-03, 1.6144e-03,
#          1.8110e-03, 7.8415e-04, 1.7967e-02, 3.0782e-03],
#         [4.6401e-05, 2.1339e-05, 9.9954e-01, 1.2540e-05, 3.4796e-05, 1.0441e-04,
#          7.8993e-06, 2.3272e-06, 3.8310e-05, 1.8969e-04]], device='cuda:0')  Target  tensor([2, 6, 1, 5, 3, 6, 5, 7, 3, 8, 3, 1, 8, 0, 2, 2], device='cuda:0')
# Prediction  tensor([[3.5118e-03, 9.6067e-06, 9.8839e-01, 2.7879e-05, 1.4308e-04, 5.2032e-05,
#          3.6315e-04, 3.2492e-03, 4.2301e-03, 2.5552e-05],
#         [3.7802e-05, 1.3317e-03, 3.7027e-05, 9.9045e-01, 4.2933e-03, 7.4567e-04,
#          2.9623e-03, 6.3545e-06, 1.2148e-04, 1.2510e-05],
#         [1.9904e-04, 1.5177e-03, 1.6020e-04, 1.3183e-05, 3.6204e-05, 1.5153e-05,
#          1.0787e-06, 9.9728e-01, 1.8685e-06, 7.7323e-04],
#         [2.7357e-04, 1.3150e-02, 8.9837e-04, 2.9093e-01, 6.1036e-03, 3.3648e-03,
#          1.1285e-03, 6.7257e-01, 1.0341e-03, 1.0554e-02],
#         [9.0863e-05, 1.3274e-03, 1.6174e-02, 1.9122e-05, 9.6269e-01, 1.8719e-04,
#          2.2865e-03, 9.3993e-07, 1.7215e-02, 4.9024e-06],
#         [2.4175e-04, 7.3495e-01, 1.0433e-03, 2.2767e-01, 4.8093e-03, 7.3204e-04,
#          1.2717e-02, 4.4040e-03, 2.4146e-07, 1.3424e-02],
#         [3.8199e-05, 2.2922e-03, 4.0974e-06, 4.0065e-05, 3.1374e-06, 9.8276e-07,
#          1.0477e-06, 9.9758e-01, 9.1522e-06, 2.8885e-05],
#         [5.4072e-03, 2.9165e-02, 1.0687e-02, 4.0611e-03, 1.0371e-02, 2.3994e-02,
#          4.9583e-05, 9.1145e-01, 6.0470e-04, 4.2135e-03],
#         [1.2111e-02, 9.0476e-01, 3.6163e-03, 1.8001e-04, 2.4175e-03, 2.6367e-02,
#          4.7138e-02, 2.6256e-05, 5.8869e-05, 3.3272e-03],
#         [7.0013e-06, 3.9604e-03, 1.1507e-05, 1.8452e-04, 1.2335e-04, 5.6188e-06,
#          1.1406e-01, 6.4768e-07, 8.8157e-01, 7.8284e-05],
#         [9.7856e-01, 4.5089e-03, 2.0240e-04, 3.5913e-04, 3.8411e-06, 7.8556e-04,
#          5.0543e-06, 4.6879e-05, 1.4916e-02, 6.1404e-04],
#         [1.0120e-03, 3.5232e-02, 3.6418e-04, 8.3409e-01, 1.7016e-04, 1.3817e-05,
#          9.9041e-03, 5.1556e-05, 1.1915e-01, 7.1923e-06],
#         [1.0056e-03, 1.3556e-03, 6.0171e-04, 5.9715e-05, 3.9566e-05, 9.4535e-03,
#          1.3390e-03, 1.0389e-05, 4.7700e-07, 9.8613e-01],
#         [3.0112e-04, 1.6415e-03, 1.0636e-01, 5.6448e-03, 8.5957e-03, 3.3837e-02,
#          7.5158e-03, 3.6556e-02, 7.9946e-01, 8.4816e-05],
#         [7.3367e-05, 9.9694e-06, 9.9975e-01, 1.0649e-07, 6.1982e-05, 6.1170e-06,
#          6.4837e-06, 5.0259e-06, 4.0211e-05, 4.4342e-05],
#         [3.4543e-04, 7.2372e-02, 8.2031e-03, 1.5369e-04, 4.8828e-04, 7.2969e-04,
#          4.8570e-04, 9.1543e-01, 2.8380e-05, 1.7588e-03]], device='cuda:0')  Target  tensor([2, 3, 7, 7, 4, 1, 7, 7, 1, 8, 0, 3, 9, 8, 2, 7], device='cuda:0')
# Prediction  tensor([[9.9375e-01, 1.4957e-03, 1.4207e-04, 2.4396e-05, 1.7098e-05, 3.0580e-03,
#          3.0362e-04, 4.7408e-05, 1.9885e-05, 1.1433e-03],
#         [2.8474e-03, 3.0734e-04, 4.0133e-05, 2.8951e-03, 7.1495e-05, 7.3547e-05,
#          9.9066e-01, 7.0762e-05, 3.7822e-05, 2.9942e-03],
#         [1.3903e-01, 6.2958e-01, 1.4092e-02, 1.9780e-03, 7.4327e-04, 9.9344e-02,
#          4.4419e-03, 6.2834e-02, 3.8836e-02, 9.1127e-03],
#         [5.3180e-01, 5.8068e-02, 9.0724e-02, 5.7141e-03, 1.4756e-03, 4.0279e-02,
#          1.1261e-04, 2.6351e-01, 4.4202e-04, 7.8720e-03],
#         [2.8247e-03, 9.3233e-01, 2.5495e-03, 7.2335e-03, 2.2322e-05, 1.7368e-02,
#          7.7030e-03, 5.5672e-04, 1.0266e-03, 2.8387e-02],
#         [5.7279e-05, 1.8658e-04, 2.7139e-04, 1.9490e-06, 1.3161e-04, 3.4424e-05,
#          2.4290e-04, 1.5467e-05, 4.2722e-04, 9.9863e-01],
#         [5.2971e-02, 3.2962e-02, 1.1887e-01, 1.9718e-02, 8.0641e-02, 3.0519e-03,
#          6.8978e-04, 5.8797e-01, 2.0009e-04, 1.0293e-01],
#         [5.5473e-06, 7.9670e-04, 2.0029e-06, 9.9915e-01, 5.2496e-08, 3.5855e-05,
#          2.2386e-06, 4.2780e-06, 4.8581e-06, 1.2408e-06],
#         [4.6765e-05, 9.0102e-06, 9.9982e-01, 3.6870e-06, 5.8587e-05, 2.8791e-06,
#          6.9605e-07, 5.2462e-05, 7.9316e-06, 2.6104e-06],
#         [1.5755e-02, 4.8237e-04, 1.1865e-02, 5.6155e-05, 9.4512e-01, 1.3991e-05,
#          2.5841e-02, 4.2174e-04, 1.0095e-04, 3.4127e-04],
#         [5.4579e-04, 2.0535e-04, 1.0156e-02, 1.8428e-03, 2.7699e-04, 4.1437e-05,
#          8.4860e-04, 2.5419e-03, 9.8349e-01, 5.0284e-05],
#         [2.9018e-02, 7.3661e-02, 4.1301e-03, 1.2904e-01, 6.9733e-01, 2.6790e-02,
#          1.9703e-02, 1.1562e-02, 1.1623e-05, 8.7580e-03],
#         [4.3470e-01, 1.3073e-02, 3.0766e-01, 7.8904e-04, 2.4461e-02, 1.3728e-01,
#          2.7419e-05, 1.4857e-02, 6.4646e-02, 2.5003e-03],
#         [2.4236e-04, 8.3354e-04, 9.3162e-04, 6.9112e-05, 9.9297e-01, 4.8139e-03,
#          3.2288e-05, 5.1444e-06, 5.8528e-05, 4.7704e-05],
#         [8.4558e-01, 6.0959e-05, 6.2695e-02, 1.5849e-05, 8.4100e-02, 8.6081e-06,
#          7.1336e-05, 5.2596e-03, 1.7254e-03, 4.8057e-04],
#         [1.0816e-05, 7.8602e-06, 6.1235e-06, 1.2172e-05, 2.0373e-05, 9.9913e-01,
#          3.7352e-04, 3.5197e-07, 4.3660e-04, 6.4737e-06]], device='cuda:0')  Target  tensor([0, 6, 0, 5, 1, 9, 7, 3, 2, 4, 8, 4, 0, 4, 0, 5], device='cuda:0')
# Prediction  tensor([[2.3479e-04, 9.9673e-01, 2.1371e-05, 5.2947e-04, 1.9445e-05, 9.1967e-06,
#          2.6831e-04, 2.0564e-03, 1.7051e-05, 1.1211e-04],
#         [5.0420e-03, 4.4683e-01, 2.0962e-02, 2.4665e-01, 6.1531e-05, 1.0968e-01,
#          2.1896e-02, 1.3094e-05, 1.2126e-01, 2.7605e-02],
#         [4.6634e-01, 1.1784e-01, 3.3520e-03, 1.5637e-02, 3.3856e-03, 6.2286e-03,
#          2.6232e-01, 9.9806e-03, 4.3351e-06, 1.1491e-01],
#         [9.5487e-01, 2.9824e-03, 2.7753e-03, 5.4228e-03, 7.8344e-03, 2.4279e-04,
#          6.7618e-03, 1.9622e-04, 5.5016e-03, 1.3411e-02],
#         [1.4498e-06, 2.9480e-06, 2.5717e-04, 3.5466e-05, 6.5002e-04, 1.0977e-04,
#          1.4297e-02, 1.2165e-05, 9.8463e-01, 7.8759e-08],
#         [2.2124e-05, 9.9948e-01, 3.0439e-06, 1.5971e-05, 1.4487e-05, 2.5270e-08,
#          4.5088e-04, 5.6178e-06, 1.1637e-06, 6.4079e-06],
#         [9.9096e-01, 1.5835e-04, 4.5170e-04, 8.8626e-04, 8.4682e-06, 3.8811e-04,
#          5.3441e-04, 4.0552e-03, 5.2729e-05, 2.5087e-03],
#         [8.1716e-04, 5.5350e-03, 8.6689e-01, 2.7182e-04, 3.8441e-02, 7.5342e-04,
#          6.1328e-02, 5.6336e-05, 2.5893e-02, 1.6904e-05],
#         [1.0144e-03, 2.1482e-03, 1.1431e-05, 1.7918e-06, 1.2909e-05, 5.8476e-05,
#          3.2622e-05, 1.5824e-04, 2.4843e-06, 9.9656e-01],
#         [6.5149e-03, 9.7349e-01, 6.0354e-04, 2.4431e-04, 9.0116e-06, 5.3156e-04,
#          2.7639e-04, 1.7220e-02, 1.7756e-05, 1.0967e-03],
#         [8.0295e-06, 7.6609e-04, 1.0616e-04, 8.7572e-06, 3.2169e-04, 1.8390e-05,
#          1.9149e-04, 9.2152e-05, 9.9848e-01, 3.1111e-06],
#         [1.7727e-03, 3.0994e-03, 6.4826e-03, 3.2589e-05, 9.8816e-01, 3.0375e-04,
#          8.1126e-05, 3.5753e-06, 1.9921e-05, 4.9192e-05],
#         [1.9105e-01, 9.6004e-03, 2.5311e-02, 1.7885e-01, 1.2057e-05, 4.1334e-04,
#          2.9919e-02, 3.9786e-03, 5.6355e-05, 5.6081e-01],
#         [4.7064e-04, 7.5465e-05, 5.8377e-04, 2.3234e-05, 5.7566e-04, 2.7378e-04,
#          9.9797e-01, 2.5797e-07, 1.9147e-05, 9.0927e-06],
#         [2.1249e-04, 8.8589e-01, 1.0392e-05, 5.3658e-04, 8.3395e-02, 1.1002e-02,
#          3.7592e-03, 2.3834e-03, 4.1833e-04, 1.2388e-02],
#         [1.3130e-04, 6.9936e-03, 1.0099e-04, 3.0096e-01, 6.6716e-01, 3.4510e-03,
#          5.9356e-04, 2.9086e-05, 4.7764e-03, 1.5808e-02]], device='cuda:0')  Target  tensor([1, 5, 6, 0, 8, 1, 0, 2, 9, 1, 8, 4, 9, 6, 1, 4], device='cuda:0')
# Prediction  tensor([[1.4221e-02, 1.8012e-02, 6.7908e-04, 2.1260e-04, 8.5295e-06, 3.5251e-04,
#          3.1473e-03, 5.9714e-03, 2.9118e-05, 9.5737e-01],
#         [8.7467e-05, 2.6701e-03, 9.9309e-01, 2.0509e-06, 3.6054e-05, 3.2200e-04,
#          4.7818e-06, 6.5741e-04, 3.2539e-04, 2.8036e-03],
#         [4.3734e-04, 4.3220e-02, 1.0021e-03, 2.1710e-04, 9.6387e-04, 9.4748e-01,
#          3.6138e-03, 9.0436e-04, 1.9412e-03, 2.2319e-04],
#         [9.7025e-06, 2.8177e-04, 7.1056e-07, 1.0490e-03, 2.0180e-06, 4.3331e-07,
#          9.9857e-01, 1.3575e-06, 7.3040e-05, 8.3300e-06],
#         [2.6332e-04, 6.1821e-03, 2.5174e-04, 1.1611e-05, 9.9288e-01, 2.6788e-04,
#          2.9154e-05, 3.4205e-05, 7.4063e-05, 6.6443e-06],
#         [2.7280e-05, 9.9956e-01, 9.3810e-05, 4.7236e-05, 1.0324e-06, 8.0166e-07,
#          1.1292e-04, 4.4706e-06, 4.9213e-06, 1.4803e-04],
#         [5.7423e-05, 4.1464e-04, 4.0475e-06, 9.7131e-01, 1.6456e-07, 1.2283e-06,
#          2.8190e-02, 5.1925e-06, 1.4221e-05, 5.7643e-06],
#         [1.7534e-04, 5.7117e-05, 1.0027e-04, 1.3940e-05, 5.4529e-06, 9.9937e-01,
#          2.4887e-04, 2.1946e-06, 3.6931e-07, 2.6284e-05],
#         [3.3056e-06, 2.5617e-04, 2.5467e-03, 9.9714e-07, 3.1046e-06, 1.3385e-05,
#          6.9225e-06, 9.0086e-07, 9.9716e-01, 3.7596e-06],
#         [1.3725e-05, 9.9922e-01, 2.1336e-04, 1.1375e-04, 3.7359e-05, 3.1995e-05,
#          3.5562e-05, 3.2582e-04, 9.5032e-08, 8.4666e-06],
#         [9.8881e-06, 3.1226e-06, 9.5395e-05, 4.8224e-04, 2.1214e-04, 5.1612e-06,
#          2.8126e-01, 2.1549e-05, 7.1791e-01, 1.5567e-06],
#         [6.0011e-05, 2.7596e-02, 3.8810e-06, 5.8490e-05, 1.5275e-06, 3.2758e-06,
#          1.3573e-04, 9.7212e-01, 4.5153e-06, 1.7112e-05],
#         [2.4342e-01, 6.0724e-04, 1.5821e-05, 7.0204e-01, 8.2398e-05, 1.7747e-06,
#          4.9333e-02, 1.0487e-03, 1.1147e-03, 2.3377e-03],
#         [7.0309e-05, 4.9672e-03, 5.4336e-04, 5.9159e-05, 4.5365e-03, 1.8042e-04,
#          6.4067e-04, 1.1190e-03, 9.8785e-01, 3.6361e-05],
#         [8.5003e-02, 7.5138e-01, 1.1524e-02, 1.1236e-01, 2.0406e-02, 2.5175e-03,
#          9.5263e-03, 5.2854e-04, 2.3272e-05, 6.7276e-03],
#         [9.9890e-01, 2.2697e-05, 2.0321e-05, 1.8183e-05, 1.8640e-05, 4.9495e-07,
#          1.9320e-04, 4.1715e-05, 4.3468e-06, 7.8119e-04]], device='cuda:0')  Target  tensor([9, 2, 5, 6, 4, 1, 3, 5, 8, 1, 8, 7, 3, 8, 1, 0], device='cuda:0')
# Prediction  tensor([[1.6090e-02, 1.6178e-02, 2.5560e-02, 5.6329e-05, 9.3263e-01, 3.4294e-03,
#          3.0247e-03, 7.1116e-04, 2.1158e-03, 2.0247e-04],
#         [1.1121e-03, 9.5018e-01, 6.7392e-06, 2.7939e-02, 3.2083e-06, 3.4154e-04,
#          1.6497e-02, 4.4215e-06, 7.0265e-05, 3.8488e-03],
#         [1.8466e-04, 9.9430e-01, 2.6720e-05, 5.1286e-04, 1.2182e-05, 2.5224e-06,
#          1.3254e-03, 6.1472e-05, 4.5439e-04, 3.1191e-03],
#         [1.7419e-03, 9.9477e-01, 1.3773e-05, 3.1693e-03, 8.0007e-07, 1.3356e-06,
#          2.8422e-04, 9.7024e-08, 1.5704e-05, 4.1644e-06],
#         [9.5459e-01, 3.5725e-03, 2.3868e-04, 1.2039e-03, 2.8739e-04, 5.5964e-07,
#          3.8599e-02, 5.7819e-04, 5.3668e-05, 8.7276e-04],
#         [1.2592e-04, 3.0714e-04, 4.8581e-05, 9.8444e-04, 7.9893e-03, 4.9687e-05,
#          9.9034e-01, 4.6212e-05, 1.0281e-04, 3.4307e-06],
#         [7.0830e-07, 1.1314e-04, 1.7732e-06, 2.1813e-06, 6.6908e-06, 9.9987e-01,
#          1.2306e-06, 2.6483e-07, 1.9323e-07, 4.4646e-07],
#         [3.6203e-04, 1.1472e-03, 1.8912e-02, 1.8086e-04, 6.8782e-04, 9.5368e-01,
#          1.4817e-04, 2.4542e-02, 3.0717e-04, 3.3770e-05],
#         [1.9507e-06, 4.3055e-03, 9.9447e-01, 3.2497e-06, 9.1914e-05, 5.9265e-04,
#          1.9781e-06, 4.2265e-04, 5.3101e-05, 5.6428e-05],
#         [7.8474e-05, 1.8956e-06, 9.9679e-01, 2.1827e-06, 2.5810e-04, 1.1140e-06,
#          7.2525e-04, 2.1258e-03, 8.4340e-07, 1.9313e-05],
#         [1.2599e-06, 2.0595e-06, 3.3561e-05, 3.1382e-07, 1.8864e-05, 4.1598e-05,
#          9.9218e-01, 1.2007e-05, 7.7096e-03, 5.9571e-08],
#         [4.6060e-06, 5.6962e-06, 4.7863e-05, 6.2569e-05, 9.9941e-01, 1.8869e-07,
#          2.5764e-04, 3.5086e-06, 2.0561e-04, 4.7765e-07],
#         [8.2326e-07, 8.4776e-05, 4.2078e-05, 7.0224e-07, 3.9150e-06, 5.7829e-07,
#          9.9985e-01, 2.2806e-06, 1.4052e-05, 9.4360e-09],
#         [5.6995e-06, 5.4009e-04, 3.6612e-07, 1.8167e-03, 7.6799e-05, 1.4561e-05,
#          2.5744e-04, 3.8499e-06, 9.9728e-01, 2.5228e-07],
#         [7.6701e-05, 1.3624e-04, 7.1057e-03, 4.1710e-05, 8.8180e-04, 4.8090e-05,
#          1.3856e-06, 4.3603e-05, 9.9124e-01, 4.2738e-04],
#         [4.2753e-05, 1.1634e-03, 1.5745e-03, 1.0938e-05, 9.9656e-01, 6.0926e-05,
#          1.5578e-04, 3.8331e-04, 1.3976e-05, 3.1886e-05]], device='cuda:0')  Target  tensor([4, 1, 1, 1, 0, 6, 5, 5, 2, 2, 6, 4, 6, 8, 8, 4], device='cuda:0')
# Prediction  tensor([[2.2080e-04, 3.7764e-02, 1.9120e-02, 1.8145e-04, 3.3842e-03, 9.3833e-01,
#          1.1146e-05, 2.2684e-05, 8.5959e-05, 8.7915e-04],
#         [2.7205e-04, 9.9138e-01, 7.1994e-04, 3.4729e-06, 1.1377e-03, 4.8653e-03,
#          1.3121e-03, 2.1457e-06, 1.7730e-04, 1.3018e-04],
#         [2.2888e-02, 4.3233e-02, 9.3873e-05, 4.3188e-03, 3.3653e-05, 9.2575e-01,
#          1.8094e-03, 8.8102e-04, 9.8259e-04, 1.4418e-05],
#         [1.7006e-04, 7.6313e-02, 7.3018e-02, 8.2721e-05, 7.1443e-03, 1.5660e-02,
#          1.0824e-03, 3.7109e-05, 8.2640e-01, 9.5214e-05],
#         [4.6779e-06, 9.9892e-01, 9.9035e-05, 2.3784e-04, 1.7223e-06, 6.4456e-04,
#          9.0263e-07, 7.2804e-05, 7.8215e-06, 1.3493e-05],
#         [9.8458e-01, 3.9952e-04, 1.2262e-04, 2.6444e-05, 3.6612e-06, 1.4856e-02,
#          7.7045e-07, 3.3895e-07, 5.7384e-07, 9.3110e-06],
#         [1.7087e-06, 5.8565e-03, 6.2966e-05, 9.4121e-01, 1.1522e-02, 1.9175e-02,
#          7.8252e-03, 3.0661e-05, 8.9247e-05, 1.4231e-02],
#         [1.4295e-02, 2.1091e-03, 2.5689e-02, 8.0381e-01, 2.8600e-04, 6.9717e-06,
#          4.7005e-03, 1.1792e-01, 3.1173e-02, 9.2572e-06],
#         [3.2380e-06, 1.0140e-03, 1.6615e-04, 3.9700e-04, 4.6518e-06, 4.2622e-05,
#          1.0937e-02, 9.6074e-05, 9.8733e-01, 5.4949e-06],
#         [1.9524e-03, 1.5842e-01, 2.9651e-02, 6.5565e-02, 9.6025e-02, 6.9062e-03,
#          1.0572e-01, 1.8090e-04, 5.1114e-01, 2.4440e-02],
#         [3.0359e-04, 2.9807e-06, 9.9759e-01, 6.2994e-07, 1.5178e-05, 3.0760e-07,
#          1.6443e-06, 2.0648e-03, 1.9107e-06, 1.5155e-05],
#         [5.3670e-04, 4.8891e-02, 3.0744e-07, 8.0576e-05, 1.9433e-06, 2.2225e-07,
#          9.5008e-01, 7.0777e-05, 2.7161e-04, 7.2034e-05],
#         [4.5807e-04, 2.6626e-05, 6.6492e-04, 1.5981e-03, 1.9829e-05, 5.4463e-07,
#          9.2646e-01, 6.4997e-06, 7.0767e-02, 8.1332e-07],
#         [1.2907e-03, 2.8247e-02, 1.9237e-02, 3.9873e-04, 1.3957e-04, 1.4287e-01,
#          1.5202e-03, 1.2778e-06, 8.0533e-01, 9.6598e-04],
#         [7.0395e-04, 2.2172e-02, 1.3326e-03, 9.6403e-01, 1.6624e-03, 1.5168e-04,
#          5.3771e-03, 6.6589e-04, 2.9424e-04, 3.6113e-03],
#         [7.5865e-02, 1.0043e-03, 9.1169e-01, 9.6269e-06, 1.7995e-03, 5.7178e-03,
#          4.6679e-05, 7.5393e-04, 2.6408e-05, 3.0835e-03]], device='cuda:0')  Target  tensor([5, 1, 5, 2, 1, 0, 3, 3, 8, 8, 2, 6, 6, 8, 3, 2], device='cuda:0')
# Prediction  tensor([[1.3555e-03, 5.1062e-01, 6.9714e-05, 3.8196e-03, 1.4977e-05, 6.4677e-03,
#          4.6620e-01, 9.6706e-06, 6.1504e-04, 1.0822e-02],
#         [5.0861e-03, 8.2322e-03, 4.6069e-03, 2.1513e-03, 1.4198e-02, 3.9168e-01,
#          2.2701e-01, 6.1950e-03, 3.3866e-01, 2.1784e-03],
#         [6.2984e-04, 1.4241e-04, 9.6973e-01, 1.6591e-04, 2.0879e-02, 2.8702e-03,
#          3.7230e-05, 4.1702e-05, 2.1470e-04, 5.2905e-03],
#         [3.2463e-06, 1.7468e-06, 1.6144e-06, 5.8078e-07, 1.2029e-07, 9.9985e-01,
#          1.4066e-04, 1.1156e-08, 1.4068e-06, 3.2368e-07],
#         [5.8257e-05, 5.4244e-04, 5.3888e-04, 7.1422e-03, 1.5003e-05, 2.9945e-04,
#          9.7907e-01, 1.2091e-06, 1.2126e-02, 2.0355e-04],
#         [1.8873e-06, 8.1935e-08, 9.9965e-01, 2.5525e-07, 2.1072e-04, 2.4729e-05,
#          8.8778e-08, 5.5684e-07, 9.3634e-07, 1.0655e-04],
#         [3.1558e-04, 8.0728e-03, 2.3342e-02, 3.2903e-03, 8.2410e-04, 3.1065e-04,
#          2.3016e-05, 9.6111e-01, 2.9905e-06, 2.7126e-03],
#         [8.1973e-01, 4.8280e-03, 7.9555e-04, 3.0805e-02, 2.4635e-03, 1.5709e-04,
#          7.2931e-05, 1.3090e-01, 8.6382e-05, 1.0167e-02],
#         [4.6528e-03, 1.6189e-01, 1.3730e-02, 4.8966e-02, 1.4519e-02, 5.8439e-03,
#          6.9758e-01, 5.0127e-03, 9.7723e-03, 3.8033e-02],
#         [9.7022e-04, 5.7490e-05, 5.4341e-01, 6.6086e-03, 2.2637e-02, 5.6250e-05,
#          1.2212e-05, 4.2379e-01, 8.2007e-04, 1.6428e-03],
#         [9.5687e-01, 3.1681e-04, 3.5591e-05, 7.9420e-04, 2.5095e-05, 6.4847e-07,
#          2.6452e-04, 4.1642e-02, 1.5725e-05, 3.1515e-05],
#         [1.4442e-03, 9.9490e-01, 2.3705e-05, 1.4625e-04, 1.9573e-05, 1.2956e-03,
#          2.5951e-04, 6.3486e-05, 1.7453e-04, 1.6712e-03],
#         [6.9693e-06, 6.3202e-06, 4.1684e-07, 1.2987e-05, 4.8738e-07, 9.9976e-01,
#          2.0420e-04, 6.6987e-07, 5.5706e-06, 3.4498e-07],
#         [1.0605e-02, 4.4669e-02, 9.2174e-01, 8.5185e-06, 4.6639e-04, 7.0559e-04,
#          2.1049e-03, 3.1296e-03, 4.3620e-04, 1.6135e-02],
#         [1.4695e-05, 3.6146e-05, 2.2166e-05, 6.2214e-05, 1.8425e-02, 1.3997e-03,
#          1.9231e-03, 2.0127e-04, 9.7791e-01, 2.6862e-06],
#         [1.2490e-03, 5.6323e-05, 5.3730e-04, 2.7272e-03, 5.5016e-03, 2.1293e-05,
#          1.0260e-05, 9.8936e-01, 1.6578e-06, 5.3119e-04]], device='cuda:0')  Target  tensor([6, 8, 2, 5, 6, 2, 7, 0, 6, 7, 0, 1, 5, 2, 8, 7], device='cuda:0')
# Prediction  tensor([[1.4290e-03, 1.9696e-02, 4.0284e-05, 9.8685e-04, 7.1922e-03, 9.6434e-01,
#          1.9359e-03, 1.0200e-03, 7.9301e-04, 2.5663e-03],
#         [1.7378e-05, 8.9487e-05, 1.1570e-04, 4.4199e-05, 9.9065e-01, 2.6519e-04,
#          8.3833e-05, 7.3488e-03, 1.3805e-03, 8.1074e-06],
#         [5.4290e-01, 3.2870e-01, 5.1407e-03, 3.9445e-03, 5.5505e-02, 3.8495e-03,
#          3.6977e-02, 9.2885e-04, 1.2640e-03, 2.0798e-02],
#         [9.7913e-05, 4.5664e-05, 3.5016e-03, 3.8204e-06, 6.2789e-05, 2.7068e-04,
#          9.2448e-01, 1.2933e-05, 7.1527e-02, 5.7697e-07],
#         [8.5958e-06, 2.1551e-04, 2.7323e-04, 1.7570e-05, 6.5843e-06, 1.1665e-04,
#          1.0966e-05, 2.4656e-06, 9.9921e-01, 1.3594e-04],
#         [4.3387e-03, 8.6016e-01, 3.0913e-05, 4.2399e-03, 6.3800e-05, 7.0798e-04,
#          4.2583e-04, 1.2971e-01, 2.9058e-05, 2.8945e-04],
#         [5.3096e-05, 5.2259e-03, 9.7829e-01, 7.0302e-04, 1.6621e-05, 4.4324e-03,
#          1.0378e-02, 3.4591e-05, 6.2334e-04, 2.3918e-04],
#         [4.3530e-03, 1.0429e-03, 3.5083e-03, 6.0562e-04, 2.9333e-04, 5.7738e-05,
#          3.2291e-05, 9.8944e-01, 5.0208e-05, 6.1927e-04],
#         [1.6302e-04, 2.2308e-03, 1.0049e-01, 4.1313e-04, 9.5675e-03, 1.0794e-01,
#          1.8413e-03, 7.9815e-05, 7.6458e-01, 1.2694e-02],
#         [9.9634e-01, 1.0895e-04, 7.2721e-07, 3.4437e-04, 4.0818e-07, 9.5876e-07,
#          3.1824e-03, 3.0894e-06, 1.5067e-05, 8.3377e-06],
#         [2.7049e-04, 8.5486e-05, 3.7554e-06, 9.9297e-01, 8.9086e-07, 2.3116e-06,
#          5.7591e-03, 6.6822e-04, 2.4060e-04, 1.1708e-06],
#         [1.4061e-03, 9.5170e-01, 1.3372e-05, 4.0523e-02, 5.8554e-06, 2.3386e-03,
#          3.6771e-04, 1.8486e-03, 3.4137e-04, 1.4569e-03],
#         [3.3928e-03, 2.0636e-01, 1.2731e-02, 4.5694e-01, 4.6735e-02, 3.2027e-02,
#          2.3403e-01, 1.0010e-04, 5.3235e-03, 2.3553e-03],
#         [2.1918e-05, 1.3765e-02, 2.4330e-04, 8.9187e-05, 5.4967e-06, 3.0871e-04,
#          5.5213e-05, 9.8354e-01, 1.8348e-07, 1.9722e-03],
#         [2.9993e-05, 1.3975e-04, 6.5790e-04, 2.2567e-03, 4.8093e-05, 3.0728e-05,
#          2.8527e-04, 1.8347e-03, 5.0326e-06, 9.9471e-01],
#         [9.2371e-03, 1.4822e-01, 1.8214e-02, 3.6969e-03, 1.9661e-03, 5.0585e-03,
#          1.3794e-01, 6.7150e-01, 3.8162e-03, 3.4946e-04]], device='cuda:0')  Target  tensor([5, 4, 0, 6, 8, 1, 2, 7, 8, 0, 3, 1, 3, 7, 9, 7], device='cuda:0')
# Prediction  tensor([[6.4414e-04, 1.5479e-01, 2.9783e-02, 1.5219e-02, 6.0852e-02, 1.8660e-03,
#          1.7006e-03, 1.4098e-04, 7.3479e-01, 2.1178e-04],
#         [9.8669e-01, 4.8021e-04, 1.2116e-02, 8.8495e-06, 9.2181e-06, 2.8864e-04,
#          6.6161e-06, 5.2339e-05, 3.4689e-04, 3.8690e-06],
#         [1.1612e-02, 1.9745e-01, 1.3825e-02, 1.2823e-01, 1.0095e-03, 5.6980e-01,
#          3.2799e-02, 3.1360e-02, 1.6824e-03, 1.2233e-02],
#         [3.0155e-04, 1.3182e-01, 1.9622e-03, 1.3661e-03, 2.1690e-05, 1.1560e-01,
#          7.0737e-01, 1.5870e-05, 4.6312e-04, 4.1091e-02],
#         [2.9870e-05, 2.1586e-04, 6.2044e-03, 1.6126e-04, 8.1594e-05, 9.9276e-01,
#          2.0512e-04, 4.6268e-05, 2.9071e-04, 2.5318e-06],
#         [3.4666e-05, 4.1273e-05, 1.2982e-06, 7.3768e-04, 2.7666e-06, 1.7259e-04,
#          9.9876e-01, 1.2582e-04, 5.4686e-08, 1.1886e-04],
#         [1.7758e-05, 5.7053e-05, 9.9021e-01, 9.8850e-06, 7.1236e-03, 7.5505e-05,
#          8.3732e-05, 1.4887e-05, 4.6510e-04, 1.9407e-03],
#         [3.7742e-05, 1.3665e-02, 7.5636e-03, 2.0909e-02, 1.4682e-04, 5.6524e-02,
#          2.8449e-04, 3.9626e-05, 1.6232e-05, 9.0081e-01],
#         [8.6578e-01, 1.7613e-04, 1.8242e-04, 4.1527e-04, 3.7623e-05, 8.6742e-07,
#          3.5674e-04, 1.3300e-01, 2.3014e-05, 3.4792e-05],
#         [1.4336e-01, 1.1998e-01, 4.8857e-03, 1.8152e-01, 3.7490e-03, 4.6204e-02,
#          1.3200e-01, 3.3723e-01, 2.9558e-02, 1.5079e-03],
#         [9.8550e-01, 2.2856e-03, 1.6973e-05, 4.5570e-03, 4.8766e-06, 4.0665e-06,
#          5.7933e-05, 6.2128e-03, 1.3487e-03, 7.2249e-06],
#         [1.8683e-01, 6.4513e-03, 4.2967e-02, 1.1431e-01, 8.3425e-03, 2.2568e-04,
#          5.9032e-02, 5.8039e-01, 2.5661e-04, 1.1897e-03],
#         [6.7448e-05, 7.0516e-02, 4.8085e-05, 1.6838e-02, 5.9616e-05, 5.2963e-02,
#          1.6214e-02, 1.1371e-05, 8.7067e-05, 8.4320e-01],
#         [1.2984e-04, 7.5317e-04, 9.4562e-02, 3.9227e-06, 8.1839e-05, 3.5682e-05,
#          1.8607e-05, 9.0437e-01, 2.9806e-05, 1.6246e-05],
#         [1.2981e-03, 9.9646e-01, 2.2560e-04, 1.9360e-05, 1.5338e-04, 8.1702e-07,
#          1.5330e-03, 6.8373e-05, 1.4363e-06, 2.4338e-04],
#         [1.7243e-01, 4.4263e-01, 2.4922e-05, 3.8057e-01, 3.5914e-06, 5.1087e-04,
#          3.0893e-03, 1.8655e-04, 4.8968e-04, 5.6779e-05]], device='cuda:0')  Target  tensor([8, 0, 5, 6, 5, 6, 2, 9, 0, 3, 0, 7, 9, 2, 1, 1], device='cuda:0')
# Prediction  tensor([[5.2889e-06, 4.2891e-04, 8.4799e-05, 6.9046e-05, 2.3790e-04, 1.0362e-04,
#          2.5429e-05, 1.2803e-04, 1.7768e-06, 9.9892e-01],
#         [9.9951e-01, 4.4256e-05, 1.0214e-05, 2.1672e-05, 2.1949e-06, 3.9138e-04,
#          1.2420e-06, 7.7666e-06, 6.6963e-06, 5.3482e-06],
#         [9.0502e-05, 1.4245e-04, 2.7426e-03, 2.3415e-05, 9.9584e-01, 6.7912e-05,
#          1.0326e-03, 3.1747e-06, 5.6043e-05, 1.1301e-06],
#         [1.1320e-02, 3.5593e-01, 1.8808e-03, 1.4679e-02, 1.6365e-03, 8.5854e-03,
#          3.7570e-01, 1.8557e-02, 2.0999e-01, 1.7269e-03],
#         [5.7244e-05, 4.6090e-04, 6.8799e-06, 9.9908e-01, 1.2676e-06, 8.2848e-07,
#          5.7184e-05, 1.1962e-04, 1.3787e-04, 7.9668e-05],
#         [2.3308e-01, 7.9886e-02, 1.1045e-01, 3.7440e-02, 7.2278e-05, 6.9820e-06,
#          1.4720e-01, 1.1205e-01, 1.0166e-04, 2.7971e-01],
#         [1.9517e-04, 4.6664e-04, 9.8197e-02, 7.9594e-04, 1.1521e-02, 6.2797e-03,
#          2.8912e-04, 1.6725e-03, 8.8043e-01, 1.5229e-04],
#         [1.5514e-03, 1.6456e-05, 3.3623e-06, 3.6944e-04, 1.1109e-05, 2.6225e-07,
#          9.7353e-01, 7.8557e-05, 2.4419e-02, 1.8968e-05],
#         [9.3937e-02, 8.7472e-01, 6.5338e-03, 1.5148e-02, 4.4847e-04, 7.0622e-04,
#          9.5542e-04, 4.7744e-04, 3.0898e-05, 7.0460e-03],
#         [3.4926e-04, 1.0011e-04, 6.0774e-05, 2.5466e-04, 6.0707e-03, 3.1770e-05,
#          9.9196e-01, 6.9342e-07, 1.1754e-03, 1.1058e-06],
#         [1.2251e-02, 9.6267e-01, 3.7115e-06, 3.0198e-03, 3.9555e-06, 2.7935e-06,
#          6.4936e-03, 2.0734e-05, 5.7544e-06, 1.5525e-02],
#         [2.8692e-05, 2.3164e-04, 4.1323e-04, 9.0679e-06, 9.9447e-01, 2.0006e-04,
#          5.4528e-04, 1.5389e-04, 3.9227e-03, 2.1127e-05],
#         [5.9447e-04, 4.4330e-02, 3.6231e-03, 1.7524e-02, 2.2909e-06, 7.6061e-02,
#          8.4534e-01, 1.1509e-03, 1.0347e-02, 1.0256e-03],
#         [1.5289e-04, 2.9852e-02, 8.4353e-03, 7.8944e-06, 2.9112e-05, 8.2268e-05,
#          3.8268e-05, 9.6130e-01, 2.3220e-06, 9.8143e-05],
#         [1.2604e-06, 2.0318e-04, 1.2596e-07, 9.9861e-01, 6.4004e-08, 2.0133e-05,
#          1.0914e-03, 1.6578e-06, 9.4060e-06, 6.2021e-05],
#         [4.9163e-03, 8.2313e-04, 3.3801e-01, 5.8449e-06, 6.3390e-01, 1.1725e-02,
#          7.4221e-03, 9.3964e-05, 2.3770e-03, 7.2690e-04]], device='cuda:0')  Target  tensor([9, 0, 4, 8, 3, 9, 8, 6, 1, 6, 1, 4, 6, 7, 3, 4], device='cuda:0')
# Prediction  tensor([[3.2182e-03, 7.4298e-02, 4.1610e-03, 2.2588e-02, 8.8065e-01, 3.7317e-03,
#          1.1454e-03, 8.2453e-03, 1.6148e-03, 3.4724e-04],
#         [4.5756e-03, 1.1021e-01, 5.6316e-02, 3.5280e-04, 1.0057e-02, 5.6162e-03,
#          1.9089e-02, 3.1274e-03, 7.3462e-01, 5.6038e-02],
#         [8.9056e-03, 7.2058e-03, 1.8003e-03, 9.8552e-05, 1.1735e-02, 5.0803e-03,
#          1.3051e-04, 3.5305e-05, 4.6782e-05, 9.6496e-01],
#         [4.3630e-02, 7.0109e-04, 7.0499e-03, 2.8256e-03, 4.1343e-06, 7.1936e-06,
#          7.6826e-04, 9.4302e-01, 7.0820e-05, 1.9210e-03],
#         [2.6506e-02, 1.2728e-03, 9.3926e-01, 5.3540e-05, 7.2910e-04, 1.5286e-02,
#          3.5114e-04, 1.5973e-02, 1.5616e-05, 5.4994e-04],
#         [9.9994e-01, 2.5281e-05, 5.9654e-07, 3.0148e-05, 3.1537e-08, 1.1725e-06,
#          3.7896e-06, 7.8618e-07, 1.8810e-07, 2.7765e-07],
#         [1.9787e-04, 3.2932e-04, 2.2446e-05, 1.4655e-05, 2.9491e-05, 7.8602e-06,
#          5.0609e-06, 9.9892e-01, 4.4731e-07, 4.7404e-04],
#         [1.7007e-04, 7.0592e-04, 2.0081e-03, 4.8193e-04, 3.4257e-04, 2.6610e-02,
#          9.6846e-01, 2.8465e-05, 3.8543e-04, 8.0567e-04],
#         [2.1036e-03, 4.6971e-07, 3.4098e-05, 1.1636e-06, 3.5445e-06, 5.2864e-06,
#          3.5239e-04, 2.4729e-05, 7.3518e-07, 9.9747e-01],
#         [1.5846e-06, 1.6579e-04, 7.3559e-04, 1.9703e-04, 3.1880e-04, 3.7714e-04,
#          9.4151e-02, 6.2244e-07, 9.0393e-01, 1.1998e-04],
#         [1.0805e-03, 9.9810e-01, 1.5612e-07, 2.3635e-04, 1.7854e-06, 3.1974e-06,
#          4.1818e-04, 1.3017e-06, 2.0510e-05, 1.3531e-04],
#         [5.9272e-02, 4.1467e-03, 8.8945e-01, 2.0630e-03, 2.9004e-02, 7.3194e-04,
#          6.6809e-03, 2.6348e-03, 1.0577e-03, 4.9577e-03],
#         [1.0532e-04, 1.5270e-02, 6.3391e-04, 1.3135e-01, 7.2319e-04, 2.9676e-02,
#          1.1339e-04, 4.2786e-04, 3.9963e-03, 8.1770e-01],
#         [4.4459e-04, 1.0326e-04, 4.4238e-02, 2.0572e-05, 8.4923e-04, 1.6103e-02,
#          6.5663e-01, 2.2256e-03, 2.7938e-01, 1.7298e-06],
#         [2.4266e-02, 5.6109e-01, 7.5587e-03, 1.4811e-05, 5.4472e-04, 5.7982e-03,
#          1.4606e-04, 1.0692e-01, 2.9202e-01, 1.6424e-03],
#         [1.5264e-04, 5.9457e-04, 9.9232e-06, 2.3997e-06, 1.2314e-05, 9.9907e-01,
#          3.6163e-05, 3.2780e-05, 1.7275e-05, 7.5685e-05]], device='cuda:0')  Target  tensor([4, 8, 9, 7, 2, 0, 7, 6, 9, 8, 1, 2, 3, 6, 8, 5], device='cuda:0')
# Prediction  tensor([[5.2367e-02, 6.5429e-04, 4.3679e-01, 4.1359e-04, 3.0734e-02, 3.7488e-04,
#          4.2431e-05, 1.5775e-03, 2.0487e-02, 4.5656e-01],
#         [3.7515e-05, 4.3492e-04, 1.4586e-02, 2.5570e-04, 2.9647e-05, 3.8994e-05,
#          1.9924e-05, 7.9131e-04, 1.0607e-04, 9.8370e-01],
#         [3.6150e-04, 8.0167e-01, 3.4920e-05, 6.6270e-06, 1.2291e-05, 2.2821e-05,
#          1.9774e-01, 6.5124e-05, 7.1877e-05, 1.0699e-05],
#         [1.0425e-05, 2.2969e-04, 5.2963e-04, 4.4062e-06, 4.4053e-05, 1.2045e-06,
#          2.2434e-07, 3.8793e-05, 3.1292e-06, 9.9914e-01],
#         [1.7484e-05, 4.8045e-03, 2.2752e-04, 8.6636e-01, 7.0562e-05, 7.0508e-06,
#          4.4381e-02, 1.4486e-03, 8.2297e-02, 3.8604e-04],
#         [3.4794e-04, 1.4067e-03, 6.5473e-04, 9.8519e-01, 4.8043e-03, 6.3503e-03,
#          7.4235e-04, 1.9119e-04, 2.9966e-04, 1.4013e-05],
#         [4.4175e-06, 7.2043e-05, 1.2927e-05, 3.6266e-04, 9.9815e-01, 5.4008e-06,
#          1.4249e-04, 4.1738e-05, 1.2113e-03, 1.9241e-06],
#         [5.8022e-02, 1.6794e-02, 1.5589e-02, 2.8468e-01, 6.4585e-04, 1.7850e-01,
#          3.3271e-01, 6.8249e-02, 3.8533e-02, 6.2771e-03],
#         [4.6014e-05, 5.1594e-03, 9.8765e-07, 3.2054e-04, 3.9478e-05, 1.7556e-03,
# ...
#         [6.6651e-03, 2.0136e-02, 3.8585e-02, 1.9959e-05, 7.5858e-05, 9.9709e-03,
#          2.5357e-05, 9.2338e-01, 5.7917e-05, 1.0896e-03],
#         [5.8381e-04, 2.0696e-03, 9.9173e-01, 2.1034e-04, 4.7728e-04, 1.2041e-04,
#          4.6017e-06, 4.6217e-03, 1.5365e-04, 3.2526e-05],
#         [4.6556e-05, 7.0762e-02, 8.2358e-04, 1.1494e-03, 6.5505e-06, 4.1976e-04,
#          2.7591e-03, 3.6960e-05, 9.2399e-01, 1.1079e-05],
#         [4.2828e-03, 7.1597e-05, 7.3022e-02, 5.9833e-05, 8.7846e-04, 9.1186e-01,
#          3.6615e-04, 8.7584e-04, 4.8914e-04, 8.0948e-03],
#         [1.4513e-02, 1.0475e-03, 1.0769e-01, 4.1395e-05, 2.2838e-04, 2.9809e-04,
#          2.6552e-04, 8.7124e-01, 3.8877e-03, 7.8728e-04],
#         [9.7341e-04, 9.5773e-03, 1.1548e-02, 4.3089e-05, 9.7660e-01, 4.3581e-05,
#          5.5739e-05, 6.2107e-04, 1.4278e-04, 3.9808e-04],
#         [8.9694e-01, 1.7809e-02, 5.1352e-04, 6.0256e-03, 4.5567e-05, 1.2607e-02,
#          5.5135e-02, 1.0021e-02, 2.9491e-04, 6.0438e-04],
#         [2.6495e-03, 7.1289e-01, 6.9357e-03, 1.6222e-01, 1.0193e-01, 3.4085e-03,
#          3.6670e-03, 1.3613e-05, 4.3887e-03, 1.8949e-03],
#         [2.8315e-03, 3.0421e-02, 6.3651e-05, 3.3583e-03, 3.1673e-03, 2.4707e-02,
#          1.6918e-01, 2.2772e-01, 5.3837e-01, 1.8434e-04],
#         [5.2481e-05, 9.9591e-01, 4.6940e-05, 2.4273e-03, 5.3731e-06, 8.3612e-04,
#          1.8423e-06, 1.2087e-04, 5.0979e-04, 8.7919e-05],
#         [4.5009e-04, 1.9569e-03, 8.0313e-06, 2.1860e-04, 6.9389e-05, 7.5955e-05,
#          9.9665e-01, 4.0317e-05, 2.8522e-05, 5.0655e-04],
#         [9.9875e-01, 6.0947e-04, 1.9669e-05, 4.8081e-05, 4.0099e-06, 9.9240e-05,
#          3.1976e-06, 2.5123e-04, 9.3084e-06, 2.0427e-04],
#         [6.2147e-04, 4.5565e-02, 9.2975e-01, 5.5305e-04, 1.9665e-04, 8.5898e-03,
#          4.9461e-04, 8.3442e-03, 1.1588e-04, 5.7691e-03]], device='cuda:0')  Target  tensor([6, 5, 3, 7, 2, 8, 5, 7, 4, 0, 1, 8, 1, 6, 0, 2], device='cuda:0')
# Prediction  tensor([[3.4741e-02, 4.2864e-02, 5.4084e-02, 2.7278e-02, 4.9804e-02, 2.9000e-04,
#          3.1529e-04, 7.3780e-01, 2.5798e-03, 5.0247e-02],
#         [1.1382e-02, 5.2822e-04, 3.1796e-02, 1.1620e-03, 9.6610e-06, 3.5396e-06,
#          7.6752e-03, 9.4717e-01, 8.1003e-05, 1.8849e-04],
#         [6.7656e-01, 2.1720e-02, 1.7379e-02, 2.9308e-03, 2.6147e-03, 2.4229e-01,
#          9.4417e-03, 7.8722e-03, 2.2426e-04, 1.8969e-02],
#         [4.7211e-03, 8.7229e-05, 7.7672e-05, 2.9681e-05, 1.0089e-05, 1.6984e-04,
#          1.6767e-02, 6.0163e-05, 2.8058e-06, 9.7807e-01],
#         [1.4210e-03, 1.4746e-02, 1.2040e-01, 3.7585e-04, 1.0422e-03, 1.6054e-02,
#          8.0893e-03, 1.4258e-03, 8.3632e-01, 1.2798e-04],
#         [9.9479e-06, 1.8187e-05, 1.6386e-04, 3.6157e-05, 1.7928e-06, 7.3345e-06,
#          1.4870e-06, 1.1909e-05, 5.5241e-08, 9.9975e-01],
#         [5.3738e-05, 5.9458e-03, 4.2133e-05, 9.7258e-01, 4.4497e-07, 5.5422e-06,
#          1.6638e-02, 1.9864e-04, 4.3374e-03, 1.9687e-04],
#         [2.0783e-03, 2.7403e-02, 3.0593e-04, 2.0662e-04, 6.9790e-03, 4.4207e-03,
#          2.7082e-03, 4.0620e-04, 9.5120e-01, 4.2963e-03],
#         [3.6558e-05, 1.8274e-02, 3.6958e-05, 5.5369e-03, 2.6996e-06, 6.3679e-06,
#          1.6564e-04, 6.6201e-04, 9.7528e-01, 1.1546e-07],
#         [1.0637e-04, 5.5200e-04, 2.5200e-06, 7.8052e-04, 2.1362e-07, 1.1587e-08,
#          9.9850e-01, 1.5536e-06, 5.2331e-05, 1.6130e-07],
#         [4.7784e-05, 9.3591e-08, 9.9993e-01, 1.0421e-07, 1.1121e-06, 5.8303e-07,
#          1.3749e-07, 1.1653e-05, 2.7259e-07, 1.2659e-05],
#         [1.9810e-05, 1.1430e-03, 4.0978e-04, 1.5987e-03, 6.2504e-03, 2.0789e-04,
#          5.8315e-03, 1.7737e-04, 9.8430e-01, 6.5657e-05],
#         [1.3243e-03, 3.6011e-03, 9.8844e-01, 1.0877e-05, 4.6054e-03, 7.5364e-06,
#          2.8292e-04, 3.6760e-04, 1.2351e-04, 1.2389e-03],
#         [1.5966e-02, 2.2719e-04, 2.7308e-03, 6.7569e-05, 9.7913e-01, 5.3557e-06,
#          9.3710e-04, 6.6686e-04, 5.4224e-05, 2.1136e-04],
#         [3.2609e-02, 2.4698e-01, 2.2749e-02, 8.3385e-05, 1.4931e-02, 1.5602e-02,
#          4.4644e-02, 5.6932e-01, 5.2255e-02, 8.2889e-04],
#         [2.9791e-04, 2.6146e-05, 3.3522e-04, 6.3951e-04, 3.3273e-04, 1.4644e-05,
#          9.8946e-01, 5.6958e-03, 3.1046e-03, 9.1783e-05]], device='cuda:0')  Target  tensor([2, 7, 0, 9, 8, 9, 3, 8, 8, 6, 2, 8, 2, 4, 0, 6], device='cuda:0')
# Prediction  tensor([[4.3877e-04, 3.5092e-03, 1.7419e-04, 9.9496e-01, 1.8009e-05, 2.7033e-06,
#          5.3813e-04, 1.5296e-04, 1.1874e-05, 1.9233e-04],
#         [4.1481e-05, 4.4960e-03, 3.6984e-04, 4.9636e-03, 7.6303e-06, 4.9734e-04,
#          9.3258e-01, 1.0385e-05, 5.7018e-02, 1.6973e-05],
#         [1.0726e-03, 3.8265e-05, 6.4983e-04, 2.2381e-06, 2.6625e-03, 5.3706e-04,
#          4.2219e-05, 9.9476e-01, 1.1211e-05, 2.2548e-04],
#         [2.8140e-03, 1.4297e-02, 4.1205e-03, 8.7090e-01, 1.3925e-05, 1.2397e-05,
#          4.9644e-03, 8.2182e-02, 2.0680e-02, 1.5766e-05],
#         [6.3266e-01, 2.3830e-01, 3.6108e-04, 2.6938e-04, 2.5856e-04, 3.1674e-02,
#          8.3745e-03, 5.1492e-02, 2.1185e-03, 3.4496e-02],
#         [4.9991e-05, 6.1401e-06, 1.3069e-06, 2.6153e-05, 4.3806e-07, 9.9934e-01,
#          5.3173e-04, 3.0582e-07, 3.8064e-05, 1.2120e-06],
#         [2.0239e-07, 2.2384e-05, 1.0935e-04, 2.8424e-06, 9.9647e-07, 9.9976e-01,
#          6.2560e-05, 7.4321e-07, 1.7395e-06, 4.2798e-05],
#         [3.9106e-01, 7.7654e-05, 9.8042e-04, 7.2251e-04, 8.0953e-06, 1.3389e-04,
#          3.0804e-04, 3.3152e-03, 1.9293e-08, 6.0339e-01],
#         [4.1989e-04, 3.3384e-03, 4.8990e-04, 3.6635e-05, 3.8195e-04, 3.5005e-02,
#          9.4571e-01, 1.9105e-04, 1.4421e-02, 5.5646e-06],
#         [1.7183e-02, 7.9182e-01, 6.1959e-02, 5.4426e-03, 7.6892e-04, 4.2082e-02,
#          1.3561e-04, 2.2522e-02, 2.4350e-02, 3.3735e-02],
#         [3.3796e-05, 7.9045e-03, 8.2613e-05, 1.5276e-06, 5.9088e-07, 9.9193e-01,
#          2.7679e-05, 3.7837e-06, 1.0961e-05, 5.0800e-06],
#         [4.9181e-04, 1.6899e-04, 1.4122e-03, 1.1955e-05, 1.2129e-03, 5.6206e-02,
#          9.3937e-01, 1.9514e-04, 3.2750e-04, 6.0629e-04],
#         [1.1863e-05, 1.6810e-03, 1.5535e-03, 2.5049e-03, 3.2906e-05, 1.3828e-03,
#          3.7055e-02, 2.3891e-03, 9.5339e-01, 3.4274e-06],
#         [6.1779e-01, 4.9595e-06, 2.9179e-01, 6.4296e-04, 3.6640e-03, 2.0488e-03,
#          3.1171e-02, 3.1208e-05, 8.5622e-05, 5.2773e-02],
#         [1.5974e-02, 3.6201e-01, 5.6229e-01, 1.0868e-04, 4.2070e-03, 4.8913e-02,
#          5.2217e-04, 3.7972e-03, 2.1646e-03, 1.1694e-05],
#         [4.7975e-06, 8.1683e-05, 4.0021e-06, 9.9667e-01, 2.8000e-03, 1.7005e-04,
#          2.2857e-04, 1.7051e-06, 1.6017e-05, 1.9602e-05]], device='cuda:0')  Target  tensor([3, 6, 7, 3, 0, 5, 5, 9, 6, 1, 5, 6, 8, 0, 1, 3], device='cuda:0')
# Prediction  tensor([[3.0182e-03, 7.5186e-01, 1.0787e-04, 9.0589e-02, 4.5013e-05, 1.0419e-03,
#          7.9556e-02, 2.0671e-02, 5.0825e-02, 2.2813e-03],
#         [4.6126e-02, 9.2637e-01, 1.8477e-02, 1.8810e-03, 2.5845e-03, 1.2695e-03,
#          1.2973e-04, 9.3713e-04, 1.1512e-04, 2.1088e-03],
#         [6.0369e-03, 1.4163e-02, 2.6562e-04, 3.7789e-05, 9.7427e-01, 1.8288e-03,
#          1.9126e-03, 1.2203e-03, 1.4185e-04, 1.2574e-04],
#         [5.2230e-04, 1.6899e-04, 3.2879e-05, 1.5561e-05, 7.9804e-07, 2.2188e-06,
#          5.5141e-04, 9.9867e-01, 1.9030e-05, 1.6148e-05],
#         [1.8213e-05, 1.1216e-04, 1.1219e-04, 4.2197e-06, 4.3730e-04, 7.1855e-05,
#          9.9523e-01, 5.2166e-05, 3.9591e-03, 2.4822e-06],
#         [2.2178e-03, 9.7151e-01, 3.0590e-04, 1.6514e-04, 3.3349e-03, 1.4990e-04,
#          2.1585e-02, 1.9900e-05, 4.7067e-04, 2.4331e-04],
#         [1.4240e-05, 9.5618e-07, 9.9959e-01, 8.6394e-08, 3.6619e-04, 4.3080e-06,
#          3.0541e-07, 1.7964e-07, 1.7813e-06, 1.7080e-05],
#         [2.1757e-05, 1.9802e-02, 8.6153e-06, 9.7754e-01, 1.5411e-06, 1.7450e-06,
#          2.5304e-03, 2.5280e-06, 7.0558e-05, 2.2623e-05],
#         [9.8865e-01, 4.1203e-04, 8.3763e-03, 7.0510e-06, 8.6593e-05, 1.5444e-04,
#          5.6690e-05, 2.1854e-03, 6.7715e-06, 6.0389e-05],
#         [1.9401e-02, 2.0385e-05, 3.8625e-05, 7.7507e-05, 6.6746e-07, 9.9037e-05,
#          9.3979e-01, 3.9853e-03, 1.9377e-05, 3.6569e-02],
#         [5.9732e-05, 2.6813e-02, 9.6996e-01, 3.6011e-06, 1.6531e-03, 1.1008e-04,
#          1.2534e-03, 1.0339e-05, 1.2837e-04, 5.4657e-06],
#         [3.1871e-04, 4.8141e-02, 2.9239e-03, 7.0763e-07, 3.5741e-04, 1.5689e-04,
#          9.4777e-01, 2.7912e-04, 1.9778e-05, 3.6407e-05],
#         [6.5908e-05, 6.9225e-04, 7.5076e-03, 2.1492e-05, 2.8289e-06, 1.0758e-04,
#          5.2312e-06, 9.9154e-01, 1.8351e-07, 6.1110e-05],
#         [8.9608e-04, 4.8360e-01, 8.6292e-03, 7.1234e-03, 2.2311e-04, 1.2922e-04,
#          3.0385e-01, 6.2438e-04, 1.9489e-01, 2.7941e-05],
#         [3.0937e-04, 3.1636e-05, 1.4062e-04, 1.4277e-05, 6.5888e-06, 9.9924e-01,
#          1.9722e-04, 2.7229e-07, 1.4227e-06, 5.6540e-05],
#         [1.4686e-01, 3.5256e-03, 3.4381e-02, 3.1244e-04, 1.0137e-04, 7.4667e-06,
#          2.0034e-03, 7.7682e-01, 1.7238e-03, 3.4268e-02]], device='cuda:0')  Target  tensor([1, 1, 4, 7, 6, 1, 2, 3, 0, 6, 2, 6, 7, 2, 5, 7], device='cuda:0')
# Prediction  tensor([[8.0901e-01, 1.3558e-02, 9.4088e-04, 2.7110e-03, 1.3745e-03, 9.4200e-03,
#          3.0011e-02, 7.4175e-04, 3.2024e-02, 1.0021e-01],
#         [6.0395e-02, 1.0816e-04, 1.7547e-02, 6.0290e-03, 1.5727e-02, 2.4534e-03,
#          7.0780e-04, 8.7414e-01, 2.2381e-02, 5.1255e-04],
#         [1.0638e-02, 1.3880e-01, 5.6180e-01, 8.9381e-04, 2.4851e-02, 7.7914e-03,
#          7.4807e-03, 1.8982e-01, 5.3096e-02, 4.8350e-03],
#         [3.2207e-04, 1.7369e-04, 8.5336e-04, 3.9152e-06, 5.8947e-06, 6.7042e-05,
#          7.6209e-05, 5.2597e-06, 9.9845e-01, 4.4271e-05],
#         [7.7705e-04, 1.0114e-03, 2.0542e-02, 1.4255e-04, 2.0343e-03, 9.5934e-01,
#          1.1240e-03, 3.5567e-04, 1.4405e-02, 2.6689e-04],
#         [5.8927e-07, 7.9528e-08, 8.2875e-07, 1.1359e-06, 1.9334e-07, 5.1313e-09,
#          9.9999e-01, 3.0294e-09, 4.2341e-06, 3.5702e-09],
#         [2.3018e-01, 3.6772e-01, 5.6770e-03, 3.2598e-02, 4.2241e-04, 2.5895e-02,
#          3.1031e-01, 6.4736e-05, 2.9455e-03, 2.4200e-02],
#         [3.5708e-02, 6.9345e-03, 3.6858e-02, 1.6958e-04, 1.3844e-04, 3.9891e-03,
#          4.2195e-04, 9.1547e-01, 1.0425e-04, 2.0559e-04],
#         [1.4836e-04, 3.0977e-01, 8.4533e-06, 1.3223e-04, 1.3500e-05, 2.4338e-04,
#          1.9994e-05, 1.8978e-04, 6.8945e-01, 3.0202e-05],
#         [1.0487e-04, 9.6351e-01, 1.8301e-05, 3.1781e-02, 9.7991e-05, 3.8572e-03,
#          1.1271e-07, 8.8323e-05, 5.1870e-04, 1.9138e-05],
#         [5.3812e-06, 3.9567e-03, 9.2413e-08, 9.9561e-01, 1.4051e-07, 1.7701e-05,
#          3.1266e-04, 1.9319e-06, 1.5160e-05, 7.8880e-05],
#         [1.5227e-05, 1.2394e-06, 9.9981e-01, 8.3150e-08, 1.0010e-04, 2.3758e-06,
#          5.4152e-07, 1.8046e-05, 4.9357e-07, 4.8051e-05],
#         [2.6456e-04, 2.4103e-04, 3.3290e-05, 4.6481e-07, 1.8164e-05, 1.1257e-06,
#          4.6556e-05, 9.9933e-01, 5.9268e-05, 4.7646e-06],
#         [8.1762e-04, 9.3542e-04, 1.9109e-02, 1.6069e-04, 1.9149e-02, 5.9633e-04,
#          2.7120e-04, 9.5877e-01, 2.4026e-05, 1.6144e-04],
#         [5.6070e-06, 1.1579e-05, 1.8981e-04, 4.0823e-07, 1.6977e-05, 1.1802e-05,
#          7.9986e-07, 9.9975e-01, 2.6630e-07, 1.5191e-05],
#         [2.7931e-05, 3.2189e-03, 6.3482e-02, 9.3578e-05, 7.4579e-04, 2.7937e-03,
#          4.8971e-04, 1.1636e-05, 9.2914e-01, 5.1924e-07]], device='cuda:0')  Target  tensor([0, 7, 2, 8, 5, 6, 1, 7, 8, 1, 3, 2, 7, 7, 7, 8], device='cuda:0')
# Prediction  tensor([[2.1559e-02, 1.7523e-01, 5.0712e-02, 1.9194e-03, 1.3460e-01, 4.8564e-03,
#          1.3478e-02, 4.9875e-01, 9.2853e-02, 6.0435e-03],
#         [9.9734e-01, 4.2765e-04, 8.7588e-06, 1.0176e-04, 8.0676e-06, 3.9412e-04,
#          3.5389e-05, 7.4157e-04, 9.0009e-07, 9.3731e-04],
#         [9.2499e-01, 6.4950e-02, 6.9443e-05, 2.5089e-03, 1.8013e-05, 3.4852e-04,
#          2.5140e-03, 1.9588e-03, 2.1966e-04, 2.4211e-03],
#         [6.0312e-01, 1.6677e-02, 2.4307e-04, 2.9184e-04, 1.0707e-03, 8.5194e-05,
#          4.2372e-02, 1.4622e-05, 3.3608e-01, 4.2702e-05],
#         [5.0934e-03, 9.7681e-01, 9.7210e-06, 2.5807e-03, 6.6783e-05, 8.0650e-04,
#          4.3351e-04, 3.5121e-05, 9.4361e-05, 1.4069e-02],
#         [1.9002e-05, 2.6530e-04, 9.1047e-05, 5.8119e-05, 6.4462e-07, 9.9943e-01,
#          1.9304e-06, 1.1104e-04, 1.1273e-05, 9.3051e-06],
#         [3.0282e-04, 3.3983e-03, 7.3455e-04, 7.5148e-01, 1.3167e-04, 8.3345e-04,
#          2.3957e-01, 1.9164e-03, 1.3154e-03, 3.2002e-04],
#         [9.9854e-01, 9.1798e-05, 1.7508e-04, 4.7841e-04, 6.3674e-04, 4.6790e-06,
#          2.2363e-07, 1.8929e-05, 3.8940e-06, 4.8893e-05],
#         [2.7861e-02, 4.6327e-01, 5.7515e-02, 2.6052e-03, 5.4922e-05, 1.9630e-01,
#          1.7624e-03, 1.5035e-01, 2.2720e-05, 1.0025e-01],
#         [3.3722e-04, 1.5490e-02, 5.8601e-01, 1.1245e-01, 2.2260e-01, 2.9114e-04,
#          2.5159e-03, 2.9973e-02, 3.0165e-02, 1.6823e-04],
#         [4.8567e-04, 2.3794e-01, 7.0139e-02, 6.4908e-03, 3.7761e-03, 6.8258e-04,
#          5.6448e-03, 6.2832e-01, 3.0294e-05, 4.6488e-02],
#         [8.2605e-04, 1.6826e-04, 5.5967e-04, 4.7486e-04, 1.1055e-01, 6.9872e-04,
#          8.8514e-01, 8.2951e-05, 1.5065e-03, 9.5275e-07],
#         [4.0202e-05, 2.4660e-04, 1.2736e-03, 5.5750e-07, 9.9703e-01, 8.5032e-06,
#          7.2172e-07, 1.0171e-03, 1.3224e-04, 2.5028e-04],
#         [2.1731e-04, 5.9936e-06, 9.9936e-01, 3.5717e-05, 3.5109e-04, 9.7436e-06,
#          7.6699e-07, 2.2718e-06, 4.3965e-06, 1.0562e-05],
#         [1.2027e-05, 6.2812e-04, 3.0035e-08, 9.9800e-01, 9.8290e-08, 1.9010e-06,
#          1.5896e-04, 1.6929e-07, 1.1949e-03, 6.0666e-06],
#         [4.4215e-03, 1.4867e-04, 3.1362e-01, 3.0307e-05, 6.2116e-01, 5.9330e-02,
#          4.9812e-04, 1.8685e-05, 6.7574e-04, 9.3886e-05]], device='cuda:0')  Target  tensor([4, 0, 0, 0, 1, 5, 3, 0, 1, 4, 7, 6, 4, 2, 3, 4], device='cuda:0')
# Prediction  tensor([[3.4278e-03, 1.2617e-01, 7.0524e-01, 4.3279e-03, 2.1066e-05, 7.5480e-05,
#          2.6313e-04, 1.0535e-02, 3.2739e-04, 1.4961e-01],
#         [1.4359e-05, 6.6885e-05, 4.2846e-05, 1.9508e-05, 5.3207e-05, 3.3755e-06,
#          2.4912e-06, 9.9979e-01, 4.1230e-06, 4.9160e-06],
#         [2.7984e-04, 2.2470e-02, 9.0050e-04, 1.3997e-03, 3.0792e-05, 7.3868e-04,
#          1.5257e-02, 9.4948e-01, 9.4136e-03, 2.7367e-05],
#         [1.2726e-06, 5.0031e-07, 9.9985e-01, 3.6818e-08, 4.8672e-07, 1.7325e-07,
#          3.6312e-08, 7.1225e-07, 6.0303e-07, 1.4381e-04],
#         [5.3538e-05, 8.0775e-02, 1.2040e-03, 6.0715e-03, 4.2611e-03, 8.2375e-01,
#          6.0077e-02, 1.3999e-04, 2.3648e-02, 1.8240e-05],
#         [3.0373e-02, 1.5190e-03, 5.3001e-05, 1.8253e-05, 1.2341e-05, 1.5341e-05,
#          3.0902e-04, 9.6768e-01, 1.9786e-05, 1.0784e-06],
#         [1.8127e-03, 5.2569e-03, 1.8892e-03, 9.6290e-01, 5.6539e-06, 1.6794e-04,
#          1.3396e-05, 2.7557e-02, 1.0529e-04, 2.9390e-04],
#         [3.4567e-04, 3.1693e-03, 7.2071e-05, 1.4098e-03, 5.7951e-04, 3.9753e-04,
#          2.5686e-04, 5.8137e-04, 1.0830e-04, 9.9308e-01],
#         [1.4396e-05, 3.0085e-05, 1.0914e-03, 7.6710e-06, 1.0091e-05, 2.1306e-04,
#          2.8162e-07, 9.9862e-01, 9.9554e-06, 4.7058e-06],
#         [2.5113e-05, 1.3965e-05, 8.9246e-04, 4.3378e-05, 9.9858e-01, 2.2392e-05,
#          1.6439e-05, 3.6654e-04, 2.3846e-05, 1.5872e-05],
#         [9.7537e-01, 1.9698e-03, 6.9461e-03, 2.4053e-03, 6.7302e-05, 1.7688e-05,
#          5.5495e-03, 4.9007e-03, 3.9622e-04, 2.3769e-03],
#         [7.0533e-02, 8.5981e-04, 1.2105e-01, 6.8887e-02, 4.7450e-02, 9.1297e-03,
#          6.6800e-03, 5.2553e-01, 1.4972e-01, 1.6164e-04],
#         [3.4857e-02, 1.3803e-01, 6.5168e-01, 1.4260e-02, 8.7578e-02, 7.1531e-04,
#          5.5342e-02, 9.1485e-04, 1.6615e-02, 1.1034e-05],
#         [2.7222e-05, 4.5769e-05, 8.6637e-04, 6.5151e-07, 9.9863e-01, 1.9362e-06,
#          2.1679e-04, 2.0166e-06, 1.8794e-04, 2.5313e-05],
#         [1.5505e-02, 4.7458e-02, 7.1815e-02, 1.2459e-03, 2.5983e-05, 9.5687e-03,
#          5.5520e-02, 1.8929e-02, 7.7931e-01, 6.2487e-04],
#         [2.0908e-04, 3.2374e-04, 2.7993e-07, 3.0087e-04, 4.4066e-06, 4.4672e-07,
#          9.9865e-01, 3.8950e-05, 4.5350e-04, 1.3810e-05]], device='cuda:0')  Target  tensor([2, 7, 7, 2, 1, 0, 3, 9, 7, 4, 0, 7, 2, 4, 8, 6], device='cuda:0')
# Test loss 0.37661847472190857
# Testing accuracy 0.8841594827586207

# %%
model_s = LSTMModel(input_size=7488 , output_size=10)
model_s.load_state_dict(torch.load(os.path.join("/gdrive/My Drive/Major Project/Images/Experiment 9","lstm_model.pt")))
model_s = model_s.cuda()
criterion = torch.nn.CrossEntropyLoss()
test(model_s, loaders, criterion, "cuda")
# Out:
# Prediction  tensor([[7.1708e-06, 2.8131e-05, 9.4193e-06, 7.4169e-04, 3.7143e-06, 8.2055e-06,
#          2.4185e-03, 9.9651e-01, 2.6945e-04, 4.8465e-07],
#         [6.9336e-04, 8.8372e-04, 5.4931e-05, 1.5983e-05, 3.1515e-05, 4.2570e-05,
#          4.8368e-05, 1.3635e-03, 5.7071e-07, 9.9687e-01],
#         [5.9249e-04, 2.0343e-05, 9.9813e-01, 9.6562e-05, 2.2745e-04, 8.3817e-07,
#          3.8387e-05, 8.5133e-04, 2.6610e-05, 1.2662e-05],
#         [7.4943e-07, 1.8461e-05, 9.9995e-01, 1.0131e-05, 2.9779e-06, 6.7956e-06,
#          2.2719e-07, 1.1308e-06, 6.1323e-06, 2.9627e-06],
#         [2.4949e-06, 1.0095e-05, 1.2320e-06, 4.3581e-05, 4.8317e-07, 9.9978e-01,
#          2.6672e-06, 3.7342e-07, 1.5285e-04, 7.6364e-06],
#         [2.5084e-07, 3.7225e-05, 1.3393e-05, 2.9174e-05, 2.6078e-06, 8.8644e-07,
#          2.3955e-08, 1.1028e-05, 1.4203e-06, 9.9990e-01],
#         [1.0140e-05, 2.1342e-04, 1.8323e-06, 2.0686e-05, 6.4789e-06, 9.1325e-07,
#          1.3772e-08, 3.1656e-07, 1.5044e-04, 9.9960e-01],
#         [2.9842e-03, 1.4712e-03, 2.3276e-04, 3.7462e-04, 1.0244e-03, 9.8540e-04,
#          1.3734e-03, 9.7874e-01, 1.9312e-03, 1.0881e-02],
#         [5.3643e-07, 7.1630e-04, 2.0583e-05, 7.1059e-05, 7.3405e-06, 9.9722e-01,
#          3.1660e-05, 1.0988e-04, 2.2643e-04, 1.5952e-03],
#         [1.6013e-06, 1.3020e-04, 2.3375e-06, 9.9984e-01, 6.2589e-08, 2.2758e-07,
#          2.1700e-05, 2.5695e-07, 1.6849e-06, 3.5454e-07],
#         [9.1833e-04, 2.8537e-03, 2.2376e-05, 9.9569e-01, 1.8797e-05, 1.9569e-04,
#          2.3135e-04, 5.9433e-05, 2.1110e-06, 6.7750e-06],
#         [1.2042e-04, 6.1612e-06, 4.5776e-04, 1.7676e-05, 3.8008e-07, 1.5325e-05,
#          1.2093e-04, 9.9919e-01, 8.9347e-06, 5.7807e-05],
#         [1.4715e-04, 4.7804e-05, 4.0237e-06, 4.5662e-04, 4.9685e-07, 1.0681e-04,
#          9.9896e-01, 1.6946e-05, 3.6644e-07, 2.6301e-04],
#         [4.6164e-05, 1.4635e-04, 4.1622e-04, 8.4298e-06, 2.7789e-07, 4.6792e-08,
#          3.3987e-07, 1.3104e-03, 1.8068e-07, 9.9807e-01],
#         [1.4857e-04, 7.2912e-06, 9.9575e-01, 1.0295e-05, 1.2781e-06, 6.5056e-07,
#          1.8434e-05, 3.9630e-03, 1.1057e-05, 8.5382e-05],
#         [1.4282e-06, 1.1397e-04, 9.2372e-05, 2.7101e-06, 1.1225e-05, 3.2922e-05,
#          1.5389e-06, 9.9972e-01, 1.0253e-08, 1.9132e-05]], device='cuda:0')  Target  tensor([7, 9, 2, 2, 5, 9, 9, 7, 5, 3, 3, 7, 6, 9, 2, 7], device='cuda:0')
# Prediction  tensor([[2.0792e-04, 3.7033e-03, 2.2493e-06, 1.3757e-03, 6.2440e-06, 9.9365e-01,
#          9.4100e-04, 6.3726e-05, 4.0913e-05, 6.2567e-06],
#         [1.2082e-06, 1.4080e-06, 4.0882e-07, 1.4732e-06, 1.0104e-06, 9.9999e-01,
#          4.7025e-07, 8.1327e-07, 3.8795e-07, 3.5011e-07],
#         [8.2830e-05, 2.4972e-05, 8.7034e-07, 5.3818e-04, 8.4232e-06, 3.1654e-06,
#          9.9891e-01, 9.1999e-06, 4.1384e-04, 1.1386e-05],
#         [1.3128e-04, 4.3550e-06, 1.0330e-04, 5.0753e-04, 7.6925e-04, 8.8013e-05,
#          9.9818e-01, 4.7206e-06, 1.8841e-06, 2.0589e-04],
#         [2.0345e-05, 1.3068e-04, 6.6437e-05, 1.9152e-07, 6.2277e-06, 2.0706e-08,
#          4.6991e-06, 3.8204e-06, 1.5770e-07, 9.9977e-01],
#         [1.4830e-06, 1.0925e-04, 5.7302e-08, 2.9333e-05, 9.6484e-07, 5.0655e-10,
#          9.9985e-01, 7.1710e-07, 5.6888e-06, 1.4763e-07],
#         [9.9977e-01, 1.2085e-04, 4.2789e-06, 2.0998e-06, 9.5221e-07, 5.2337e-05,
#          3.5369e-06, 9.0243e-06, 3.7692e-06, 2.8538e-05],
#         [4.7055e-06, 1.0367e-03, 3.1046e-06, 5.3506e-06, 1.7977e-05, 1.1746e-05,
#          4.5749e-04, 2.9359e-05, 9.9811e-01, 3.2264e-04],
#         [6.2591e-06, 5.1707e-05, 1.9291e-08, 2.2818e-04, 6.2322e-07, 1.2539e-09,
#          9.9969e-01, 1.7331e-06, 1.9406e-05, 5.3015e-08],
#         [1.0777e-03, 9.9831e-01, 1.8939e-06, 1.8567e-05, 5.0231e-08, 1.6935e-06,
#          7.2916e-05, 3.7182e-04, 2.4666e-05, 1.2505e-04],
#         [2.0648e-03, 9.0961e-01, 2.0784e-04, 1.2580e-04, 1.3012e-03, 6.4894e-05,
#          6.7325e-02, 9.0648e-03, 9.5872e-03, 6.4906e-04],
#         [4.1528e-06, 3.2758e-06, 2.0577e-05, 1.8294e-05, 9.9992e-01, 2.0738e-07,
#          3.2281e-05, 1.7653e-08, 8.3814e-07, 2.7530e-08],
#         [4.9107e-04, 7.7377e-05, 3.6062e-04, 2.3969e-05, 1.0559e-05, 9.9893e-01,
#          9.6315e-05, 9.6538e-06, 9.9988e-08, 3.3699e-06],
#         [1.6271e-05, 2.5661e-04, 8.0702e-05, 5.5524e-04, 9.9567e-01, 2.5820e-06,
#          6.6013e-05, 7.1593e-04, 2.6322e-03, 8.6354e-06],
#         [1.1137e-06, 2.6846e-05, 3.1534e-05, 2.8811e-07, 6.7270e-08, 5.0584e-07,
#          7.1555e-08, 9.9987e-01, 2.4176e-08, 7.0071e-05],
#         [2.8802e-05, 3.0858e-06, 7.5166e-07, 1.5032e-05, 4.6156e-08, 1.4096e-04,
#          4.8848e-04, 2.0833e-06, 9.9932e-01, 1.6581e-07]], device='cuda:0')  Target  tensor([5, 5, 6, 6, 9, 6, 0, 8, 6, 1, 1, 4, 5, 4, 7, 8], device='cuda:0')
# Prediction  tensor([[1.5022e-06, 2.8854e-07, 1.2157e-05, 6.1767e-06, 7.0794e-05, 8.4803e-07,
#          4.1652e-06, 3.8011e-06, 9.9990e-01, 2.4793e-06],
#         [1.9243e-06, 1.1060e-04, 3.8423e-05, 1.9534e-04, 2.0752e-04, 1.1870e-05,
#          1.8775e-06, 2.2461e-05, 1.2992e-04, 9.9928e-01],
#         [1.2836e-03, 2.4197e-04, 1.1366e-03, 5.2589e-04, 6.2001e-05, 7.4706e-07,
#          1.8244e-03, 1.0098e-03, 9.9391e-01, 4.6523e-07],
#         [9.9832e-01, 4.7900e-06, 8.0453e-04, 2.4276e-04, 3.9665e-05, 8.0282e-08,
#          1.4084e-04, 1.6368e-05, 4.0434e-06, 4.2505e-04],
#         [8.5153e-06, 1.1312e-04, 1.0717e-04, 1.3708e-04, 8.9185e-06, 1.1629e-05,
#          9.9688e-01, 3.1697e-07, 2.7328e-03, 1.6955e-06],
#         [6.7178e-06, 3.0502e-05, 2.9676e-06, 9.5410e-07, 1.5419e-07, 2.3472e-07,
#          1.3382e-06, 4.2668e-05, 2.8033e-07, 9.9991e-01],
#         [2.6287e-07, 2.7167e-07, 1.0249e-06, 1.6187e-06, 4.9437e-06, 1.2387e-07,
#          9.9999e-01, 2.2138e-07, 5.2858e-06, 1.4003e-08],
#         [2.9514e-06, 9.9968e-01, 3.4435e-08, 5.7957e-05, 6.1294e-08, 3.1421e-06,
#          3.2605e-06, 4.0515e-07, 3.6767e-07, 2.4707e-04],
#         [8.9855e-07, 6.3214e-06, 1.4612e-07, 9.9892e-01, 5.7306e-07, 4.9669e-08,
#          1.4964e-04, 2.0576e-06, 9.2021e-04, 4.1695e-07],
#         [9.9986e-01, 4.5682e-07, 4.4203e-07, 2.0776e-05, 1.9779e-07, 6.4342e-08,
#          9.4281e-05, 1.6375e-05, 2.0931e-06, 2.4959e-07],
#         [4.7593e-02, 1.3208e-02, 1.9869e-03, 3.6173e-03, 3.0820e-04, 3.0338e-01,
#          6.1802e-01, 1.4579e-04, 3.7827e-05, 1.1709e-02],
#         [1.4164e-05, 2.2345e-06, 5.1666e-04, 4.8336e-06, 3.2888e-05, 1.0306e-04,
#          9.6112e-01, 9.0860e-05, 3.8113e-02, 8.9992e-07],
#         [7.5968e-05, 1.7300e-04, 9.9652e-01, 1.3342e-06, 3.9058e-05, 6.9179e-04,
#          1.3415e-06, 1.1586e-04, 3.9811e-04, 1.9851e-03],
#         [2.2901e-04, 9.8602e-01, 6.5228e-07, 1.3458e-02, 9.1239e-06, 6.3372e-07,
#          1.9944e-04, 1.8545e-06, 4.2940e-05, 4.1965e-05],
#         [4.1119e-04, 2.6539e-05, 9.9800e-01, 9.5034e-06, 9.0706e-04, 1.2683e-05,
#          8.7601e-06, 7.1984e-06, 2.0528e-04, 4.1482e-04],
#         [2.1887e-04, 8.2603e-05, 2.9583e-06, 1.2377e-05, 1.3095e-05, 5.4209e-04,
#          1.8471e-04, 9.9890e-01, 2.5208e-06, 3.9254e-05]], device='cuda:0')  Target  tensor([8, 9, 8, 0, 6, 9, 6, 1, 3, 0, 6, 6, 2, 1, 2, 7], device='cuda:0')
# Prediction  tensor([[1.6090e-05, 3.7746e-03, 5.3380e-04, 2.0629e-04, 4.3159e-03, 5.3462e-05,
#          1.9985e-05, 4.0630e-04, 9.8693e-01, 3.7462e-03],
#         [2.1582e-04, 2.4764e-05, 8.6345e-04, 8.2250e-06, 9.9810e-01, 1.2968e-04,
#          4.7395e-06, 1.9950e-04, 2.4249e-05, 4.3438e-04],
#         [3.5650e-05, 2.8561e-04, 9.9841e-01, 1.5982e-05, 3.1469e-05, 4.8112e-04,
#          6.5553e-04, 1.0196e-05, 2.5864e-05, 4.9535e-05],
#         [1.1205e-07, 3.2221e-05, 1.2388e-08, 9.9994e-01, 3.0786e-09, 8.5823e-08,
#          9.3496e-06, 1.2996e-06, 7.7140e-07, 1.6060e-05],
#         [3.2700e-06, 1.6456e-05, 3.4924e-07, 9.9947e-01, 2.9685e-06, 1.2249e-05,
#          4.9295e-04, 4.7890e-07, 1.6627e-06, 5.9048e-07],
#         [8.8418e-02, 1.1692e-03, 1.6936e-05, 2.8987e-05, 2.3379e-06, 7.1647e-07,
#          8.6373e-04, 9.0879e-01, 5.8221e-05, 6.5514e-04],
#         [1.8125e-03, 9.9234e-01, 3.3848e-06, 5.8964e-04, 2.4993e-07, 1.2017e-07,
#          1.3932e-05, 1.9616e-05, 9.2302e-06, 5.2121e-03],
#         [1.5345e-04, 4.5608e-07, 3.2301e-04, 8.6131e-07, 6.0353e-06, 2.6004e-05,
#          9.2522e-05, 1.4863e-05, 1.5302e-08, 9.9938e-01],
#         [9.5977e-06, 1.7470e-05, 1.1012e-06, 4.8500e-05, 2.5132e-06, 9.9973e-01,
#          1.6716e-04, 3.8608e-08, 4.3272e-06, 1.7844e-05],
#         [4.2453e-05, 1.2870e-04, 8.0937e-06, 3.2135e-05, 1.0217e-06, 2.5558e-05,
#          9.9930e-01, 6.1586e-07, 4.5890e-04, 2.1107e-06],
#         [3.4920e-04, 7.2153e-05, 6.7953e-05, 9.9936e-01, 1.9419e-06, 6.5890e-05,
#          1.6137e-05, 5.2669e-05, 1.8125e-05, 9.0596e-07],
#         [3.7518e-05, 1.7289e-03, 8.3689e-01, 1.1761e-04, 3.3596e-06, 1.1795e-06,
#          3.9165e-05, 1.5994e-01, 4.7692e-06, 1.2423e-03],
#         [2.4859e-04, 1.4092e-04, 1.2367e-02, 9.4565e-01, 2.0615e-03, 6.6600e-05,
#          3.9616e-04, 3.7594e-02, 3.3083e-04, 1.1422e-03],
#         [1.2799e-03, 1.0401e-05, 1.7936e-03, 4.9215e-04, 5.5208e-04, 7.0504e-06,
#          9.9364e-01, 2.1517e-05, 8.1346e-04, 1.3890e-03],
#         [4.2801e-05, 7.4105e-07, 9.9972e-01, 1.8269e-06, 2.5519e-06, 8.4583e-07,
#          4.9050e-08, 7.8949e-06, 6.8970e-07, 2.2006e-04],
#         [2.7048e-07, 6.2774e-06, 2.1117e-06, 2.9163e-05, 6.6220e-07, 9.9991e-01,
#          3.6770e-05, 1.5984e-06, 1.1779e-05, 1.5632e-08]], device='cuda:0')  Target  tensor([8, 4, 2, 3, 3, 7, 1, 9, 5, 6, 3, 2, 7, 6, 2, 5], device='cuda:0')
# Prediction  tensor([[9.4545e-06, 2.2386e-04, 3.1639e-06, 2.0204e-03, 6.1910e-07, 7.6533e-05,
#          6.3776e-05, 3.7632e-05, 9.9756e-01, 3.3123e-07],
#         [1.3307e-01, 4.2579e-04, 3.3382e-06, 3.5549e-03, 1.1999e-05, 4.1914e-05,
#          8.6059e-01, 1.9901e-03, 2.7076e-04, 4.3886e-05],
#         [7.3169e-06, 3.6867e-07, 6.7129e-06, 6.5026e-04, 7.9936e-06, 9.9922e-01,
#          9.3613e-05, 8.8850e-06, 6.5550e-07, 6.3168e-07],
#         [1.5695e-04, 7.0004e-04, 1.8827e-04, 5.2321e-05, 7.2119e-06, 6.7657e-06,
#          7.3440e-07, 7.0942e-04, 1.2413e-06, 9.9818e-01],
#         [1.6791e-06, 2.9648e-06, 1.5314e-04, 2.5806e-06, 1.2311e-05, 1.9240e-06,
#          2.5541e-04, 5.5695e-05, 9.9941e-01, 1.0738e-04],
#         [1.9609e-05, 1.8058e-05, 9.9874e-01, 5.3953e-07, 1.3678e-04, 5.7757e-05,
#          1.1130e-05, 9.9117e-04, 9.8602e-07, 2.8123e-05],
#         [9.9955e-01, 1.4384e-04, 2.1580e-05, 8.7537e-05, 1.8038e-06, 1.2887e-07,
#          9.8945e-06, 1.1817e-05, 1.2278e-04, 4.7470e-05],
#         [3.1173e-06, 1.8908e-07, 8.0509e-08, 1.4010e-05, 2.4370e-08, 4.9892e-06,
#          9.9987e-01, 1.1720e-06, 6.1643e-08, 1.0382e-04],
#         [2.7924e-05, 9.9984e-01, 1.5797e-06, 1.0492e-04, 3.6662e-08, 9.4767e-06,
#          2.0912e-06, 5.8546e-06, 7.5867e-06, 3.9249e-06],
#         [9.9953e-01, 2.8429e-06, 9.7704e-05, 8.3266e-06, 1.5510e-04, 5.5382e-05,
#          8.7519e-05, 4.7041e-06, 2.6009e-05, 3.2479e-05],
#         [2.0274e-02, 3.4224e-06, 9.7769e-01, 2.1921e-05, 4.4211e-05, 2.6801e-07,
#          3.5331e-04, 1.5914e-03, 1.0154e-06, 2.3953e-05],
#         [2.6450e-06, 2.5236e-07, 1.1910e-07, 1.1761e-07, 3.4611e-08, 2.2939e-06,
#          9.9999e-01, 6.8756e-07, 8.6179e-08, 2.1485e-07],
#         [6.1042e-05, 2.9170e-05, 2.9902e-06, 1.4686e-06, 3.4233e-05, 5.4937e-06,
#          4.9157e-05, 9.9982e-01, 2.4400e-07, 3.2998e-07],
#         [1.4161e-04, 1.5782e-05, 1.8518e-03, 1.5480e-05, 1.7775e-05, 1.0075e-05,
#          2.7519e-07, 9.9794e-01, 1.6192e-07, 6.6321e-06],
#         [5.4948e-06, 3.8630e-06, 7.4844e-06, 3.1934e-07, 3.1033e-07, 2.5833e-07,
#          7.2807e-08, 9.9992e-01, 1.5627e-07, 5.7157e-05],
#         [2.0639e-06, 2.8864e-05, 9.9992e-01, 1.9610e-07, 6.1837e-07, 2.7859e-08,
#          1.1109e-08, 2.5174e-06, 6.1487e-07, 4.7257e-05]], device='cuda:0')  Target  tensor([8, 7, 5, 9, 8, 2, 0, 6, 1, 0, 2, 6, 7, 7, 7, 2], device='cuda:0')
# Prediction  tensor([[3.2295e-07, 1.9284e-05, 1.2524e-07, 9.9961e-01, 5.4174e-07, 4.8273e-07,
#          3.5956e-04, 1.1340e-06, 1.1514e-05, 4.3713e-07],
#         [1.6962e-05, 2.7916e-05, 1.5002e-04, 1.1757e-01, 3.3218e-03, 3.6234e-05,
#          3.5135e-02, 9.2444e-06, 8.4373e-01, 1.8032e-06],
#         [5.7837e-04, 1.8086e-04, 9.9332e-06, 8.0527e-04, 6.7341e-05, 7.3696e-05,
#          9.9519e-01, 1.4717e-04, 2.9429e-03, 3.0999e-06],
#         [1.0166e-07, 1.1115e-04, 1.9279e-06, 9.9955e-01, 2.1073e-04, 5.1364e-05,
#          1.1444e-05, 1.4089e-07, 6.6470e-05, 1.2635e-06],
#         [7.2772e-06, 3.6573e-06, 1.0493e-05, 2.8304e-06, 7.0061e-05, 4.3980e-06,
#          7.4825e-08, 6.5465e-06, 2.7012e-05, 9.9987e-01],
#         [2.5802e-03, 7.3246e-05, 7.6650e-05, 1.0550e-06, 7.8372e-06, 3.4200e-05,
#          2.2661e-06, 3.2976e-04, 3.4319e-07, 9.9689e-01],
#         [1.0597e-06, 3.3528e-04, 3.2767e-07, 9.9898e-01, 3.2211e-04, 2.1600e-04,
#          6.8259e-06, 3.4119e-07, 1.1030e-04, 3.0216e-05],
#         [5.5024e-05, 2.4734e-06, 2.2324e-06, 3.5962e-05, 9.2592e-07, 6.2301e-08,
#          9.9982e-01, 4.3611e-07, 7.9740e-05, 4.5854e-07],
#         [9.9999e-01, 2.2268e-07, 6.2643e-06, 1.1030e-06, 4.9293e-08, 1.4108e-07,
#          2.2981e-06, 2.6827e-07, 1.7346e-08, 2.8428e-06],
#         [1.6203e-03, 4.7781e-03, 3.2970e-05, 4.0826e-04, 1.8792e-07, 2.2081e-04,
#          9.9761e-04, 6.3483e-05, 1.0454e-04, 9.9177e-01],
#         [1.0746e-04, 4.7235e-05, 3.2461e-06, 2.8935e-06, 4.0019e-07, 3.3548e-06,
#          6.1334e-06, 4.6502e-06, 1.3037e-08, 9.9982e-01],
#         [2.0255e-04, 1.7441e-05, 3.7343e-04, 9.1194e-05, 1.3573e-05, 9.9715e-01,
#          3.3371e-05, 2.4403e-06, 1.0100e-06, 2.1139e-03],
#         [9.4642e-06, 8.5888e-06, 2.7846e-06, 1.8981e-06, 1.2786e-05, 9.9986e-01,
#          7.2964e-05, 7.7906e-06, 1.7555e-05, 1.8495e-06],
#         [6.6818e-07, 3.8940e-08, 2.3554e-08, 4.3057e-06, 1.8753e-07, 4.6191e-09,
#          9.9999e-01, 5.5020e-07, 3.3761e-06, 1.6847e-09],
#         [7.6474e-07, 7.2995e-05, 9.9617e-01, 4.0496e-07, 6.8043e-05, 3.6595e-03,
#          6.2317e-06, 3.3104e-06, 2.2337e-05, 2.1446e-07],
#         [4.8108e-05, 3.4281e-03, 1.3824e-05, 9.9162e-01, 7.1662e-05, 8.5219e-05,
#          5.7209e-05, 8.0797e-05, 5.0711e-04, 4.0917e-03]], device='cuda:0')  Target  tensor([3, 8, 6, 3, 9, 9, 3, 6, 0, 9, 9, 5, 5, 6, 2, 3], device='cuda:0')
# Prediction  tensor([[1.5460e-03, 2.3971e-04, 2.0505e-04, 4.0051e-04, 8.9743e-05, 6.1446e-05,
#          8.9815e-06, 9.9735e-01, 1.4893e-05, 8.2889e-05],
#         [8.2927e-05, 1.0812e-05, 1.5482e-03, 9.1645e-04, 2.7458e-05, 3.3338e-05,
#          4.4294e-05, 2.3757e-04, 7.3654e-06, 9.9709e-01],
#         [1.8415e-05, 5.6561e-07, 9.9982e-01, 7.3008e-07, 7.8982e-06, 3.9057e-07,
#          2.2049e-06, 1.3461e-04, 6.4351e-06, 5.0717e-06],
#         [7.6101e-06, 7.4035e-05, 1.9304e-06, 1.9980e-04, 7.5245e-07, 9.9970e-01,
#          4.7227e-06, 5.8345e-07, 6.4162e-06, 8.9678e-07],
#         [3.4116e-04, 5.9274e-05, 1.1241e-05, 3.3671e-04, 9.9824e-01, 7.4902e-05,
#          1.6892e-04, 1.2279e-04, 2.1929e-05, 6.2650e-04],
#         [1.2151e-05, 9.9892e-01, 1.4170e-05, 9.5452e-04, 7.6160e-05, 2.8167e-06,
#          9.4599e-06, 4.2105e-06, 1.8425e-06, 4.7594e-06],
#         [1.5551e-05, 3.9466e-06, 3.5119e-06, 3.5770e-04, 2.1892e-05, 9.9944e-01,
#          6.2266e-05, 1.9546e-05, 7.0096e-05, 5.3015e-06],
#         [1.2935e-03, 2.0310e-04, 3.2266e-04, 5.3463e-05, 8.2187e-05, 9.5406e-07,
#          3.6052e-05, 9.9662e-01, 1.4069e-05, 1.3758e-03],
#         [1.7041e-06, 1.4337e-06, 1.1155e-05, 3.8286e-06, 2.1530e-08, 4.6778e-08,
#          4.5637e-04, 3.9342e-07, 9.9953e-01, 1.3654e-08],
#         [1.5984e-05, 2.2141e-06, 1.1462e-05, 1.4606e-06, 9.9832e-01, 1.3938e-03,
#          1.1727e-05, 1.6693e-04, 7.5926e-05, 3.5215e-06],
#         [9.9828e-01, 6.9210e-04, 2.4074e-05, 2.2845e-04, 2.0211e-04, 2.1069e-04,
#          1.4212e-04, 6.3720e-08, 7.5293e-06, 2.0857e-04],
#         [5.6445e-05, 3.0553e-07, 3.9264e-08, 9.6063e-05, 8.9278e-07, 4.8390e-06,
#          9.9980e-01, 1.3562e-06, 1.4099e-07, 3.8529e-05],
#         [4.5446e-06, 1.2156e-06, 7.8636e-05, 8.4766e-07, 4.3095e-06, 4.9741e-07,
#          1.2129e-06, 4.9474e-07, 2.6358e-06, 9.9991e-01],
#         [1.0789e-06, 4.1459e-05, 2.6627e-06, 3.7091e-03, 1.3346e-04, 2.6812e-05,
#          2.6925e-06, 7.4604e-06, 9.9557e-01, 5.0877e-04],
#         [1.5359e-05, 4.5225e-05, 4.3230e-04, 1.5347e-03, 5.0692e-04, 4.4452e-05,
#          3.9423e-07, 4.7114e-04, 2.7198e-05, 9.9692e-01],
#         [9.3924e-05, 7.0578e-06, 2.7974e-05, 1.1724e-03, 1.2284e-05, 4.2435e-06,
#          6.1771e-05, 1.7959e-04, 2.9509e-04, 9.9815e-01]], device='cuda:0')  Target  tensor([7, 9, 2, 5, 4, 1, 5, 7, 8, 4, 0, 6, 9, 8, 9, 9], device='cuda:0')
# Prediction  tensor([[3.0122e-03, 7.6629e-02, 4.9091e-01, 6.4487e-04, 8.6599e-04, 2.0010e-03,
#          1.5041e-03, 4.0860e-01, 1.2806e-02, 3.0321e-03],
#         [1.0279e-04, 7.9134e-05, 6.0091e-03, 2.5311e-05, 9.9149e-01, 1.1653e-04,
#          8.3728e-05, 1.3017e-05, 2.0597e-03, 1.5927e-05],
#         [1.1670e-06, 5.7670e-05, 1.7417e-06, 4.1343e-06, 7.7517e-06, 9.9992e-01,
#          3.5190e-06, 1.5661e-07, 4.0660e-07, 9.5255e-07],
#         [2.9506e-04, 2.5427e-04, 1.0250e-03, 9.7459e-05, 8.1803e-05, 2.2235e-05,
#          6.3560e-07, 7.6504e-06, 1.1266e-03, 9.9709e-01],
#         [1.2596e-03, 1.9448e-04, 9.9488e-01, 1.2748e-05, 6.6306e-04, 8.3875e-04,
#          7.4943e-04, 3.7140e-04, 1.9231e-05, 1.0082e-03],
#         [9.9705e-01, 3.8204e-05, 7.6474e-04, 7.2148e-04, 9.4513e-07, 2.0852e-07,
#          7.3622e-04, 4.0354e-05, 7.5379e-07, 6.4902e-04],
#         [4.3597e-05, 1.2770e-05, 8.3722e-06, 3.2770e-05, 1.7721e-06, 6.9482e-05,
#          1.9397e-03, 9.8999e-06, 4.2586e-05, 9.9784e-01],
#         [1.6056e-04, 8.1366e-07, 9.9957e-01, 4.6665e-05, 1.5335e-04, 1.9084e-06,
#          1.1179e-05, 2.6779e-05, 6.5518e-08, 2.6166e-05],
#         [7.5162e-06, 3.8811e-06, 2.0998e-04, 2.8752e-05, 9.9938e-01, 7.3707e-06,
#          1.4209e-05, 1.5537e-04, 1.7149e-04, 2.3253e-05],
#         [1.0429e-06, 1.6070e-04, 4.2737e-05, 9.0408e-05, 7.2299e-04, 4.3640e-06,
#          8.3186e-05, 1.0884e-05, 7.9492e-08, 9.9888e-01],
#         [5.7900e-07, 3.9749e-04, 2.0623e-04, 2.6751e-04, 1.2587e-05, 7.3048e-05,
#          1.2183e-04, 4.1964e-07, 5.9938e-05, 9.9886e-01],
#         [1.6573e-04, 2.2672e-05, 1.9016e-06, 8.6638e-04, 3.8114e-07, 5.2633e-06,
#          1.4142e-03, 1.3295e-06, 9.9741e-01, 1.1637e-04],
#         [6.5622e-05, 9.8769e-06, 5.9861e-07, 9.9984e-01, 2.1456e-08, 4.0277e-05,
#          2.7605e-05, 5.8990e-07, 1.0472e-07, 1.8582e-05],
#         [1.8316e-04, 6.4918e-05, 3.0800e-03, 1.1880e-05, 9.6901e-05, 9.9651e-01,
#          2.6225e-05, 5.4568e-06, 6.7136e-08, 2.0742e-05],
#         [7.9032e-07, 8.7151e-05, 8.3276e-06, 9.9964e-01, 3.4646e-06, 9.4238e-05,
#          5.4913e-05, 9.5088e-06, 5.3045e-05, 4.6213e-05],
#         [2.4210e-07, 1.4051e-04, 1.3820e-06, 9.9788e-01, 4.0112e-07, 9.6709e-07,
#          4.3389e-05, 6.0931e-05, 1.8742e-03, 4.1615e-07]], device='cuda:0')  Target  tensor([7, 4, 5, 9, 2, 0, 9, 2, 4, 9, 9, 8, 3, 5, 3, 3], device='cuda:0')
# Prediction  tensor([[1.6494e-05, 3.3548e-05, 3.5901e-03, 5.7629e-04, 1.2212e-04, 2.0530e-04,
#          4.8665e-06, 1.0612e-03, 6.1238e-06, 9.9438e-01],
#         [6.9502e-04, 3.9974e-06, 9.9823e-01, 3.2161e-06, 6.5343e-05, 7.3998e-05,
#          1.4112e-05, 2.4319e-06, 6.5450e-05, 8.4873e-04],
#         [2.3575e-04, 2.6580e-04, 6.4059e-05, 3.7494e-06, 9.9676e-01, 3.6663e-05,
#          1.1401e-05, 1.5278e-03, 3.6257e-04, 7.3278e-04],
#         [4.5977e-04, 9.9864e-01, 2.1717e-04, 4.8842e-04, 1.2855e-04, 4.6163e-05,
#          2.4804e-06, 2.0293e-06, 4.3638e-06, 9.9504e-06],
#         [6.0266e-05, 5.3935e-06, 1.9399e-06, 5.1149e-04, 8.1547e-07, 1.7069e-06,
#          3.9513e-05, 7.7457e-06, 9.9937e-01, 1.0107e-06],
#         [7.0731e-04, 8.0101e-06, 5.4918e-05, 5.7494e-05, 7.0716e-06, 9.7331e-08,
#          8.6782e-04, 9.9735e-01, 8.3120e-04, 1.1868e-04],
#         [9.9839e-01, 3.5119e-05, 3.1631e-06, 4.1569e-06, 6.5915e-08, 2.7398e-07,
#          4.7659e-04, 1.0002e-03, 5.7835e-06, 8.2974e-05],
#         [2.3452e-05, 3.2675e-04, 1.8557e-07, 4.8788e-04, 3.1964e-07, 1.8798e-05,
#          9.9850e-01, 4.6103e-05, 1.9576e-07, 5.9793e-04],
#         [1.2985e-04, 3.7956e-05, 4.8581e-07, 2.0066e-05, 5.9933e-07, 5.3297e-04,
#          9.9918e-01, 8.2477e-08, 8.3241e-05, 1.2899e-05],
#         [8.5894e-02, 3.0041e-03, 5.4980e-03, 4.0609e-04, 5.0176e-04, 1.2247e-03,
#          8.7377e-01, 5.1975e-05, 2.9645e-02, 7.9247e-07],
#         [1.2239e-05, 7.1747e-05, 1.6283e-05, 2.8330e-04, 2.5156e-03, 2.0058e-05,
#          6.0721e-06, 9.9700e-01, 1.5271e-07, 7.8459e-05],
#         [6.2553e-07, 1.3519e-03, 2.7978e-07, 2.2985e-03, 2.4285e-04, 9.9985e-07,
#          9.9580e-01, 2.7812e-04, 2.5524e-05, 4.9951e-07],
#         [3.5285e-05, 1.6654e-06, 1.5825e-04, 1.4213e-04, 4.9266e-05, 1.3837e-04,
#          4.1312e-06, 2.3635e-05, 9.9944e-01, 5.8036e-06],
#         [9.9993e-01, 2.3413e-06, 5.9169e-08, 1.4368e-07, 2.4444e-08, 3.8121e-08,
#          2.8304e-06, 3.0722e-06, 1.5101e-07, 5.6787e-05],
#         [9.9850e-01, 3.8602e-05, 9.8501e-05, 5.5294e-05, 1.2114e-05, 4.6087e-08,
#          6.8507e-05, 1.0495e-03, 3.8035e-06, 1.7715e-04],
#         [3.0143e-06, 9.5644e-07, 1.6196e-06, 8.1065e-05, 1.2936e-06, 2.7623e-06,
#          3.3888e-06, 4.3829e-05, 2.8086e-07, 9.9986e-01]], device='cuda:0')  Target  tensor([9, 2, 4, 1, 8, 7, 0, 6, 6, 0, 7, 6, 8, 0, 0, 9], device='cuda:0')
# Prediction  tensor([[9.1967e-06, 7.8009e-07, 1.2798e-05, 4.1963e-04, 2.3147e-04, 8.4111e-07,
#          1.9193e-05, 9.9903e-01, 8.9954e-05, 1.8366e-04],
#         [1.9820e-05, 1.3960e-03, 2.8620e-07, 9.9757e-01, 1.1311e-06, 3.3924e-07,
#          3.3302e-05, 3.4922e-06, 9.7020e-04, 9.9927e-07],
#         [1.1483e-04, 1.0860e-06, 9.6143e-06, 2.1168e-05, 1.6040e-05, 9.9966e-01,
#          1.5035e-04, 6.5754e-08, 2.1361e-05, 1.0147e-06],
#         [9.7937e-07, 8.2698e-04, 1.2200e-05, 3.8488e-05, 2.6115e-06, 7.2003e-06,
#          1.0075e-03, 9.9808e-01, 1.6288e-05, 6.2132e-06],
#         [1.3837e-04, 1.0399e-04, 3.3849e-07, 2.1871e-04, 3.7922e-07, 2.3165e-08,
#          9.9918e-01, 1.4877e-04, 2.0516e-04, 1.8547e-06],
#         [6.7993e-05, 2.0926e-04, 4.1226e-04, 5.7867e-05, 9.9893e-01, 4.3385e-05,
#          3.2624e-05, 1.4785e-04, 7.8984e-06, 9.0817e-05],
#         [1.8116e-05, 4.5525e-05, 3.5678e-05, 8.8436e-06, 2.2764e-04, 1.6852e-03,
#          9.5115e-06, 3.0697e-07, 9.9797e-01, 1.5868e-07],
#         [9.8601e-01, 5.0043e-04, 2.4427e-03, 1.1408e-03, 1.6725e-03, 1.7840e-03,
#          4.9281e-04, 1.6755e-04, 5.1407e-06, 5.7821e-03],
#         [9.9938e-01, 1.4721e-05, 1.7044e-06, 8.4004e-06, 2.8951e-06, 1.8601e-05,
#          3.7028e-04, 5.1005e-05, 2.3332e-06, 1.5263e-04],
#         [2.3327e-07, 3.7916e-05, 8.6438e-06, 1.4376e-06, 2.0731e-06, 3.3710e-07,
#          3.8873e-07, 9.9995e-01, 3.1706e-08, 1.7682e-06],
#         [1.6061e-05, 3.4167e-05, 3.2761e-03, 5.0921e-05, 9.9426e-01, 3.3762e-05,
#          1.6061e-05, 1.8249e-06, 2.3073e-03, 1.5119e-06],
#         [3.4163e-05, 9.6299e-05, 1.4212e-04, 1.4439e-06, 9.9580e-01, 5.1620e-06,
#          3.2657e-05, 2.5001e-03, 1.3800e-03, 1.2306e-05],
#         [7.3403e-04, 1.6631e-05, 3.3660e-03, 1.4683e-04, 3.5273e-05, 4.4053e-06,
#          4.1553e-05, 9.9552e-01, 7.6822e-05, 6.1389e-05],
#         [9.5449e-04, 1.7253e-07, 9.9885e-01, 1.7028e-04, 2.6714e-06, 9.4317e-06,
#          3.0012e-08, 1.0910e-06, 6.6431e-07, 1.2467e-05],
#         [1.0236e-04, 7.0699e-04, 4.4967e-08, 9.9851e-01, 2.0710e-06, 3.2066e-04,
#          6.4602e-05, 4.6268e-06, 7.2052e-05, 2.1282e-04],
#         [1.8073e-05, 9.9861e-01, 2.9476e-05, 8.4760e-04, 1.5457e-06, 2.6320e-04,
#          1.1561e-07, 3.9152e-05, 1.1982e-04, 6.7464e-05]], device='cuda:0')  Target  tensor([7, 3, 5, 7, 6, 4, 8, 0, 0, 7, 4, 4, 7, 2, 3, 1], device='cuda:0')
# Prediction  tensor([[4.5433e-06, 1.0545e-04, 4.3644e-07, 2.3313e-04, 9.4092e-06, 7.9940e-06,
#          1.2809e-04, 1.3196e-06, 9.9950e-01, 9.2399e-06],
#         [1.4744e-06, 3.4812e-05, 7.1659e-08, 9.9912e-01, 2.5606e-06, 1.3506e-06,
#          6.0447e-04, 2.6496e-05, 1.9348e-04, 1.2233e-05],
#         [5.2362e-04, 8.2412e-07, 9.9625e-01, 2.4542e-06, 1.5580e-04, 8.9411e-07,
#          2.1223e-05, 2.9563e-03, 5.3961e-05, 2.9967e-05],
#         [7.4500e-06, 4.4166e-04, 1.0896e-03, 9.1106e-06, 1.1870e-03, 2.4512e-03,
#          6.6687e-05, 2.9680e-07, 9.9469e-01, 5.6245e-05],
#         [1.4554e-05, 5.5029e-05, 2.3475e-05, 4.4025e-06, 3.0305e-06, 9.9979e-01,
#          7.1694e-05, 4.6466e-06, 5.3057e-07, 3.7173e-05],
#         [6.4465e-05, 4.7022e-05, 2.7570e-07, 9.5481e-06, 1.1040e-06, 1.5243e-03,
#          9.9834e-01, 8.4941e-06, 1.5455e-06, 6.6351e-06],
#         [7.0687e-05, 6.0397e-05, 1.6957e-04, 1.4388e-06, 7.3190e-07, 3.0230e-07,
#          3.1738e-06, 9.9956e-01, 1.1390e-04, 2.0593e-05],
#         [1.1330e-07, 6.1239e-07, 7.7493e-07, 7.7836e-06, 3.8798e-06, 5.7859e-08,
#          9.9982e-01, 8.5829e-07, 1.6791e-04, 3.2249e-08],
#         [7.6163e-07, 1.6416e-06, 9.8689e-09, 9.9997e-01, 1.4911e-06, 4.3646e-07,
#          2.1677e-05, 1.2154e-06, 3.1678e-07, 2.0948e-06],
#         [7.7317e-04, 1.3238e-03, 2.4516e-06, 9.9641e-01, 4.8242e-04, 6.5792e-05,
#          9.9459e-06, 5.5943e-04, 2.0050e-06, 3.7559e-04],
#         [8.1445e-07, 3.6197e-05, 3.0095e-06, 5.3699e-07, 9.5293e-07, 4.0585e-07,
#          3.6151e-06, 9.9992e-01, 3.2578e-06, 2.8234e-05],
#         [3.9293e-06, 1.9308e-06, 1.4647e-05, 1.7120e-05, 1.4737e-06, 9.9994e-01,
#          1.8328e-05, 1.4403e-06, 3.3094e-07, 2.4367e-07],
#         [3.6182e-06, 1.8039e-04, 3.1068e-07, 1.2651e-04, 7.2204e-07, 2.0915e-07,
#          7.6844e-06, 2.8188e-05, 9.9965e-01, 3.0725e-09],
#         [9.9997e-01, 1.1118e-06, 2.1566e-06, 5.6973e-07, 1.1670e-06, 5.3300e-07,
#          1.1191e-05, 3.4098e-07, 2.6705e-06, 1.1177e-05],
#         [3.5646e-06, 4.5353e-06, 1.1675e-03, 9.9756e-01, 2.0576e-05, 6.4716e-05,
#          8.8729e-04, 1.3144e-07, 2.8626e-04, 5.5048e-06],
#         [1.6579e-05, 1.7359e-05, 9.9969e-01, 1.4642e-06, 4.6136e-05, 7.1147e-07,
#          1.6159e-07, 2.7117e-06, 6.6377e-05, 1.5416e-04]], device='cuda:0')  Target  tensor([8, 3, 2, 8, 5, 6, 7, 6, 3, 3, 7, 5, 8, 0, 3, 2], device='cuda:0')
# Prediction  tensor([[9.9990e-01, 2.0110e-06, 2.7145e-07, 6.3487e-05, 6.2147e-07, 3.1947e-06,
#          1.8582e-05, 6.6524e-06, 1.1350e-06, 8.7284e-07],
#         [2.7908e-04, 4.7359e-05, 4.7104e-06, 2.0425e-03, 9.6482e-06, 3.9185e-06,
#          9.9556e-01, 1.2844e-03, 1.1136e-04, 6.5254e-04],
#         [9.1456e-06, 1.5732e-04, 1.2624e-04, 6.2737e-05, 9.9469e-01, 9.4631e-05,
#          1.5752e-04, 5.5948e-04, 4.1387e-03, 7.8415e-06],
#         [1.5879e-03, 7.5596e-03, 5.8773e-03, 6.1629e-02, 3.1852e-02, 1.3390e-05,
#          2.2410e-03, 4.8548e-03, 6.6151e-01, 2.2288e-01],
#         [1.3070e-05, 3.6899e-04, 7.7505e-06, 4.9927e-05, 3.4742e-07, 4.1936e-07,
#          2.4143e-05, 1.5398e-06, 9.9952e-01, 1.5930e-05],
#         [1.5144e-06, 1.5874e-04, 1.1591e-03, 6.2574e-06, 5.0276e-06, 9.9838e-01,
#          2.6446e-05, 4.9476e-06, 2.5307e-04, 3.6542e-07],
#         [2.9041e-06, 6.7957e-07, 2.8200e-06, 6.5356e-07, 1.1410e-07, 9.9998e-01,
#          8.8419e-06, 1.1050e-08, 1.2960e-07, 1.2703e-07],
#         [6.3565e-07, 2.4815e-05, 1.6632e-04, 2.4499e-04, 4.9065e-05, 9.9919e-01,
#          7.6868e-06, 3.0473e-04, 6.2535e-06, 7.4563e-06],
#         [6.6333e-04, 9.9806e-01, 3.6398e-04, 9.2456e-05, 6.6924e-05, 4.8394e-07,
#          4.2971e-05, 3.8290e-04, 9.4083e-06, 3.1840e-04],
#         [3.5699e-06, 5.2597e-07, 8.3881e-08, 2.5314e-04, 1.5901e-05, 1.1024e-06,
#          9.9970e-01, 3.3194e-06, 1.8341e-05, 1.0912e-06],
#         [2.8503e-04, 3.3023e-04, 2.7117e-05, 3.4199e-07, 6.9208e-05, 9.9712e-01,
#          1.9433e-03, 7.4413e-06, 1.4686e-04, 6.6117e-05],
#         [1.3741e-05, 6.2956e-04, 4.1354e-05, 5.8218e-05, 1.7862e-05, 7.7749e-06,
#          3.6806e-07, 4.9037e-04, 2.9288e-06, 9.9874e-01],
#         [7.8052e-06, 1.3777e-06, 7.9819e-05, 6.2026e-05, 9.3476e-07, 5.0074e-08,
#          9.9982e-01, 2.4675e-07, 3.1312e-05, 2.3815e-08],
#         [7.8827e-04, 1.7361e-05, 5.0162e-06, 2.1646e-04, 1.3146e-06, 3.0648e-05,
#          1.9361e-04, 2.5105e-05, 4.1887e-05, 9.9868e-01],
#         [2.0792e-05, 2.9636e-03, 8.9163e-02, 9.7720e-05, 4.2538e-02, 1.1655e-03,
#          8.2401e-04, 3.2867e-06, 8.6320e-01, 2.7950e-05],
#         [6.2831e-05, 9.9701e-01, 2.3262e-03, 3.5969e-05, 2.8260e-05, 5.4911e-06,
#          1.8660e-04, 3.4110e-06, 1.5329e-05, 3.3047e-04]], device='cuda:0')  Target  tensor([0, 6, 4, 9, 8, 5, 5, 5, 1, 6, 5, 9, 6, 9, 2, 1], device='cuda:0')
# Prediction  tensor([[1.7663e-05, 2.0864e-05, 9.1685e-06, 9.9992e-01, 2.4586e-06, 5.3775e-06,
#          7.5883e-06, 2.2021e-06, 1.1606e-05, 2.0830e-07],
#         [8.5216e-04, 3.2326e-05, 9.9717e-01, 2.3297e-05, 3.7281e-04, 2.3019e-05,
#          4.0653e-06, 9.8968e-05, 1.2484e-03, 1.7445e-04],
#         [5.2809e-07, 9.5367e-04, 2.2049e-06, 9.9894e-01, 3.9137e-07, 2.1784e-07,
#          7.0178e-05, 4.8680e-06, 1.6753e-06, 2.8233e-05],
#         [9.8394e-06, 4.7322e-05, 2.2341e-03, 1.8019e-06, 9.9596e-01, 5.6473e-07,
#          2.0743e-05, 3.2987e-05, 1.6710e-03, 2.4859e-05],
#         [7.1648e-05, 5.5067e-04, 9.9816e-01, 1.0339e-04, 7.8101e-05, 2.5806e-04,
#          2.9992e-05, 1.3427e-04, 4.7325e-04, 1.4245e-04],
#         [6.2637e-05, 1.2857e-05, 1.7280e-05, 2.5012e-05, 1.5555e-04, 4.4687e-06,
#          1.8083e-06, 2.8287e-05, 9.9968e-01, 1.6079e-05],
#         [6.4204e-06, 9.9932e-01, 8.2289e-07, 2.0669e-04, 1.7595e-05, 1.1935e-08,
#          1.0393e-05, 1.0074e-04, 2.2112e-07, 3.3694e-04],
#         [2.0975e-04, 6.9209e-05, 9.9751e-01, 4.6781e-07, 3.3863e-04, 1.0668e-04,
#          1.7079e-03, 1.9307e-06, 5.2028e-05, 1.2176e-06],
#         [5.5948e-07, 4.1109e-07, 4.9169e-07, 2.9486e-07, 9.9992e-01, 1.8886e-07,
#          2.0175e-07, 5.8539e-06, 7.1228e-05, 1.9422e-07],
#         [9.9944e-01, 5.6537e-05, 2.9262e-05, 3.1099e-06, 5.8400e-08, 2.5573e-06,
#          3.9367e-04, 5.7487e-07, 1.0953e-05, 6.7228e-05],
#         [3.2341e-07, 6.8263e-07, 6.4162e-07, 2.0426e-07, 1.3899e-06, 4.9441e-08,
#          8.5740e-08, 1.0000e+00, 3.7665e-08, 5.6475e-08],
#         [1.4101e-05, 2.4198e-04, 9.9931e-01, 7.8691e-06, 4.6365e-05, 5.4151e-05,
#          3.5394e-07, 8.0578e-05, 5.2762e-07, 2.4724e-04],
#         [4.5978e-05, 7.1192e-06, 1.4378e-07, 2.0160e-04, 7.3219e-05, 4.8496e-07,
#          9.9921e-01, 4.0329e-04, 6.0344e-05, 2.2664e-06],
#         [2.6632e-06, 1.3624e-06, 1.3582e-04, 2.4003e-05, 9.9976e-01, 5.0596e-07,
#          1.0001e-06, 6.5096e-05, 9.7674e-06, 1.1783e-06],
#         [1.5095e-05, 2.3252e-04, 9.9953e-01, 7.0121e-07, 1.0613e-05, 2.3304e-05,
#          2.0068e-06, 5.5942e-07, 4.5812e-06, 1.7600e-04],
#         [3.7775e-06, 9.9662e-01, 3.4197e-05, 2.8419e-03, 2.1280e-06, 9.1623e-05,
#          3.9874e-05, 3.6473e-04, 5.7725e-07, 5.0139e-06]], device='cuda:0')  Target  tensor([3, 2, 3, 4, 2, 8, 1, 2, 4, 0, 7, 2, 6, 4, 2, 1], device='cuda:0')
# Prediction  tensor([[8.5760e-05, 4.4655e-04, 1.2156e-05, 9.9572e-01, 2.3142e-05, 6.5987e-04,
#          3.9775e-05, 3.5366e-05, 2.9591e-03, 1.7519e-05],
#         [1.4118e-04, 8.9846e-04, 6.4498e-05, 9.9529e-01, 4.2258e-04, 1.2943e-06,
#          4.4819e-05, 2.9968e-03, 3.7672e-05, 1.0440e-04],
#         [1.3159e-04, 9.9839e-01, 3.0793e-06, 6.1166e-04, 1.7915e-06, 1.4203e-04,
#          7.3345e-05, 6.0718e-04, 9.0200e-06, 3.2017e-05],
#         [1.3546e-07, 9.9389e-01, 5.7536e-05, 3.7865e-04, 1.0370e-04, 8.0973e-05,
#          6.3605e-04, 6.2206e-06, 1.4296e-03, 3.4191e-03],
#         [8.8452e-05, 1.5064e-06, 2.5730e-04, 8.6719e-04, 2.5706e-05, 1.5623e-06,
#          9.8894e-01, 9.6460e-03, 6.8484e-05, 1.0395e-04],
#         [2.2820e-04, 1.9784e-03, 1.3242e-06, 9.9090e-01, 6.0835e-08, 5.8560e-03,
#          4.5242e-04, 1.8744e-05, 5.5889e-04, 2.0067e-06],
#         [9.9987e-01, 4.6588e-06, 1.7663e-06, 9.2997e-06, 6.8440e-08, 8.9065e-07,
#          1.1262e-05, 2.8896e-06, 9.6619e-05, 2.2805e-06],
#         [2.7287e-06, 9.9593e-01, 1.2857e-05, 1.8410e-05, 2.1771e-04, 1.1157e-04,
#          5.5141e-04, 3.9200e-06, 8.3791e-04, 2.3173e-03],
#         [9.1876e-06, 9.9978e-01, 5.1876e-06, 2.7317e-05, 2.0098e-06, 3.6971e-06,
#          1.4884e-04, 1.5463e-07, 2.4766e-05, 1.2449e-06],
#         [2.0260e-03, 7.9108e-01, 3.3056e-04, 5.4526e-02, 6.7583e-03, 2.9680e-02,
#          1.6191e-02, 1.3800e-03, 4.7858e-02, 5.0170e-02],
#         [9.5846e-01, 1.2096e-02, 2.5611e-05, 9.5346e-04, 1.6223e-05, 2.3050e-02,
#          2.4096e-04, 4.8642e-03, 1.1468e-05, 2.8090e-04],
#         [7.2162e-04, 1.4560e-04, 1.7667e-03, 6.7804e-06, 1.2670e-05, 1.3227e-04,
#          5.5106e-07, 9.9719e-01, 9.6632e-08, 2.0430e-05],
#         [4.4344e-05, 2.7411e-04, 8.0304e-06, 1.6022e-06, 9.5037e-08, 7.3552e-06,
#          4.5717e-07, 3.8202e-05, 8.0966e-08, 9.9963e-01],
#         [1.0382e-04, 9.9081e-01, 2.1400e-03, 2.7119e-06, 3.0951e-05, 6.5036e-07,
#          1.7803e-04, 1.4752e-04, 1.3013e-06, 6.5838e-03],
#         [1.3893e-04, 3.6734e-07, 8.0282e-05, 1.0535e-06, 9.9967e-01, 1.7467e-05,
#          3.4279e-05, 1.3171e-07, 5.3680e-05, 5.3579e-07],
#         [1.5839e-06, 2.6050e-04, 8.7685e-08, 7.1458e-04, 6.0319e-07, 1.5573e-08,
#          1.6558e-05, 9.9821e-08, 9.9895e-01, 5.1396e-05]], device='cuda:0')  Target  tensor([3, 3, 1, 1, 6, 3, 0, 1, 1, 1, 0, 7, 9, 1, 4, 8], device='cuda:0')
# Prediction  tensor([[1.5327e-04, 1.6318e-03, 2.4136e-06, 9.9331e-01, 8.3226e-06, 3.8492e-03,
#          6.5645e-05, 7.1776e-04, 2.0090e-04, 6.3487e-05],
#         [4.1472e-04, 1.9760e-03, 5.9820e-06, 9.3342e-04, 1.5921e-04, 3.0608e-06,
#          9.9630e-01, 5.6235e-05, 7.4044e-05, 7.3429e-05],
#         [1.3788e-06, 2.0563e-04, 9.8159e-06, 6.1232e-06, 2.2012e-04, 2.2041e-05,
#          1.2146e-06, 9.9948e-01, 6.0216e-06, 4.9365e-05],
#         [3.9905e-05, 9.9630e-01, 1.2876e-06, 2.6144e-04, 6.5568e-04, 2.9203e-04,
#          5.2528e-06, 3.8823e-04, 3.0066e-06, 2.0484e-03],
#         [2.1825e-04, 9.9928e-01, 5.1159e-07, 2.7011e-04, 2.3469e-07, 4.6853e-06,
#          1.4264e-06, 2.0444e-05, 2.0321e-04, 5.5120e-06],
#         [4.0106e-03, 8.5961e-04, 2.7515e-05, 2.6543e-04, 2.2838e-05, 2.2551e-05,
#          6.9263e-04, 1.7437e-05, 1.6225e-06, 9.9408e-01],
#         [9.9137e-01, 8.4908e-05, 6.2848e-03, 7.8597e-06, 1.5066e-05, 2.3950e-04,
#          2.1213e-05, 1.0728e-04, 2.4017e-06, 1.8648e-03],
#         [1.6938e-05, 5.4255e-06, 1.1194e-05, 1.2588e-05, 2.1948e-06, 9.9982e-01,
#          4.3533e-05, 6.0273e-05, 2.4266e-05, 1.0522e-08],
#         [4.1226e-04, 2.5829e-05, 1.0520e-04, 1.4115e-03, 1.1218e-04, 1.1818e-07,
#          2.5984e-03, 9.9391e-01, 1.4271e-03, 1.0623e-06],
#         [1.8380e-01, 4.9814e-04, 1.8243e-05, 2.8281e-03, 1.9447e-02, 2.3249e-06,
#          7.9283e-01, 1.9561e-04, 3.6320e-04, 1.0805e-05],
#         [5.2308e-06, 5.5311e-05, 5.7376e-06, 1.1301e-07, 3.4604e-07, 9.9969e-01,
#          2.1712e-04, 8.9799e-06, 1.2482e-05, 2.4157e-06],
#         [3.7535e-07, 5.2919e-06, 9.8748e-05, 5.5044e-06, 6.4845e-04, 9.2194e-04,
#          1.8858e-04, 5.4879e-06, 9.9813e-01, 2.6231e-07],
#         [1.3358e-03, 2.2618e-03, 1.6006e-03, 1.8175e-06, 9.9161e-01, 2.6211e-04,
#          3.7777e-07, 1.2959e-03, 2.6630e-06, 1.6330e-03],
#         [1.5941e-07, 9.9972e-01, 4.8761e-05, 1.7015e-05, 1.2252e-06, 3.4298e-06,
#          7.0753e-07, 7.0183e-06, 1.2848e-04, 7.0866e-05],
#         [3.2491e-08, 2.5944e-04, 8.0747e-08, 9.9961e-01, 1.4609e-07, 9.7929e-08,
#          8.2276e-06, 1.6868e-05, 9.6220e-05, 5.8709e-06],
#         [7.7218e-06, 1.0869e-04, 3.9152e-04, 3.3647e-06, 2.8098e-04, 2.0149e-06,
#          4.9998e-06, 9.9919e-01, 8.4376e-06, 9.9231e-07]], device='cuda:0')  Target  tensor([3, 6, 7, 1, 1, 9, 0, 5, 7, 6, 5, 8, 4, 1, 3, 7], device='cuda:0')
# Prediction  tensor([[1.3990e-04, 9.9420e-01, 1.4482e-03, 5.1140e-04, 1.8629e-05, 3.2439e-03,
#          1.6698e-06, 8.8106e-05, 2.5222e-05, 3.2267e-04],
#         [2.6327e-05, 7.1358e-05, 3.3148e-04, 4.5835e-05, 2.4093e-03, 1.0894e-04,
#          9.3145e-06, 9.9694e-01, 5.9970e-05, 1.2140e-06],
#         [8.7691e-03, 8.9951e-02, 8.3372e-03, 1.6979e-01, 2.9679e-03, 2.5902e-01,
#          2.2117e-04, 3.6914e-01, 9.0613e-02, 1.1857e-03],
#         [9.9832e-01, 3.3398e-04, 6.0340e-05, 4.3718e-05, 5.4742e-04, 1.6699e-04,
#          2.4698e-05, 2.6179e-04, 1.2852e-07, 2.3934e-04],
#         [4.9846e-05, 1.5219e-03, 6.9706e-01, 1.7877e-05, 1.1141e-03, 3.3513e-04,
#          3.7957e-06, 2.0159e-05, 4.2087e-06, 2.9988e-01],
#         [6.3377e-04, 2.6915e-07, 2.9478e-04, 1.0136e-05, 2.4533e-04, 9.9880e-01,
#          5.6061e-06, 1.4443e-06, 1.0643e-05, 4.0643e-07],
#         [9.8580e-04, 1.1625e-03, 1.0186e-04, 1.3463e-05, 8.6624e-07, 9.9496e-01,
#          9.7838e-04, 3.9867e-06, 7.4738e-05, 1.7170e-03],
#         [2.7381e-04, 5.0466e-06, 5.5727e-04, 1.1752e-05, 1.1898e-03, 6.9635e-04,
#          2.2038e-04, 5.8705e-04, 9.9630e-01, 1.6036e-04],
#         [1.4443e-06, 5.4694e-06, 4.0598e-08, 1.1171e-04, 1.6927e-06, 4.8377e-08,
#          9.9986e-01, 1.8849e-05, 1.2707e-07, 4.2847e-08],
#         [1.2563e-06, 6.7246e-05, 1.7235e-06, 1.0907e-05, 2.3032e-06, 5.1708e-05,
#          4.1547e-05, 6.6252e-08, 9.9982e-01, 4.8211e-07],
#         [1.6676e-03, 1.2481e-05, 5.2610e-07, 4.0480e-05, 1.3590e-07, 5.6905e-08,
#          3.8648e-04, 9.9783e-01, 6.5042e-06, 5.6207e-05],
#         [1.4320e-07, 6.1281e-07, 6.5126e-08, 8.0005e-09, 5.7308e-09, 1.0000e+00,
#          7.3664e-07, 2.1311e-09, 1.4906e-08, 1.7128e-07],
#         [9.3514e-04, 9.4372e-06, 1.2088e-05, 9.0567e-04, 9.9743e-01, 1.0630e-04,
#          4.9805e-05, 1.8227e-05, 4.2780e-04, 1.0610e-04],
#         [2.5723e-03, 5.9819e-04, 1.3217e-05, 2.8282e-06, 1.4971e-04, 6.4935e-04,
#          4.5184e-05, 9.9271e-01, 3.6532e-07, 3.2638e-03],
#         [6.5714e-05, 7.2463e-06, 4.7816e-06, 4.2690e-06, 9.3220e-07, 9.9990e-01,
#          1.3892e-06, 3.6356e-06, 4.2856e-07, 7.7025e-06],
#         [9.7331e-06, 9.9979e-01, 2.2875e-06, 5.4067e-05, 2.4208e-07, 9.1991e-08,
#          1.0423e-04, 8.1124e-06, 1.9485e-05, 1.0510e-05]], device='cuda:0')  Target  tensor([1, 7, 8, 0, 2, 5, 5, 8, 6, 8, 7, 5, 4, 7, 5, 1], device='cuda:0')
# Prediction  tensor([[1.3461e-06, 1.2280e-04, 9.3164e-04, 1.3480e-04, 2.1018e-05, 3.4843e-06,
#          4.0732e-06, 5.6277e-05, 3.3825e-04, 9.9839e-01],
#         [7.9316e-05, 2.4708e-06, 4.9532e-06, 1.0237e-05, 1.0939e-04, 5.6523e-06,
#          1.2972e-06, 9.9966e-01, 7.0766e-05, 5.8311e-05],
#         [5.1641e-07, 1.4552e-05, 3.1648e-05, 6.8071e-06, 7.3644e-07, 9.9993e-01,
#          5.7435e-06, 5.5171e-06, 9.5527e-07, 3.1961e-06],
#         [8.9578e-06, 5.2194e-06, 2.2797e-07, 1.7517e-06, 5.6446e-07, 2.7489e-06,
#          5.6665e-07, 1.1255e-05, 1.5562e-09, 9.9997e-01],
#         [4.3899e-05, 3.0176e-03, 8.6852e-04, 5.4046e-02, 9.3712e-01, 1.0097e-05,
#          4.3360e-04, 8.6056e-05, 4.3012e-03, 7.2269e-05],
#         [9.9902e-01, 4.8669e-06, 7.7681e-06, 3.0068e-07, 1.2525e-04, 7.5181e-04,
#          7.1128e-06, 4.6653e-05, 6.5210e-06, 3.0606e-05],
#         [1.3191e-05, 1.6436e-05, 1.5620e-07, 7.1785e-05, 1.0504e-06, 1.7729e-04,
#          9.9941e-01, 2.0569e-04, 9.9394e-07, 1.0354e-04],
#         [3.5184e-04, 6.5368e-05, 4.6429e-06, 5.4763e-06, 9.9955e-01, 1.6778e-06,
#          1.4109e-06, 2.7761e-06, 1.2061e-05, 6.0517e-07],
#         [7.6271e-01, 2.1719e-05, 3.4944e-03, 7.9297e-03, 2.9838e-06, 3.5654e-03,
#          1.6285e-03, 8.7533e-02, 2.1775e-04, 1.3290e-01],
#         [9.9801e-01, 6.3114e-05, 3.2753e-06, 5.1398e-07, 5.8620e-07, 6.7945e-05,
#          1.0682e-05, 1.1050e-05, 5.2043e-07, 1.8339e-03],
#         [3.4591e-06, 2.2510e-05, 9.6294e-07, 6.9688e-04, 4.9317e-05, 2.5719e-06,
#          9.9459e-01, 1.4379e-05, 4.6167e-03, 3.6972e-07],
#         [4.7906e-04, 9.7456e-06, 1.7746e-07, 9.9916e-01, 6.3624e-05, 3.5644e-06,
#          7.3494e-05, 2.9478e-06, 7.7645e-07, 2.0624e-04],
#         [3.5953e-06, 4.4110e-06, 2.0627e-07, 9.9996e-01, 1.2795e-08, 3.1094e-07,
#          3.1333e-05, 8.5203e-08, 2.8879e-06, 7.1140e-07],
#         [2.8566e-01, 4.7811e-01, 2.6797e-04, 1.1130e-02, 8.5442e-04, 1.8578e-02,
#          8.1583e-02, 4.3502e-05, 6.5342e-02, 5.8424e-02],
#         [2.8329e-01, 3.2551e-01, 2.0242e-02, 3.2563e-01, 3.6462e-03, 4.5474e-04,
#          1.2924e-02, 2.5684e-02, 2.2212e-03, 4.0423e-04],
#         [3.4645e-05, 4.7982e-05, 1.3260e-04, 5.5694e-07, 9.9934e-01, 4.8480e-06,
#          5.8405e-07, 4.5406e-05, 3.8801e-04, 1.0167e-06]], device='cuda:0')  Target  tensor([9, 7, 5, 9, 4, 0, 6, 4, 7, 0, 6, 3, 3, 1, 2, 4], device='cuda:0')
# Prediction  tensor([[3.0835e-03, 9.9554e-01, 1.6394e-06, 3.0993e-04, 4.2604e-06, 4.5877e-06,
#          9.4414e-04, 5.6107e-06, 6.9455e-06, 1.0140e-04],
#         [4.3681e-06, 2.0137e-04, 1.9117e-05, 2.1474e-04, 4.4467e-06, 1.6024e-04,
#          9.9934e-01, 1.6917e-06, 4.6336e-05, 3.1519e-06],
#         [1.2442e-05, 1.9505e-04, 8.9811e-06, 9.1705e-06, 9.9917e-01, 5.5262e-06,
#          1.7546e-05, 9.9021e-05, 4.8646e-04, 5.9080e-07],
#         [5.6388e-05, 1.4379e-04, 4.5562e-05, 9.9814e-01, 2.3188e-04, 2.9721e-04,
#          8.5679e-04, 8.9280e-06, 2.1878e-04, 5.1297e-06],
#         [1.3200e-05, 6.0706e-03, 8.0179e-04, 3.3470e-05, 7.8839e-04, 2.9544e-03,
#          3.9979e-04, 1.5906e-06, 9.8884e-01, 9.3023e-05],
#         [5.1031e-04, 1.5640e-05, 9.9208e-01, 5.4347e-07, 5.1048e-04, 8.4124e-04,
#          1.8229e-05, 1.5899e-03, 5.5356e-05, 4.3807e-03],
#         [3.7970e-07, 8.6239e-07, 2.2636e-06, 1.0383e-06, 1.1785e-06, 8.6295e-07,
#          3.8575e-09, 1.0566e-06, 2.6769e-07, 9.9999e-01],
#         [1.3023e-03, 5.6882e-04, 1.0857e-04, 4.7276e-06, 2.2728e-04, 1.1378e-05,
#          1.0906e-03, 9.9631e-01, 1.6532e-04, 2.0711e-04],
#         [9.9897e-01, 3.5287e-06, 2.7773e-06, 3.1803e-07, 3.4106e-05, 2.1235e-05,
#          2.0316e-04, 4.7534e-06, 8.0645e-07, 7.5506e-04],
#         [9.6824e-08, 1.1348e-06, 1.9873e-09, 9.9999e-01, 5.6151e-09, 1.6085e-07,
#          4.5114e-06, 6.8233e-07, 3.9195e-07, 5.4540e-08],
#         [1.1898e-05, 9.9450e-01, 5.3304e-07, 2.8853e-03, 7.7675e-07, 2.4927e-03,
#          3.4029e-05, 7.2001e-06, 6.8918e-05, 2.6929e-06],
#         [6.3567e-04, 3.2807e-04, 2.0578e-04, 1.1764e-04, 1.2800e-04, 1.2369e-04,
#          1.4757e-05, 9.9844e-01, 8.4774e-06, 6.7441e-07],
#         [6.1737e-02, 8.8308e-01, 7.1092e-04, 1.1293e-04, 6.8530e-04, 2.3074e-05,
#          3.3761e-03, 1.0506e-02, 1.0014e-03, 3.8768e-02],
#         [9.9274e-05, 2.4808e-05, 1.2888e-04, 5.0197e-04, 2.2287e-01, 7.1093e-02,
#          1.4184e-02, 5.2402e-05, 6.9105e-01, 2.6916e-06],
#         [1.0937e-07, 5.0132e-07, 4.9140e-07, 1.6779e-07, 1.8410e-09, 9.9999e-01,
#          6.4452e-06, 3.8937e-09, 1.5230e-07, 1.2458e-06],
#         [8.2159e-05, 9.9903e-01, 4.9396e-07, 6.3701e-04, 1.8050e-07, 1.9788e-06,
#          2.3179e-04, 1.2935e-05, 5.9980e-07, 3.6307e-06]], device='cuda:0')  Target  tensor([1, 6, 4, 3, 8, 2, 9, 7, 0, 3, 1, 7, 1, 4, 5, 1], device='cuda:0')
# Prediction  tensor([[3.9471e-05, 3.1519e-05, 3.3902e-04, 2.5838e-05, 9.9917e-01, 3.2530e-05,
#          5.5437e-05, 2.5350e-06, 3.0710e-04, 1.3063e-07],
#         [4.9297e-07, 1.0504e-06, 1.1575e-04, 7.7696e-05, 3.0717e-04, 3.4424e-07,
#          1.3726e-04, 2.3450e-06, 9.9936e-01, 2.4341e-07],
#         [4.1452e-04, 6.4327e-05, 8.6669e-06, 1.2677e-03, 8.6475e-03, 2.7663e-05,
#          9.8923e-01, 1.8506e-06, 3.4048e-04, 3.4238e-07],
#         [4.6796e-04, 1.0814e-03, 4.4791e-07, 2.5566e-02, 1.0114e-05, 1.4850e-03,
#          1.5174e-02, 9.5510e-01, 9.7553e-04, 1.4129e-04],
#         [1.3703e-07, 9.9777e-01, 3.1936e-05, 1.5919e-03, 1.6272e-06, 9.5737e-05,
#          1.4598e-05, 1.1423e-04, 3.0410e-04, 7.3154e-05],
#         [8.8936e-07, 5.2460e-05, 9.9691e-01, 8.0450e-06, 6.6319e-05, 2.6861e-03,
#          3.0015e-05, 4.6515e-06, 2.3937e-04, 5.7558e-06],
#         [5.6135e-05, 4.8053e-06, 1.1322e-05, 3.9025e-07, 1.3957e-04, 9.9957e-01,
#          1.3460e-04, 4.9855e-06, 8.1079e-05, 2.1913e-07],
#         [6.7623e-05, 8.9535e-04, 4.8567e-06, 2.1631e-01, 7.9511e-06, 1.3722e-06,
#          7.8232e-01, 2.7073e-04, 3.7781e-06, 1.1219e-04],
#         [4.0392e-04, 1.5451e-05, 5.9773e-03, 1.8794e-04, 9.9248e-01, 2.5583e-06,
#          3.5236e-05, 1.7419e-05, 8.7522e-04, 4.1644e-06],
#         [2.9975e-05, 1.1840e-06, 1.0718e-06, 6.4545e-04, 1.1844e-06, 8.1439e-08,
#          9.9878e-01, 5.0026e-04, 4.1902e-05, 5.1319e-07],
#         [8.7456e-05, 1.1546e-04, 8.0570e-05, 9.9775e-05, 1.4296e-05, 1.4284e-06,
#          4.1160e-07, 8.5461e-07, 9.9959e-01, 1.3842e-05],
#         [2.4133e-06, 3.1637e-07, 2.0650e-05, 1.0740e-06, 2.9186e-05, 2.1540e-07,
#          9.9922e-01, 6.4251e-07, 7.2092e-04, 6.5010e-09],
#         [2.9085e-06, 2.5620e-05, 1.8577e-06, 9.9971e-01, 5.5948e-05, 6.7822e-06,
#          1.0574e-05, 1.9874e-07, 1.8237e-04, 7.2453e-07],
#         [8.0871e-04, 4.0477e-04, 1.5332e-06, 1.9963e-05, 1.7388e-06, 1.3287e-06,
#          3.2021e-06, 1.3951e-06, 5.1382e-08, 9.9876e-01],
#         [1.3538e-05, 3.1012e-07, 2.6367e-05, 3.0334e-07, 1.7484e-06, 2.1977e-08,
#          5.5051e-07, 9.9995e-01, 4.3164e-07, 1.8421e-06],
#         [3.6627e-04, 2.2674e-04, 1.7060e-04, 1.9657e-04, 5.7030e-04, 2.5159e-05,
#          3.7212e-07, 9.9834e-01, 1.1082e-05, 9.5931e-05]], device='cuda:0')  Target  tensor([4, 8, 6, 7, 1, 2, 5, 6, 4, 6, 8, 6, 3, 9, 7, 7], device='cuda:0')
# Prediction  tensor([[1.3181e-04, 6.0728e-05, 1.2761e-05, 4.8783e-06, 3.0546e-05, 1.0111e-05,
#          7.8606e-08, 2.0065e-05, 4.9521e-06, 9.9972e-01],
#         [1.4694e-06, 8.0559e-07, 9.9967e-01, 9.2859e-07, 5.8930e-06, 2.3401e-04,
#          1.4592e-07, 1.3756e-07, 1.1184e-05, 7.2877e-05],
#         [1.5568e-05, 9.9384e-01, 2.4666e-03, 3.9699e-04, 1.9537e-05, 2.5216e-03,
#          1.3007e-06, 5.6635e-04, 4.7555e-05, 1.2413e-04],
#         [7.3523e-06, 2.7159e-05, 9.9993e-01, 2.3235e-07, 3.6545e-06, 1.1142e-07,
#          6.2109e-07, 3.1753e-05, 7.2795e-07, 7.4517e-07],
#         [9.9991e-01, 4.7339e-06, 6.1872e-05, 5.6010e-07, 3.5065e-07, 2.7773e-06,
#          3.3431e-08, 8.8438e-08, 7.6480e-08, 2.2800e-05],
#         [4.3208e-06, 5.8837e-08, 3.5356e-08, 8.5409e-05, 6.3256e-07, 1.9758e-07,
#          9.9990e-01, 1.3455e-06, 1.1183e-07, 5.2642e-06],
#         [7.9095e-05, 1.2202e-03, 2.8203e-04, 2.8251e-06, 1.1488e-05, 2.2735e-04,
#          2.5182e-06, 2.7701e-06, 9.9815e-01, 1.8912e-05],
#         [1.7220e-04, 1.2931e-05, 1.8377e-05, 9.9951e-01, 7.3736e-07, 5.7115e-07,
#          1.4489e-05, 1.0140e-04, 1.6626e-04, 5.8775e-07],
#         [2.3053e-06, 7.3255e-05, 9.0170e-04, 2.9258e-06, 7.3034e-06, 1.6418e-05,
#          9.9841e-01, 2.1448e-05, 5.6926e-04, 1.9317e-08],
#         [6.1973e-05, 3.0750e-04, 9.6081e-01, 3.4075e-03, 2.4857e-02, 6.6048e-04,
#          4.2938e-03, 5.3843e-03, 2.1367e-04, 8.5403e-06],
#         [2.5795e-05, 1.8019e-07, 9.9996e-01, 5.7728e-08, 1.7128e-06, 1.2130e-07,
#          3.0930e-07, 3.1622e-06, 3.0051e-07, 8.4483e-06],
#         [2.5055e-05, 1.7107e-03, 1.6202e-05, 2.4090e-03, 1.6122e-04, 9.9377e-01,
#          1.2472e-04, 8.2073e-04, 1.5582e-05, 9.4722e-04],
#         [4.2143e-05, 3.3965e-06, 9.9691e-01, 1.0566e-05, 1.8066e-03, 3.7821e-04,
#          7.2679e-06, 2.5038e-06, 3.5649e-04, 4.7800e-04],
#         [2.9976e-05, 1.7736e-06, 6.4645e-04, 6.7130e-07, 9.9906e-01, 1.2081e-04,
#          9.3419e-05, 3.1284e-06, 4.2002e-05, 7.9297e-07],
#         [8.1615e-06, 1.5915e-04, 1.5127e-05, 6.1454e-04, 3.6635e-06, 9.9863e-01,
#          9.0704e-05, 3.1353e-04, 1.4768e-04, 1.5032e-05],
#         [1.6310e-04, 5.4108e-07, 9.9971e-01, 6.5637e-05, 3.2947e-06, 4.0189e-05,
#          8.4695e-08, 5.8379e-07, 4.1302e-07, 1.7379e-05]], device='cuda:0')  Target  tensor([9, 2, 1, 2, 0, 6, 8, 3, 6, 2, 2, 5, 2, 4, 5, 2], device='cuda:0')
# Prediction  tensor([[5.7770e-05, 4.8240e-06, 3.8264e-06, 8.0269e-05, 7.2750e-06, 2.2055e-05,
#          1.3402e-05, 9.9980e-01, 2.3866e-06, 7.0392e-06],
#         [1.9937e-05, 1.1427e-06, 1.1815e-04, 1.0095e-03, 1.5403e-04, 2.5407e-07,
#          2.7299e-04, 4.0673e-05, 9.9836e-01, 2.7411e-05],
#         [7.2736e-05, 1.2296e-04, 2.5759e-03, 6.1351e-06, 9.9685e-01, 2.4163e-06,
#          4.1184e-06, 1.6420e-04, 1.9064e-04, 7.3094e-06],
#         [4.1727e-06, 6.6142e-04, 3.5529e-07, 9.9867e-01, 3.5005e-05, 5.4418e-08,
#          2.9738e-04, 5.9908e-06, 2.5929e-05, 3.0411e-04],
#         [7.8463e-05, 2.8698e-03, 1.2177e-05, 2.4260e-05, 1.2223e-05, 6.1524e-07,
#          1.9260e-05, 9.8381e-05, 5.1553e-05, 9.9683e-01],
#         [3.5051e-03, 9.8060e-01, 2.2228e-03, 1.0948e-03, 9.6143e-03, 5.7329e-05,
#          1.4188e-04, 6.6190e-04, 2.0836e-03, 1.8359e-05],
#         [3.3862e-04, 1.4858e-03, 1.2473e-05, 3.4700e-03, 1.8040e-04, 6.1106e-07,
#          9.9361e-01, 7.1957e-04, 1.5186e-04, 3.0308e-05],
#         [2.1130e-04, 9.9815e-01, 1.1911e-05, 5.4432e-06, 4.6072e-06, 1.2659e-07,
#          4.5098e-04, 9.3139e-06, 5.6078e-06, 1.1519e-03],
#         [5.4582e-06, 4.6905e-06, 1.7431e-06, 4.5888e-06, 3.2498e-06, 7.3665e-07,
# ...
#         [5.3013e-04, 3.7654e-06, 3.1551e-05, 2.5579e-03, 3.1613e-04, 9.7739e-01,
#          1.9034e-02, 3.4640e-05, 9.7175e-05, 2.5822e-06],
#         [2.0971e-04, 3.2254e-04, 8.8722e-06, 8.6217e-06, 4.1304e-07, 7.3171e-05,
#          4.7352e-05, 9.9928e-01, 6.7911e-06, 3.9307e-05],
#         [4.8676e-06, 9.5551e-05, 6.7002e-04, 4.3380e-04, 3.9946e-05, 1.0997e-06,
#          1.9040e-05, 4.6329e-03, 4.1698e-04, 9.9369e-01],
#         [6.1391e-07, 5.6059e-07, 2.4278e-08, 1.2644e-06, 2.7115e-08, 2.4888e-08,
#          1.2208e-05, 1.4099e-06, 9.9998e-01, 1.7355e-09],
#         [4.1475e-05, 1.2597e-03, 3.8218e-06, 7.5065e-05, 1.8720e-06, 7.8237e-06,
#          5.8559e-06, 3.7222e-05, 1.8967e-06, 9.9857e-01],
#         [1.6851e-03, 1.8751e-03, 1.4751e-04, 2.7387e-06, 2.4371e-05, 3.5652e-06,
#          1.5122e-05, 4.2247e-03, 2.2597e-07, 9.9202e-01],
#         [1.1224e-03, 2.6315e-03, 6.1972e-03, 9.6003e-01, 2.9685e-04, 2.0778e-06,
#          2.0795e-02, 9.4705e-04, 1.2153e-04, 7.8585e-03],
#         [4.4246e-05, 1.5939e-04, 1.5944e-05, 1.1730e-05, 4.4629e-06, 1.5139e-05,
#          2.2052e-05, 9.9902e-01, 3.4219e-06, 7.0236e-04],
#         [1.3880e-04, 1.0695e-04, 3.9534e-04, 2.9403e-03, 1.4033e-04, 2.3639e-04,
#          3.6629e-06, 9.9576e-01, 2.0933e-04, 6.9565e-05],
#         [5.5666e-06, 1.1658e-05, 2.9842e-05, 9.9990e-01, 3.3362e-05, 1.0476e-07,
#          5.2240e-06, 6.6869e-08, 9.7638e-06, 1.5265e-07],
#         [1.4145e-06, 1.0659e-05, 3.6412e-05, 1.1843e-07, 5.9820e-03, 4.4913e-07,
#          5.4448e-06, 8.8191e-06, 9.9395e-01, 1.1351e-07],
#         [4.5960e-04, 2.3734e-03, 7.3421e-05, 9.8975e-01, 2.5602e-05, 3.0171e-06,
#          8.2518e-04, 5.9393e-07, 2.4998e-03, 3.9849e-03],
#         [1.5409e-04, 7.7032e-04, 6.9296e-05, 3.2834e-03, 1.5741e-04, 1.5305e-06,
#          3.2691e-05, 6.8330e-05, 9.9544e-01, 2.1556e-05]], device='cuda:0')  Target  tensor([4, 4, 1, 5, 7, 9, 8, 9, 9, 3, 7, 7, 3, 8, 3, 8], device='cuda:0')
# Prediction  tensor([[2.4876e-05, 1.9940e-05, 2.8416e-07, 2.2249e-04, 9.3540e-06, 3.2044e-03,
#          9.9405e-01, 1.1992e-04, 2.1684e-03, 1.8089e-04],
#         [5.9325e-05, 1.1905e-04, 9.9330e-01, 9.5963e-04, 1.9256e-03, 2.1254e-04,
#          1.7618e-05, 3.2793e-03, 1.1972e-04, 1.1057e-05],
#         [6.1293e-05, 3.1626e-06, 7.8055e-05, 3.0862e-05, 2.1825e-04, 3.2510e-06,
#          9.9869e-01, 2.9962e-05, 8.8391e-04, 1.8934e-07],
#         [8.8166e-05, 2.3779e-05, 9.2638e-07, 1.0210e-04, 5.8308e-04, 6.5083e-08,
#          9.9913e-01, 2.8826e-06, 6.4172e-05, 6.0287e-06],
#         [3.6638e-06, 3.8481e-06, 4.7500e-05, 3.8732e-06, 2.6552e-04, 4.3852e-04,
#          9.5070e-05, 1.2701e-04, 9.9901e-01, 5.3965e-07],
#         [1.2548e-04, 9.3361e-05, 1.7942e-04, 9.9891e-01, 4.4899e-07, 8.6720e-06,
#          5.9275e-06, 3.3086e-04, 3.1780e-04, 2.4495e-05],
#         [2.4709e-03, 9.7228e-05, 1.6278e-05, 8.6497e-05, 1.9352e-04, 5.2705e-07,
#          6.5222e-05, 1.1929e-05, 9.9706e-01, 2.3806e-07],
#         [7.1154e-08, 8.6868e-07, 8.8596e-06, 3.2760e-06, 1.1273e-04, 1.4172e-06,
#          6.2945e-06, 3.7699e-07, 9.9987e-01, 3.6581e-07],
#         [2.1830e-03, 9.9490e-01, 3.8933e-05, 5.3090e-05, 1.2130e-05, 2.4971e-03,
#          1.3783e-06, 2.3820e-04, 7.8998e-06, 7.0428e-05],
#         [2.2172e-06, 8.2432e-06, 9.0846e-05, 1.0449e-04, 7.9183e-05, 1.8139e-05,
#          1.2530e-06, 9.9969e-01, 4.4757e-07, 6.7586e-06],
#         [5.3808e-05, 1.0896e-04, 6.6716e-08, 9.9588e-01, 1.3885e-06, 7.9668e-04,
#          3.0366e-03, 1.1595e-04, 9.8722e-06, 1.0084e-06],
#         [1.1594e-05, 1.1499e-04, 9.9725e-01, 3.3245e-04, 1.8065e-03, 8.4422e-06,
#          5.4731e-06, 1.4959e-04, 3.1085e-04, 1.1725e-05],
#         [2.7525e-05, 1.2221e-04, 1.4991e-05, 4.7052e-06, 2.8885e-05, 9.9879e-01,
#          5.1883e-04, 7.5877e-07, 8.7814e-07, 4.9218e-04],
#         [2.0832e-06, 1.0703e-05, 2.5718e-09, 9.9996e-01, 6.8109e-07, 5.1556e-07,
#          1.0379e-05, 6.2084e-08, 1.5749e-05, 2.2903e-07],
#         [8.0582e-05, 3.4299e-05, 2.0175e-06, 1.9344e-07, 9.8314e-06, 2.4464e-07,
#          4.5379e-06, 1.7176e-05, 1.6691e-07, 9.9985e-01],
#         [1.8683e-04, 9.8780e-01, 2.5389e-04, 5.0179e-03, 1.4221e-05, 2.0894e-04,
#          6.1877e-03, 1.2425e-05, 3.2612e-06, 3.1853e-04]], device='cuda:0')  Target  tensor([6, 2, 6, 6, 8, 3, 8, 8, 1, 7, 3, 2, 5, 3, 9, 1], device='cuda:0')
# Prediction  tensor([[2.4735e-05, 7.6110e-06, 2.6250e-05, 1.1151e-05, 4.1654e-06, 9.9992e-01,
#          1.0038e-06, 3.4900e-06, 1.3232e-06, 6.3036e-07],
#         [6.7643e-07, 5.5274e-06, 2.0589e-07, 2.1562e-04, 3.9472e-05, 1.8403e-08,
#          9.9973e-01, 5.4341e-06, 3.7921e-06, 8.6126e-08],
#         [9.6851e-07, 1.9233e-05, 5.7419e-05, 4.6288e-07, 5.9886e-04, 1.4179e-04,
#          3.6541e-06, 3.3201e-05, 9.9914e-01, 1.2364e-06],
#         [1.9340e-06, 3.5229e-05, 1.7875e-06, 6.2559e-06, 6.2485e-07, 3.0571e-07,
#          3.7968e-07, 9.9994e-01, 1.4531e-06, 7.2116e-06],
#         [6.9267e-06, 7.1017e-05, 8.1477e-07, 9.9937e-01, 3.4109e-05, 4.5887e-04,
#          1.0524e-05, 1.0293e-06, 3.9059e-05, 7.3191e-06],
#         [4.8197e-06, 1.5216e-04, 4.6774e-06, 1.2604e-05, 9.0594e-05, 1.6476e-05,
#          2.2662e-03, 5.1106e-07, 9.9745e-01, 9.1022e-07],
#         [2.2244e-04, 1.4243e-06, 4.3444e-07, 1.6112e-04, 1.1726e-05, 3.8831e-05,
#          9.9842e-01, 1.0093e-04, 2.3297e-06, 1.0417e-03],
#         [1.0257e-05, 8.1133e-05, 3.3621e-07, 9.3093e-06, 1.0476e-05, 1.5558e-06,
#          9.9981e-01, 5.4414e-05, 3.4698e-07, 1.7589e-05],
#         [3.1539e-04, 9.9247e-01, 6.2455e-05, 3.7475e-03, 4.5715e-05, 1.3986e-05,
#          1.1118e-03, 1.6424e-03, 4.7908e-06, 5.8503e-04],
#         [4.3680e-06, 1.5933e-05, 2.4473e-07, 3.5562e-04, 1.9549e-06, 1.6762e-07,
#          9.9962e-01, 5.9033e-07, 4.7153e-07, 4.8530e-08],
#         [2.6614e-04, 3.5924e-04, 1.7439e-06, 8.1714e-06, 5.5482e-08, 4.6151e-07,
#          3.6757e-06, 9.5706e-07, 5.0025e-07, 9.9936e-01],
#         [6.7314e-04, 9.9857e-01, 2.7514e-06, 6.1757e-05, 2.6863e-05, 2.2455e-05,
#          2.7572e-06, 5.8938e-04, 2.5135e-05, 2.1947e-05],
#         [2.6806e-06, 1.0138e-04, 6.3903e-05, 6.3367e-07, 9.9938e-01, 1.7879e-05,
#          8.7263e-07, 4.0220e-04, 2.7171e-05, 6.0890e-06],
#         [5.7522e-06, 1.0400e-04, 9.9839e-01, 9.0522e-08, 6.3571e-06, 7.3038e-06,
#          5.9954e-08, 1.9258e-06, 1.4883e-06, 1.4820e-03],
#         [9.9820e-01, 2.5899e-05, 1.3154e-03, 1.7626e-05, 8.4346e-06, 1.3132e-04,
#          7.5662e-06, 2.3180e-04, 1.2005e-05, 5.3761e-05],
#         [6.2490e-03, 6.6756e-03, 8.0820e-05, 8.7547e-05, 4.7285e-04, 7.9947e-04,
#          1.1148e-01, 1.6366e-04, 1.4415e-01, 7.2984e-01]], device='cuda:0')  Target  tensor([5, 6, 8, 7, 3, 8, 6, 6, 1, 6, 9, 1, 4, 2, 0, 1], device='cuda:0')
# Prediction  tensor([[4.8519e-03, 3.4302e-03, 1.6209e-04, 2.3821e-05, 1.5247e-05, 2.2174e-04,
#          9.9117e-01, 9.5190e-07, 8.4653e-05, 4.3779e-05],
#         [6.7507e-03, 1.7484e-03, 9.8575e-01, 8.0200e-05, 7.5876e-05, 2.7374e-04,
#          4.1783e-03, 1.7030e-04, 9.3651e-04, 3.5705e-05],
#         [7.2041e-06, 1.8334e-04, 3.5738e-05, 1.8908e-06, 3.5366e-05, 1.0030e-06,
#          2.3415e-07, 1.1107e-07, 9.9973e-01, 3.1103e-07],
#         [2.9829e-07, 8.9163e-06, 1.6824e-05, 3.3579e-05, 1.4235e-06, 3.4309e-06,
#          1.2171e-07, 4.3306e-05, 1.1277e-06, 9.9989e-01],
#         [1.4767e-05, 8.4489e-03, 1.8640e-02, 1.9775e-03, 1.6975e-04, 1.1714e-01,
#          4.6598e-04, 1.9984e-03, 5.5224e-02, 7.9592e-01],
#         [3.5595e-05, 7.9640e-06, 3.5070e-05, 2.9279e-07, 9.9983e-01, 3.3164e-06,
#          8.0588e-05, 7.4881e-09, 3.1818e-06, 4.6928e-06],
#         [2.5944e-04, 1.4746e-04, 9.2981e-01, 3.2053e-02, 3.3777e-02, 5.4805e-04,
#          6.2387e-04, 2.2504e-03, 5.2168e-04, 1.2849e-05],
#         [2.8361e-06, 1.3213e-04, 8.7222e-08, 9.9938e-01, 1.4197e-06, 4.2813e-04,
#          4.1658e-05, 2.8173e-06, 5.3368e-06, 4.1285e-06],
#         [9.9639e-01, 7.0505e-04, 9.1121e-05, 9.9583e-06, 4.6763e-06, 8.4771e-07,
#          6.5004e-05, 7.6091e-04, 3.9691e-05, 1.9366e-03],
#         [3.4890e-07, 6.5092e-06, 7.0350e-07, 8.5588e-06, 1.4753e-07, 9.9997e-01,
#          7.3626e-06, 6.0965e-07, 4.2736e-06, 3.2068e-06],
#         [3.1204e-06, 3.9460e-05, 3.0887e-06, 3.6773e-05, 5.1908e-05, 3.5686e-06,
#          9.9976e-01, 2.3364e-07, 1.0056e-04, 3.9752e-08],
#         [3.4866e-05, 1.1239e-03, 2.1988e-06, 9.9852e-01, 2.3728e-06, 1.7784e-06,
#          4.3978e-05, 1.4088e-06, 7.5132e-05, 1.9309e-04],
#         [5.8249e-05, 9.9548e-01, 4.3476e-04, 1.7731e-03, 3.0665e-04, 1.4010e-04,
#          4.8124e-06, 9.5476e-06, 4.3287e-05, 1.7447e-03],
#         [1.1007e-04, 3.9213e-03, 3.0924e-06, 8.5915e-05, 1.4144e-06, 1.6346e-08,
#          9.9545e-01, 3.8742e-04, 2.9884e-05, 7.9918e-06],
#         [6.2319e-04, 1.6643e-06, 1.0551e-04, 8.0873e-06, 2.8614e-04, 4.0449e-04,
#          3.2072e-05, 1.2139e-07, 8.1284e-05, 9.9846e-01],
#         [7.0178e-06, 3.8363e-05, 7.0400e-06, 4.7219e-05, 1.3640e-07, 2.6289e-06,
#          7.6305e-06, 9.9845e-06, 9.9987e-01, 8.6045e-06]], device='cuda:0')  Target  tensor([6, 2, 8, 9, 9, 4, 2, 3, 0, 5, 6, 3, 1, 6, 9, 8], device='cuda:0')
# Prediction  tensor([[2.5345e-03, 9.8521e-01, 4.2975e-05, 2.5647e-04, 1.3372e-03, 2.5792e-04,
#          1.6110e-03, 7.2723e-03, 1.2159e-04, 1.3534e-03],
#         [1.3256e-03, 9.4909e-04, 1.1648e-05, 8.9283e-04, 1.0425e-05, 9.9537e-01,
#          1.8886e-05, 4.5955e-05, 4.6297e-04, 9.0840e-04],
#         [5.9991e-05, 4.1524e-05, 1.2219e-04, 7.9813e-07, 9.9974e-01, 1.1802e-06,
#          1.8504e-05, 6.3601e-06, 1.0119e-05, 3.9614e-06],
#         [1.1805e-06, 1.9574e-06, 4.8452e-06, 4.9245e-07, 4.3637e-07, 1.0046e-06,
#          5.9525e-08, 9.9999e-01, 2.9491e-08, 2.1449e-06],
#         [1.8905e-07, 3.5371e-06, 2.6223e-06, 1.0343e-06, 3.7143e-06, 4.3199e-07,
#          6.8611e-05, 6.7469e-08, 9.9992e-01, 2.0475e-08],
#         [7.4412e-04, 9.9788e-01, 2.2164e-06, 6.4452e-04, 4.1459e-06, 1.0318e-08,
#          6.1479e-04, 2.6037e-06, 2.5048e-05, 8.1085e-05],
#         [2.4380e-04, 1.0611e-05, 4.5223e-06, 9.9858e-01, 2.6988e-06, 3.4519e-08,
#          9.3533e-05, 1.0070e-03, 6.1930e-05, 6.4035e-07],
#         [1.8000e-06, 5.2099e-06, 3.1865e-09, 9.9987e-01, 1.0574e-06, 3.0060e-07,
#          8.4123e-05, 2.5841e-06, 3.6323e-05, 1.2680e-06],
#         [9.5781e-07, 5.6428e-05, 7.6693e-06, 2.9345e-06, 1.1804e-06, 4.8145e-07,
#          5.9347e-08, 9.9993e-01, 2.0235e-08, 3.2310e-06],
#         [5.6797e-06, 1.4902e-04, 3.0087e-06, 1.0112e-05, 2.5364e-06, 2.4514e-07,
#          2.4068e-05, 9.9979e-01, 7.7884e-08, 1.8657e-05],
#         [3.0219e-06, 8.3759e-07, 1.6381e-05, 1.0975e-06, 2.0175e-05, 2.1391e-07,
#          5.5941e-09, 2.1707e-07, 1.7318e-07, 9.9996e-01],
#         [1.1760e-04, 9.9919e-01, 3.6222e-05, 1.9466e-05, 4.2814e-04, 7.3409e-06,
#          7.4246e-05, 6.6035e-05, 5.5134e-06, 6.0120e-05],
#         [3.9644e-07, 8.0553e-05, 5.7684e-09, 9.9988e-01, 5.3390e-09, 4.1691e-08,
#          2.7484e-05, 2.1991e-07, 8.4992e-06, 8.0719e-07],
#         [6.9530e-07, 3.2873e-06, 4.6729e-05, 1.1175e-06, 4.0048e-06, 3.0255e-06,
#          9.3799e-07, 9.9994e-01, 6.9796e-07, 3.9297e-06],
#         [3.7022e-05, 1.7084e-04, 8.8376e-04, 5.3345e-07, 5.2944e-05, 1.0192e-04,
#          9.9827e-01, 1.7160e-06, 4.8169e-04, 9.8532e-08],
#         [1.2456e-06, 2.6899e-07, 2.0555e-08, 9.9933e-01, 3.7699e-09, 5.4890e-07,
#          6.4323e-04, 1.8419e-07, 2.2179e-05, 2.1580e-07]], device='cuda:0')  Target  tensor([1, 5, 4, 7, 8, 1, 3, 3, 7, 7, 9, 1, 3, 7, 6, 3], device='cuda:0')
# Prediction  tensor([[9.9816e-01, 1.3410e-04, 2.4583e-04, 1.3098e-04, 1.6944e-04, 1.0075e-06,
#          2.9205e-05, 3.2686e-06, 3.8561e-06, 1.1267e-03],
#         [7.9965e-04, 3.6602e-04, 1.3594e-05, 7.6078e-06, 4.1335e-05, 8.6877e-06,
#          1.1275e-05, 9.9848e-01, 4.1509e-07, 2.6865e-04],
#         [9.9667e-01, 2.0035e-05, 1.3299e-03, 4.2040e-05, 5.2412e-06, 1.0690e-05,
#          4.1189e-05, 6.7994e-04, 6.2256e-04, 5.7914e-04],
#         [3.2423e-05, 1.3797e-04, 1.9817e-05, 2.0628e-04, 1.9560e-04, 9.9789e-01,
#          5.2621e-05, 7.3948e-05, 3.4552e-05, 1.3569e-03],
#         [1.4674e-04, 1.7834e-06, 9.9947e-01, 3.5254e-07, 1.4978e-05, 2.2619e-06,
#          6.2441e-07, 3.4258e-05, 1.0390e-06, 3.2905e-04],
#         [4.2602e-04, 4.3284e-03, 3.8990e-05, 1.3645e-04, 1.9626e-05, 1.2172e-03,
#          9.9060e-01, 4.4670e-05, 3.1570e-03, 3.3593e-05],
#         [4.8822e-05, 2.2120e-07, 1.4210e-04, 4.7647e-07, 9.9975e-01, 6.4344e-07,
#          6.0954e-05, 7.3946e-08, 4.8109e-07, 1.7147e-07],
#         [1.6019e-03, 9.3878e-01, 7.6748e-04, 2.3651e-02, 2.2963e-03, 7.8840e-04,
#          9.1494e-03, 8.4881e-03, 1.4182e-02, 2.9047e-04],
#         [2.0998e-06, 1.5017e-04, 2.1893e-07, 9.9710e-01, 3.6112e-07, 1.3173e-07,
#          5.4354e-05, 1.3339e-04, 2.5551e-03, 6.8386e-07],
#         [2.6823e-04, 1.4528e-03, 1.7053e-05, 6.0558e-01, 2.4541e-04, 4.2211e-04,
#          8.0001e-03, 3.8339e-01, 2.0019e-04, 4.1874e-04],
#         [1.7556e-04, 9.3597e-04, 2.7503e-04, 4.3129e-06, 1.0311e-03, 2.9731e-06,
#          7.0762e-05, 3.7831e-05, 9.9734e-01, 1.2719e-04],
#         [6.2826e-06, 7.1456e-04, 3.7793e-05, 1.1132e-05, 3.6269e-06, 7.9938e-05,
#          2.7321e-05, 9.9911e-01, 6.0021e-07, 1.2438e-05],
#         [7.6628e-05, 3.2775e-04, 9.9624e-01, 3.8503e-07, 3.1020e-03, 1.6222e-04,
#          7.4626e-07, 4.1758e-05, 1.5060e-05, 2.8938e-05],
#         [9.8817e-01, 1.0449e-04, 1.8742e-05, 4.3223e-03, 6.6436e-04, 3.7168e-04,
#          4.7327e-03, 4.2172e-06, 1.6078e-03, 6.6656e-07],
#         [2.9676e-04, 9.9735e-01, 6.2208e-06, 2.4376e-05, 1.9640e-06, 7.4746e-06,
#          5.3283e-04, 2.0116e-05, 4.8500e-05, 1.7082e-03],
#         [1.2527e-06, 9.9624e-01, 1.8590e-04, 1.3441e-03, 5.2279e-07, 1.5506e-05,
#          1.2865e-05, 2.1711e-03, 2.5425e-06, 2.6430e-05]], device='cuda:0')  Target  tensor([0, 7, 0, 5, 2, 6, 4, 1, 3, 3, 8, 7, 2, 0, 1, 1], device='cuda:0')
# Prediction  tensor([[1.7546e-06, 1.5435e-05, 1.6089e-04, 8.8928e-06, 1.3283e-03, 7.1466e-06,
#          4.8903e-06, 1.1928e-05, 9.9846e-01, 1.0198e-06],
#         [9.9701e-01, 2.8942e-04, 2.5340e-05, 1.2259e-03, 9.0141e-04, 2.6735e-06,
#          1.8722e-04, 2.1308e-04, 1.4329e-04, 5.8401e-07],
#         [8.6559e-05, 7.6147e-04, 9.4930e-01, 1.2456e-03, 3.6567e-02, 4.0635e-03,
#          1.5460e-04, 2.4950e-03, 5.2741e-03, 5.3738e-05],
#         [1.5288e-05, 9.9912e-01, 6.1449e-04, 4.3997e-08, 4.2701e-05, 1.6689e-05,
#          1.5736e-04, 1.4766e-06, 2.6301e-05, 9.8409e-06],
#         [2.1566e-04, 3.2976e-04, 9.9140e-01, 5.9843e-05, 2.3724e-04, 1.2394e-03,
#          1.3780e-05, 2.5765e-04, 7.0900e-05, 6.1734e-03],
#         [5.6797e-07, 4.2057e-05, 4.0800e-05, 8.8470e-07, 3.6812e-05, 9.9952e-01,
#          3.5381e-04, 1.1672e-06, 3.0579e-07, 5.8727e-06],
#         [3.7221e-04, 3.8021e-05, 7.6672e-05, 1.5215e-03, 3.3312e-03, 4.1506e-05,
#          5.9490e-05, 9.9429e-01, 2.4879e-04, 1.9740e-05],
#         [3.8638e-04, 4.0291e-06, 5.0061e-05, 1.8724e-06, 9.9878e-01, 1.0589e-07,
#          7.6843e-04, 7.6629e-07, 6.3656e-06, 4.8328e-07],
#         [3.2395e-05, 8.0348e-04, 6.3915e-06, 9.9797e-01, 1.1213e-06, 2.0783e-04,
#          2.5318e-04, 2.4677e-04, 4.7505e-04, 5.2617e-06],
#         [9.9690e-01, 1.4539e-06, 2.6431e-03, 9.4280e-06, 4.5690e-07, 1.6728e-06,
#          4.4789e-05, 1.0863e-04, 1.3098e-05, 2.7969e-04],
#         [5.1612e-06, 1.2640e-06, 3.5007e-07, 9.9998e-01, 1.1622e-06, 7.0466e-06,
#          7.4808e-06, 3.7212e-07, 5.2614e-08, 1.0764e-06],
#         [6.4482e-07, 1.1249e-04, 9.9868e-01, 1.5489e-04, 2.1315e-04, 5.4456e-04,
#          1.0423e-06, 2.7493e-04, 4.9027e-06, 1.2702e-05],
#         [6.8800e-05, 9.9436e-05, 1.8664e-07, 1.5881e-06, 8.4798e-08, 9.1326e-08,
#          9.9982e-01, 2.8530e-07, 6.9949e-06, 4.0871e-06],
#         [9.9986e-01, 6.4877e-07, 1.5337e-05, 6.7240e-07, 3.7782e-06, 7.6676e-05,
#          9.1740e-08, 5.5153e-06, 2.1112e-05, 1.1572e-05],
#         [9.9673e-01, 1.4873e-05, 1.3401e-04, 1.6562e-04, 8.0612e-05, 2.3152e-04,
#          5.3814e-04, 1.5594e-04, 1.4516e-05, 1.9376e-03],
#         [1.6562e-03, 2.3791e-04, 6.9071e-05, 5.3542e-05, 8.7381e-06, 5.8956e-07,
#          3.3570e-04, 1.8660e-04, 2.5672e-07, 9.9745e-01]], device='cuda:0')  Target  tensor([8, 0, 2, 1, 2, 5, 7, 4, 3, 0, 3, 2, 6, 0, 0, 9], device='cuda:0')
# Test loss 0.06665313243865967
# Testing accuracy 0.9806034482758621

# %% [markdown]
# # Model Interpretation

# %%
from flashtorch.saliency.backprop import Backprop
from flashtorch.utils import load_image

# %%
# model = torch.load(os.path.join("/gdrive/My Drive/Major Project/Images/Experiment 2","model.pt"))
model = CNN(output_size = 5)
model.load_state_dict(torch.load(os.path.join("/gdrive/My Drive/Major Project/Images/Experiment 2/model_5classes_200e.pt")))
# Out:
# <All keys matched successfully>

# %%
backprop = Backprop(model)

# %%
image = load_image("/gdrive/My Drive/Major Project/Images/Experiment 2/Data/test/Abhogi/9_49.png")

plt.imshow(image)
inp = data_transforms["test"](image)
inp = inp.unsqueeze(dim=0)
inp.requires_grad = True

backprop.visualize(inp , 0 , guided=False , figsize=(20,10))
